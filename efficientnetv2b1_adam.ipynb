# %%
import keras
import tensorflow as tf
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten,Conv2D
from keras.models import Model
from keras import backend as K
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np
import cv2
import sklearn
import os
import seaborn as sns
from google.colab.patches import cv2_imshow
import glob
import keras
from keras.models import Sequential
from tensorflow.python.keras.layers import Dense, Flatten, GlobalAveragePooling2D, Activation, Flatten, Dropout
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import callbacks
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam, SGD

# %%
seed = 10

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
 batch_size=16

# %%
train_path="/content/drive/MyDrive/Capstone_data/Clahe_train"
test_path="/content/drive/MyDrive/Capstone_data/Clahe_test"
val_path="/content/drive/MyDrive/Capstone_data/Clahe_val"

# %%
train_normal = glob.glob(train_path+"/normal/*.jpeg")
train_pneumonia = glob.glob(train_path+"/pneumonia/*.jpeg")

test_normal = glob.glob(test_path+"/normal/*.jpeg")
test_pneumonia = glob.glob(test_path+"/pneumonia/*.jpeg")

val_normal = glob.glob(val_path+"/normal/*.jpeg")
val_pneumonia = glob.glob(val_path+"/pneumonia/*.jpeg")

# %%
train_list = [x for x in train_normal]
train_list.extend([x for x in train_pneumonia])

df_train = pd.DataFrame(np.concatenate([['Normal']*len(train_normal) , ['Pneumonia']*len(train_pneumonia)]), columns = ['class'])
df_train['image'] = [x for x in train_list]

test_list = [x for x in test_normal]
test_list.extend([x for x in test_pneumonia])

df_test = pd.DataFrame(np.concatenate([['Normal']*len(test_normal) , ['Pneumonia']*len(test_pneumonia)]), columns = ['class'])
df_test['image'] = [x for x in test_list]

val_list = [x for x in val_normal]
val_list.extend([x for x in val_pneumonia])

df_val = pd.DataFrame(np.concatenate([['Normal']*len(val_normal) , ['Pneumonia']*len(val_pneumonia)]), columns = ['class'])
df_val['image'] = [x for x in val_list]

# %%
df_train.head()
df_test.head()
df_val.head()
# Out:
#     class                                              image
# 0  Normal  /content/drive/MyDrive/Capstone_data/Clahe_val...
# 1  Normal  /content/drive/MyDrive/Capstone_data/Clahe_val...
# 2  Normal  /content/drive/MyDrive/Capstone_data/Clahe_val...
# 3  Normal  /content/drive/MyDrive/Capstone_data/Clahe_val...
# 4  Normal  /content/drive/MyDrive/Capstone_data/Clahe_val...

# %%
df_train=df_train.sample(frac=1)

# %%
df_train.head()
# Out:
#           class                                              image
# 18       Normal  /content/drive/MyDrive/Capstone_data/Clahe_tra...
# 265      Normal  /content/drive/MyDrive/Capstone_data/Clahe_tra...
# 2164  Pneumonia  /content/drive/MyDrive/Capstone_data/Clahe_tra...
# 1211     Normal  /content/drive/MyDrive/Capstone_data/Clahe_tra...
# 2910  Pneumonia  /content/drive/MyDrive/Capstone_data/Clahe_tra...

# %%
from sklearn.model_selection import KFold, StratifiedKFold
Y = df_train[['class']]

kf = KFold(n_splits = 5)
                         
skf = StratifiedKFold(n_splits = 5, random_state = 7, shuffle = True)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator ,load_img,img_to_array

train_datagen = ImageDataGenerator(
        rescale = 1./255,
        shear_range=10,
        zoom_range=0.3,
        horizontal_flip=True,
        vertical_flip=True,
        brightness_range=[0.5,2.0],
        width_shift_range = 0.2,
        rotation_range=20,
        fill_mode = 'nearest',
)
test_datagen = ImageDataGenerator(
        rescale = 1./255)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Input, Flatten, SeparableConv2D
from tensorflow.keras.layers import GlobalMaxPooling2D,GlobalAveragePooling2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from tensorflow.keras.callbacks import ModelCheckpoint, Callback, EarlyStopping
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.applications import ResNet50, InceptionV3, EfficientNetV2B1
from tensorflow.keras.layers.experimental.preprocessing import Normalization

# %%
df_train.shape
n=5216

# %%
x=len(train_normal)
y=len(train_pneumonia)
s1=(x+y)//batch_size
a=len(test_normal)
b=len(test_pneumonia)
s2=(a+b)//batch_size

# %%
from keras.callbacks import ReduceLROnPlateau
import numpy as np
from keras.callbacks import LearningRateScheduler
from tensorflow.keras.models import load_model
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix ,classification_report
import numpy as np

# %%
from tensorflow import keras
from keras import optimizers
import matplotlib.pyplot as plt

# %%
def printHistory(history, title, epochs):
    f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
    t = f.suptitle(title, fontsize=12)
    f.subplots_adjust(top=0.85, wspace=0.3)

    epoch_list = list(range(1,epochs+1))
    ax1.plot(epoch_list, history.history['accuracy'], label='Train Accuracy')
    ax1.plot(epoch_list, history.history['val_accuracy'], label='Validation Accuracy')
    ax1.set_xticks(np.arange(0, epochs+1, 5))
    ax1.set_ylabel('Accuracy Value')
    ax1.set_xlabel('Epoch')
    ax1.set_title('Accuracy')
    l1 = ax1.legend(loc="best")

    ax2.plot(epoch_list, history.history['loss'], label='Train Loss')
    ax2.plot(epoch_list, history.history['val_loss'], label='Validation Loss')
    ax2.set_xticks(np.arange(0, epochs+1, 5))
    ax2.set_ylabel('Loss Value')
    ax2.set_xlabel('Epoch')
    ax2.set_title('Loss')
    l2 = ax2.legend(loc="best")

# %%
from sklearn.metrics import roc_curve, roc_auc_score
def plot_roc_curve(predictions, labels,auc):
    fpr, tpr, thresholds = roc_curve(labels, predictions) 
    plt.title('Receiver Operating Characteristic (ROC)  Curve',fontsize=14)
    plt.xlim([0, 1])
    plt.ylim([0, 1])
    plt.plot(fpr, tpr, 'g',label = 'AUC Score = %0.2f' % auc)
    plt.plot([0, 1], [0, 1],'r--')
    plt.ylabel('\nTrue Positive Rate (TPR)', fontsize=12)
    plt.xlabel('\nFalse Positive Rate (FPR)', fontsize=12)
    plt.legend()
    plt.grid()
    plt.show()

# %%
def conf(cm,target_names):
    plt.figure(figsize=(5,3))
    sns.set(font_scale=1.2)
    ax = sns.heatmap(cm, annot=True,xticklabels=['H', 'P'], yticklabels=['H', 'P'], cbar=False, cmap='Blues',linewidths=1, linecolor='black', fmt='.0f')
    plt.yticks(rotation=0)
    plt.xlabel('Predicted labels')
    plt.ylabel('True labels')
    ax.xaxis.set_ticks_position('top') 
    plt.title('Confusion matrix')
    plt.show()

# %%
VALIDATION_ACCURACY = []
VALIDATION_LOSS = []
TRAINING_ACCURACY=[]
TRAINING_LOSS=[]

save_dir = '/content/drive/MyDrive/Capstone_data/Clahe_train'
fold_var=1
fine_tune_at=30
t=df_train[['class']]
for train_index, val_index in skf.split(np.zeros(len(Y)),Y):
	print("K-Fold"+str(fold_var))
	training_data = df_train.iloc[train_index]
	validation_data = df_train.iloc[val_index]
	
	train_data_generator = train_datagen.flow_from_dataframe(dataframe=training_data,x_col="image",y_col="class",target_size=(224,224),
                                               batch_size=16,class_mode='categorical',shuffle=True)
	valid_data_generator  = test_datagen.flow_from_dataframe(dataframe=validation_data,x_col="image",y_col="class",target_size=(224,224),
                                               batch_size=16,class_mode='categorical',shuffle=False)
        
 	# CREATE NEW MODEL
	model = Sequential()
	conv_base = EfficientNetV2B1(input_shape=[224,224]+[3], include_top=False, weights='imagenet')
	for layer in conv_base.layers[:fine_tune_at]:
		layer.trainable = False
	x=  conv_base.output
	x = GlobalAveragePooling2D()(x)
	x = BatchNormalization()(x)
	x = Dropout(0.3)(x) 
	x = Dense(512, activation ='relu')(x)
	x = BatchNormalization()(x)
	x = Dropout(0.5)(x)
	x = Dense(2, activation ='sigmoid')(x)
	model = Model(conv_base.input, x)
	reduce_lr = ReduceLROnPlateau(monitor='val_loss',patience=7)
	early_stopping = EarlyStopping(monitor = "val_accuracy",patience = 9,verbose = 1,mode = "max",)
	checkpoint = ModelCheckpoint(monitor = "val_accuracy",filepath = "/content/drive/MyDrive/Capstone_data/crefv2b1mnt_adam"+str(fold_var)+".h5",verbose = 1,save_best_only = True, )
	opt = keras.optimizers.Adam(lr=0.0001)
	model.compile(loss = "binary_crossentropy", optimizer =opt, metrics = "accuracy")
	s1=train_data_generator.n//train_data_generator.batch_size
	s2=valid_data_generator.n//valid_data_generator.batch_size
	lr_sched = LearningRateScheduler(lambda epoch: 1e-4 * (0.75 ** np.floor(epoch / 2)))
	history = model.fit(train_data_generator,
    epochs = 30, 
    batch_size = 16,
    validation_data = valid_data_generator,
    validation_steps = s2,
    steps_per_epoch = s1,
    callbacks = [reduce_lr, early_stopping, checkpoint,lr_sched])
	if early_stopping.stopped_epoch==0:
		x=30
	else:
		x=early_stopping.stopped_epoch+1
	printHistory(history,"EfficientNetV2B1_Adam",x)
	modela = load_model("/content/drive/MyDrive/Capstone_data/crefv2b1mnt_adam"+str(fold_var)+".h5") 
	
	results = modela.evaluate(valid_data_generator)
	results = dict(zip(model.metrics_names,results))
	Y_pred = modela.predict_generator(valid_data_generator)
	y_pred = np.argmax(Y_pred, axis=1)
	target_names = ['Normal','Pneumonia']
	cm = confusion_matrix(valid_data_generator.classes, y_pred)
	conf(cm,target_names)
	print('Classification Report')
	print(classification_report(valid_data_generator.classes, y_pred, target_names=target_names))
	auc = roc_auc_score(valid_data_generator.classes, y_pred) 
	plot_roc_curve(valid_data_generator.classes, y_pred,auc)
	TRAINING_ACCURACY.append(history.history['accuracy'])
	TRAINING_LOSS.append(history.history['loss'])
	VALIDATION_ACCURACY.append(history.history['val_accuracy'])
	VALIDATION_LOSS.append(history.history['val_loss'])

	fold_var += 1+
# Out:
# K-Fold1
# Found 4172 validated image filenames belonging to 2 classes.
# Found 1044 validated image filenames belonging to 2 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-b1_notop.h5
# 28456008/28456008 [==============================] - 1s 0us/step
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/30
# 260/260 [==============================] - ETA: 0s - loss: 0.7670 - accuracy: 0.6802
# Epoch 1: val_accuracy improved from -inf to 0.77788, saving model to /content/drive/MyDrive/Capstone_data/crefv2b1mnt_adam1.h5
# 260/260 [==============================] - 963s 3s/step - loss: 0.7670 - accuracy: 0.6802 - val_loss: 0.5092 - val_accuracy: 0.7779 - lr: 1.0000e-04
# Epoch 2/30
# 260/260 [==============================] - ETA: 0s - loss: 0.5830 - accuracy: 0.7810
# Epoch 2: val_accuracy improved from 0.77788 to 0.92212, saving model to /content/drive/MyDrive/Capstone_data/crefv2b1mnt_adam1.h5
# 260/260 [==============================] - 115s 441ms/step - loss: 0.5830 - accuracy: 0.7810 - val_loss: 0.2574 - val_accuracy: 0.9221 - lr: 1.0000e-04
# Epoch 3/30
# 260/260 [==============================] - ETA: 0s - loss: 0.5086 - accuracy: 0.8318
# Epoch 3: val_accuracy improved from 0.92212 to 0.94519, saving model to /content/drive/MyDrive/Capstone_data/crefv2b1mnt_adam1.h5
# 260/260 [==============================] - 116s 446ms/step - loss: 0.5086 - accuracy: 0.8318 - val_loss: 0.2159 - val_accuracy: 0.9452 - lr: 7.5000e-05
# Epoch 4/30
# 260/260 [==============================] - ETA: 0s - loss: 0.4722 - accuracy: 0.8395
# Epoch 4: val_accuracy did not improve from 0.94519
# 260/260 [==============================] - 111s 426ms/step - loss: 0.4722 - accuracy: 0.8395 - val_loss: 0.2500 - val_accuracy: 0.9279 - lr: 7.5000e-05
# Epoch 5/30
# 260/260 [==============================] - ETA: 0s - loss: 0.4220 - accuracy: 0.8588
# Epoch 5: val_accuracy did not improve from 0.94519
# 260/260 [==============================] - 111s 427ms/step - loss: 0.4220 - accuracy: 0.8588 - val_loss: 0.2875 - val_accuracy: 0.9096 - lr: 5.6250e-05
# Epoch 6/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3615 - accuracy: 0.8770
# Epoch 6: val_accuracy did not improve from 0.94519
# 260/260 [==============================] - 111s 428ms/step - loss: 0.3615 - accuracy: 0.8770 - val_loss: 0.3461 - val_accuracy: 0.9038 - lr: 5.6250e-05
# Epoch 7/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3777 - accuracy: 0.8725
# Epoch 7: val_accuracy did not improve from 0.94519
# 260/260 [==============================] - 111s 427ms/step - loss: 0.3777 - accuracy: 0.8725 - val_loss: 0.2317 - val_accuracy: 0.9327 - lr: 4.2188e-05
# Epoch 8/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3603 - accuracy: 0.8744
# Epoch 8: val_accuracy did not improve from 0.94519
# 260/260 [==============================] - 111s 427ms/step - loss: 0.3603 - accuracy: 0.8744 - val_loss: 0.2582 - val_accuracy: 0.9269 - lr: 4.2188e-05
# Epoch 9/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3612 - accuracy: 0.8730
# Epoch 9: val_accuracy did not improve from 0.94519
# 260/260 [==============================] - 111s 429ms/step - loss: 0.3612 - accuracy: 0.8730 - val_loss: 0.1835 - val_accuracy: 0.9413 - lr: 3.1641e-05
# Epoch 10/30
# 260/260 [==============================] - ETA: 0s - loss: 0.
val_accuracy did not improve from 0.95385
# 260/260 [==============================] - 115s 442ms/step - loss: 0.3094 - accuracy: 0.8881 - val_loss: 0.2137 - val_accuracy: 0.9327 - lr: 1.3348e-05
# Epoch 17/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2917 - accuracy: 0.9028
# Epoch 17: val_accuracy did not improve from 0.95385
# 260/260 [==============================] - 116s 445ms/step - loss: 0.2917 - accuracy: 0.9028 - val_loss: 0.2272 - val_accuracy: 0.9308 - lr: 1.0011e-05
# Epoch 17: early stopping
# 66/66 [==============================] - 15s 200ms/step - loss: 0.1631 - accuracy: 0.9530
# <ipython-input-21-3c66221ba299>:58: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   Y_pred = modela.predict_generator(valid_data_generator)
# Classification Report
#               precision    recall  f1-score   support
#
#       Normal       0.89      0.93      0.91       268
#    Pneumonia       0.98      0.96      0.97       775
#
#     accuracy                           0.95      1043
#    macro avg       0.93      0.95      0.94      1043
# weighted avg       0.95      0.95      0.95      1043
# K-Fold4
# Found 4173 validated image filenames belonging to 2 classes.
# Found 1043 validated image filenames belonging to 2 classes.
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/30
# 260/260 [==============================] - ETA: 0s - loss: 0.7630 - accuracy: 0.6825
# Epoch 1: val_accuracy improved from -inf to 0.91058, saving model to /content/drive/MyDrive/Capstone_data/crefv2b1mnt_adam4.h5
# 260/260 [==============================] - 165s 459ms/step - loss: 0.7630 - accuracy: 0.6825 - val_loss: 0.3162 - val_accuracy: 0.9106 - lr: 1.0000e-04
# Epoch 2/30
# 260/260 [==============================] - ETA: 0s - loss: 0.5599 - accuracy: 0.7934
# Epoch 2: val_accuracy improved from 0.91058 to 0.92404, saving model to /content/drive/MyDrive/Capstone_data/crefv2b1mnt_adam4.h5
# 260/260 [==============================] - 117s 450ms/step - loss: 0.5599 - accuracy: 0.7934 - val_loss: 0.2429 - val_accuracy: 0.9240 - lr: 1.0000e-04
# Epoch 3/30
# 260/260 [==============================] - ETA: 0s - loss: 0.4893 - accuracy: 0.8311
# Epoch 3: val_accuracy did not improve from 0.92404
# 260/260 [==============================] - 115s 440ms/step - loss: 0.4893 - accuracy: 0.8311 - val_loss: 0.2426 - val_accuracy: 0.9240 - lr: 7.5000e-05
# Epoch 4/30
# 260/260 [==============================] - ETA: 0s - loss: 0.4603 - accuracy: 0.8436
# Epoch 4: val_accuracy improved from 0.92404 to 0.94135, saving model to /content/drive/MyDrive/Capstone_data/crefv2b1mnt_adam4.h5
# 260/260 [==============================] - 111s 426ms/step - loss: 0.4603 - accuracy: 0.8436 - val_loss: 0.2319 - val_accuracy: 0.9413 - lr: 7.5000e-05
# Epoch 5/30
# 260/260 [==============================] - ETA: 0s - loss: 0.4028 - accuracy: 0.8610
# Epoch 5: val_accuracy improved from 0.94135 to 0.94519, saving model to /content/drive/MyDrive/Capstone_data/crefv2b1mnt_adam4.h5
# 260/260 [==============================] - 112s 430ms/step - loss: 0.4028 - accuracy: 0.8610 - val_loss: 0.1823 - val_accuracy: 0.9452 - lr: 5.6250e-05
# Epoch 6/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3969 - accuracy: 0.8672
# Epoch 6: val_accuracy improved from 0.94519 to 0.95096, saving model to /content/drive/MyDrive/Capstone_data/crefv2b1mnt_adam4.h5
# 260/260 [==============================] - 111s 425ms/step - loss: 0.3969 - accuracy: 0.8672 - val_loss: 0.1941 - val_accuracy: 0.9510 - lr: 5.6250e-05
# Epoch 7/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3689 - accuracy: 0.8691
# Epoch 7: val_accuracy improved from 0.95096 to 0.95962, saving model to /content/drive/MyDrive/Capstone_data/crefv2b1mnt_adam4.h5
# 260/260 [==============================] - 114s 438ms/step - loss: 0.3689 - accuracy: 0.8691 - val_loss: 0.1655 - val_accuracy: 0.9596 - lr: 4.2188e-05
# Epoch 8/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3502 - accuracy: 0.8727
# Epoch 8: val_accuracy did not improve from 0.95962
# 260/260 [==============================] - 126s 484ms/step - loss: 0.3502 - accuracy: 0.8727 - val_loss: 0.1763 - val_accuracy: 0.9365 - lr: 4.2188e-05
# Epoch 9/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3444 - accuracy: 0.8838
# Epoch 9: val_accuracy did not improve from 0.95962
# 260/260 [==============================] - 125s 479ms/step - loss: 0.3444 - accuracy: 0.8838 - val_loss: 0.1609 - val_accuracy: 0.9481 - lr: 3.1641e-05
# Epoch 10/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3346 - accuracy: 0.8843
# Epoch 10: val_accuracy did not improve from 0.95962
# 260/260 [==============================] - 124s 477ms/step - loss: 0.3346 - accuracy: 0.8843 - val_loss: 0.2242 - val_accuracy: 0.9413 - lr: 3.1641e-05
# Epoch 11/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3164 - accuracy: 0.8939
# Epoch 11: val_accuracy improved from 0.95962 to 0.96154, saving model to /content/drive/MyDrive/Capstone_data/crefv2b1mnt_ad
:58: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   Y_pred = modela.predict_generator(valid_data_generator)
# Classification Report
#               precision    recall  f1-score   support
#
#       Normal       0.92      0.93      0.93       268
#    Pneumonia       0.98      0.97      0.97       775
#
#     accuracy                           0.96      1043
#    macro avg       0.95      0.95      0.95      1043
# weighted avg       0.96      0.96      0.96      1043
# K-Fold5
# Found 4173 validated image filenames belonging to 2 classes.
# Found 1043 validated image filenames belonging to 2 classes.
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/30
# 260/260 [==============================] - ETA: 0s - loss: 0.7971 - accuracy: 0.6623
# Epoch 1: val_accuracy improved from -inf to 0.81442, saving model to /content/drive/MyDrive/Capstone_data/crefv2b1mnt_adam5.h5
# 260/260 [==============================] - 170s 476ms/step - loss: 0.7971 - accuracy: 0.6623 - val_loss: 0.4581 - val_accuracy: 0.8144 - lr: 1.0000e-04
# Epoch 2/30
# 260/260 [==============================] - ETA: 0s - loss: 0.5927 - accuracy: 0.7799
# Epoch 2: val_accuracy improved from 0.81442 to 0.91250, saving model to /content/drive/MyDrive/Capstone_data/crefv2b1mnt_adam5.h5
# 260/260 [==============================] - 119s 458ms/step - loss: 0.5927 - accuracy: 0.7799 - val_loss: 0.3032 - val_accuracy: 0.9125 - lr: 1.0000e-04
# Epoch 3/30
# 260/260 [==============================] - ETA: 0s - loss: 0.5117 - accuracy: 0.8213
# Epoch 3: val_accuracy improved from 0.91250 to 0.93462, saving model to /content/drive/MyDrive/Capstone_data/crefv2b1mnt_adam5.h5
# 260/260 [==============================] - 122s 470ms/step - loss: 0.5117 - accuracy: 0.8213 - val_loss: 0.2309 - val_accuracy: 0.9346 - lr: 7.5000e-05
# Epoch 4/30
# 260/260 [==============================] - ETA: 0s - loss: 0.4709 - accuracy: 0.8408
# Epoch 4: val_accuracy did not improve from 0.93462
# 260/260 [==============================] - 118s 454ms/step - loss: 0.4709 - accuracy: 0.8408 - val_loss: 0.2838 - val_accuracy: 0.9135 - lr: 7.5000e-05
# Epoch 5/30
# 260/260 [==============================] - ETA: 0s - loss: 0.4366 - accuracy: 0.8530
# Epoch 5: val_accuracy did not improve from 0.93462
# 260/260 [==============================] - 119s 456ms/step - loss: 0.4366 - accuracy: 0.8530 - val_loss: 0.2786 - val_accuracy: 0.9183 - lr: 5.6250e-05
# Epoch 6/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3959 - accuracy: 0.8670
# Epoch 6: val_accuracy improved from 0.93462 to 0.94423, saving model to /content/drive/MyDrive/Capstone_data/crefv2b1mnt_adam5.h5
# 260/260 [==============================] - 119s 456ms/step - loss: 0.3959 - accuracy: 0.8670 - val_loss: 0.1979 - val_accuracy: 0.9442 - lr: 5.6250e-05
# Epoch 7/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3675 - accuracy: 0.8766
# Epoch 7: val_accuracy improved from 0.94423 to 0.94904, saving model to /content/drive/MyDrive/Capstone_data/crefv2b1mnt_adam5.h5
# 260/260 [==============================] - 119s 459ms/step - loss: 0.3675 - accuracy: 0.8766 - val_loss: 0.1804 - val_accuracy: 0.9490 - lr: 4.2188e-05
# Epoch 8/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3535 - accuracy: 0.8824
# Epoch 8: val_accuracy did not improve from 0.94904
# 260/260 [==============================] - 119s 458ms/step - loss: 0.3535 - accuracy: 0.8824 - val_loss: 0.2575 - val_accuracy: 0.9298 - lr: 4.2188e-05
# Epoch 9/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3486 - accuracy: 0.8785
# Epoch 9: val_accuracy did not improve from 0.94904
# 260/260 [==============================] - 119s 456ms/step - loss: 0.3486 - accuracy: 0.8785 - val_loss: 0.1853 - val_accuracy: 0.9385 - lr: 3.1641e-05
# Epoch 10/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3333 - accuracy: 0.8809
# Epoch 10: val_accuracy did not improve from 0.94904
# 260/260 [==============================] - 118s 452ms/step - loss: 0.3333 - accuracy: 0.8809 - val_loss: 0.1689 - val_accuracy: 0.9490 - lr: 3.1641e-05
# Epoch 11/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3220 - accuracy: 0.8920
# Epoch 11: val_accuracy did not improve from 0.94904
# 260/260 [==============================] - 124s 475ms/step - loss: 0.3220 - accuracy: 0.8920 - val_loss: 0.2115 - val_accuracy: 0.9394 - lr: 2.3730e-05
# Epoch 12/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3052 - accuracy: 0.8913
# Epoch 12: val_accuracy did not improve from 0.94904
# 260/260 [==============================] - 116s 446ms/step - loss: 0.3052 - accuracy: 0.8913 - val_loss: 0.1825 - val_accuracy: 0.9442 - lr: 2.3730e-05
# Epoch 13/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3054 - accuracy: 0.8994
# Epoch 13: val_accuracy did not improve from 0.94904
# 260/260 [==============================] - 115s 443ms/step - loss: 0.3054 - accuracy: 0.8994 - val_loss: 0.1560 - val_accuracy: 0.9481 - lr: 1.7798e-05
# Epoch 14/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3151 - accuracy: 0.8932
# Epoch 14: val_accuracy did not improve from 0.94904
# 260/260 [==============================] - 116s 446ms/step - loss: 0.3151 - accuracy: 0.8932 - val_loss: 0.1805 - val_accuracy: 0.9442 - lr: 1.7798e-05
# Epoch 15/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3036 - accuracy: 0.8951
# Epoch 15: val_accuracy did not improve from 0.94904
# 260/260 [==============================] - 116s 445ms/step - loss: 0.3036 - accuracy: 0.8951 - val_loss: 0.1672 - val_accuracy: 0.9442 - lr: 1.3348e-05
# Epoch 16/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3000 - accuracy: 0.8985
# Epoch 16: val_accuracy improved from 0.94904 to 0.95288, saving model to /content/drive/MyDrive/Capstone_data/crefv2b1mnt_adam5.h5
# 260/260 [==============================] - 118s 453ms/step - loss: 0.3000 - accuracy: 0.8985 - val_loss: 0.1585 - val_accuracy: 0.9529 - lr: 1.3348e-05
# Epoch 17/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3034 - accuracy: 0.8942
# Epoch 17: val_accuracy did not improve from 0.95288
# 260/260 [==============================] - 115s 444ms/step - loss: 0.3034 - accuracy: 0.8942 - val_loss: 0.1586 - val_accuracy: 0.9490 - lr: 1.0011e-05
# Epoch 18/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2782 - accuracy: 0.9038
# Epoch 18: val_accuracy did not improve from 0.95288
# 260/260 [==============================] - 116s 444ms/step - loss: 0.2782 - accuracy: 0.9038 - val_loss: 0.1560 - val_accuracy: 0.9519 - lr: 1.0011e-05
# Epoch 19/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2893 - accuracy: 0.9026
# Epoch 19: val_accuracy did not improve from 0.95288
# 260/260 [==============================] - 118s 453ms/step - loss: 0.2893 - accuracy: 0.9026 - val_loss: 0.1660 - val_accuracy: 0.9490 - lr: 7.5085e-06
# Epoch 20/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3028 - accuracy: 0.8922
# Epoch 20: val_accuracy did not improve from 0.95288
# 260/260 [==============================] - 117s 451ms/step - loss: 0.3028 - accuracy: 0.8922 - val_loss: 0.1422 - val_accuracy: 0.9481 - lr: 7.5085e-06
# Epoch 21/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2829 - accuracy: 0.8980
# Epoch 21: val_accuracy did not improve from 0.95288
# 260/260 [==============================] - 117s 448ms/step - loss: 0.2829 - accuracy: 0.8980 - val_loss: 0.1519 - val_accuracy: 0.9519 - lr: 5.6314e-06
# Epoch 22/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2776 - accuracy: 0.9040
# Epoch 22: val_accuracy did not improve from 0.95288
# 260/260 [==============================] - 118s 453ms/step - loss: 0.2776 - accuracy: 0.9040 - val_loss: 0.1562 - val_accuracy: 0.9500 - lr: 5.6314e-06
# Epoch 23/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2614 - accuracy: 0.9127
# Epoch 23: val_accuracy did not improve from 0.95288
# 260/260 [==============================] - 117s 452ms/step - loss: 0.2614 - accuracy: 0.9127 - val_loss: 0.1718 - val_accuracy: 0.9519 - lr: 4.2235e-06
# Epoch 24/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2817 - accuracy: 0.9038
# Epoch 24: val_accuracy did not improve from 0.95288
# 260/260 [==============================] - 119s 456ms/step - loss: 0.2817 - accuracy: 0.9038 - val_loss: 0.1625 - val_accuracy: 0.9510 - lr: 4.2235e-06
# Epoch 25/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2788 - accuracy: 0.9062
# Epoch 25: val_accuracy did not improve from 0.95288
# 260/260 [==============================] - 120s 461ms/step - loss: 0.2788 - accuracy: 0.9062 - val_loss: 0.1449 - val_accuracy: 0.9529 - lr: 3.1676e-06
# Epoch 25: early stopping
# 66/66 [==============================] - 16s 214ms/step - loss: 0.1585 - accuracy: 0.9530
# <ipython-input-21-3c66221ba299>:58: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   Y_pred = modela.predict_generator(valid_data_generator)
# Classification Report
#               precision    recall  f1-score   support
#
#       Normal       0.89      0.94      0.91       268
#    Pneumonia       0.98      0.96      0.97       775
#
#     accuracy                           0.95      1043
#    macro avg       0.93      0.95      0.94      1043
# weighted avg       0.95      0.95      0.95      1043

# %%
l1=max(VALIDATION_ACCURACY[0])
l2=max(VALIDATION_ACCURACY[1])
l3=max(VALIDATION_ACCURACY[2])
l4=max(VALIDATION_ACCURACY[3])
l5=max(VALIDATION_ACCURACY[4])

avg=(l1+l2+l3+l4+l5)/5
avg
# Out:
# 0.9530769228935242
