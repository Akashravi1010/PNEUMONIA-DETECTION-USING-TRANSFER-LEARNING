# %%
import keras
import tensorflow as tf
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten,Conv2D
from keras.models import Model
from keras import backend as K
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np
import cv2
import sklearn
import os
import seaborn as sns
from google.colab.patches import cv2_imshow
import glob
import keras
from keras.models import Sequential
from tensorflow.python.keras.layers import Dense, Flatten, GlobalAveragePooling2D, Activation, Flatten, Dropout
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import callbacks
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam, SGD

# %%
seed = 10

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
 batch_size=16

# %%
train_path="/content/drive/MyDrive/Capstone_data/Clahe_train"
test_path="/content/drive/MyDrive/Capstone_data/Clahe_test"
val_path="/content/drive/MyDrive/Capstone_data/Clahe_val"

# %%
train_normal = glob.glob(train_path+"/normal/*.jpeg")
train_pneumonia = glob.glob(train_path+"/pneumonia/*.jpeg")

test_normal = glob.glob(test_path+"/normal/*.jpeg")
test_pneumonia = glob.glob(test_path+"/pneumonia/*.jpeg")

val_normal = glob.glob(val_path+"/normal/*.jpeg")
val_pneumonia = glob.glob(val_path+"/pneumonia/*.jpeg")

# %%
train_list = [x for x in train_normal]
train_list.extend([x for x in train_pneumonia])

df_train = pd.DataFrame(np.concatenate([['Normal']*len(train_normal) , ['Pneumonia']*len(train_pneumonia)]), columns = ['class'])
df_train['image'] = [x for x in train_list]

test_list = [x for x in test_normal]
test_list.extend([x for x in test_pneumonia])

df_test = pd.DataFrame(np.concatenate([['Normal']*len(test_normal) , ['Pneumonia']*len(test_pneumonia)]), columns = ['class'])
df_test['image'] = [x for x in test_list]

val_list = [x for x in val_normal]
val_list.extend([x for x in val_pneumonia])

df_val = pd.DataFrame(np.concatenate([['Normal']*len(val_normal) , ['Pneumonia']*len(val_pneumonia)]), columns = ['class'])
df_val['image'] = [x for x in val_list]

# %%
df_train.head()
df_test.head()
df_val.head()
# Out:
#     class                                              image
# 0  Normal  /content/drive/MyDrive/Capstone_data/Clahe_val...
# 1  Normal  /content/drive/MyDrive/Capstone_data/Clahe_val...
# 2  Normal  /content/drive/MyDrive/Capstone_data/Clahe_val...
# 3  Normal  /content/drive/MyDrive/Capstone_data/Clahe_val...
# 4  Normal  /content/drive/MyDrive/Capstone_data/Clahe_val...

# %%
df_train=df_train.sample(frac=1)

# %%
df_train.head()
# Out:
#           class                                              image
# 4505  Pneumonia  /content/drive/MyDrive/Capstone_data/Clahe_tra...
# 4911  Pneumonia  /content/drive/MyDrive/Capstone_data/Clahe_tra...
# 3195  Pneumonia  /content/drive/MyDrive/Capstone_data/Clahe_tra...
# 3641  Pneumonia  /content/drive/MyDrive/Capstone_data/Clahe_tra...
# 4082  Pneumonia  /content/drive/MyDrive/Capstone_data/Clahe_tra...

# %%
from sklearn.model_selection import KFold, StratifiedKFold
Y = df_train[['class']]

kf = KFold(n_splits = 5)
                         
skf = StratifiedKFold(n_splits = 5, random_state = 7, shuffle = True)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator ,load_img,img_to_array

train_datagen = ImageDataGenerator(
        rescale = 1./255,
        shear_range=10,
        zoom_range=0.3,
        horizontal_flip=True,
        vertical_flip=True,
        brightness_range=[0.5,2.0],
        width_shift_range = 0.2,
        rotation_range=20,
        fill_mode = 'nearest',
)
test_datagen = ImageDataGenerator(
        rescale = 1./255)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Input, Flatten, SeparableConv2D
from tensorflow.keras.layers import GlobalMaxPooling2D,GlobalAveragePooling2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from tensorflow.keras.callbacks import ModelCheckpoint, Callback, EarlyStopping
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.applications import ResNet50, InceptionV3, EfficientNetV2L
from tensorflow.keras.layers.experimental.preprocessing import Normalization

# %%
df_train.shape
n=5216

# %%
x=len(train_normal)
y=len(train_pneumonia)
s1=(x+y)//batch_size
a=len(test_normal)
b=len(test_pneumonia)
s2=(a+b)//batch_size

# %%
from keras.callbacks import ReduceLROnPlateau
import numpy as np
from keras.callbacks import LearningRateScheduler
from tensorflow.keras.models import load_model
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix ,classification_report
import numpy as np

# %%
from tensorflow import keras
from keras import optimizers
import matplotlib.pyplot as plt

# %%
def printHistory(history, title, epochs):
    f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
    t = f.suptitle(title, fontsize=12)
    f.subplots_adjust(top=0.85, wspace=0.3)

    epoch_list = list(range(1,epochs+1))
    ax1.plot(epoch_list, history.history['accuracy'], label='Train Accuracy')
    ax1.plot(epoch_list, history.history['val_accuracy'], label='Validation Accuracy')
    ax1.set_xticks(np.arange(0, epochs+1, 5))
    ax1.set_ylabel('Accuracy Value')
    ax1.set_xlabel('Epoch')
    ax1.set_title('Accuracy')
    l1 = ax1.legend(loc="best")

    ax2.plot(epoch_list, history.history['loss'], label='Train Loss')
    ax2.plot(epoch_list, history.history['val_loss'], label='Validation Loss')
    ax2.set_xticks(np.arange(0, epochs+1, 5))
    ax2.set_ylabel('Loss Value')
    ax2.set_xlabel('Epoch')
    ax2.set_title('Loss')
    l2 = ax2.legend(loc="best")

# %%
from sklearn.metrics import roc_curve, roc_auc_score
def plot_roc_curve(predictions, labels,auc):
    fpr, tpr, thresholds = roc_curve(labels, predictions) 
    plt.title('Receiver Operating Characteristic (ROC)  Curve',fontsize=14)
    plt.xlim([0, 1])
    plt.ylim([0, 1])
    plt.plot(fpr, tpr, 'g',label = 'AUC Score = %0.2f' % auc)
    plt.plot([0, 1], [0, 1],'r--')
    plt.ylabel('\nTrue Positive Rate (TPR)', fontsize=12)
    plt.xlabel('\nFalse Positive Rate (FPR)', fontsize=12)
    plt.legend()
    plt.grid()
    plt.show()

# %%
def conf(cm,target_names):
    plt.figure(figsize=(5,3))
    sns.set(font_scale=1.2)
    ax = sns.heatmap(cm, annot=True,xticklabels=['H', 'P'], yticklabels=['H', 'P'], cbar=False, cmap='Blues',linewidths=1, linecolor='black', fmt='.0f')
    plt.yticks(rotation=0)
    plt.xlabel('Predicted labels')
    plt.ylabel('True labels')
    ax.xaxis.set_ticks_position('top') 
    plt.title('Confusion matrix')
    plt.show()

# %%
VALIDATION_ACCURACY = []
VALIDATION_LOSS = []
TRAINING_ACCURACY=[]
TRAINING_LOSS=[]

save_dir = '/content/drive/MyDrive/Capstone_data/Clahe_train'
fold_var=1
fine_tune_at=30
t=df_train[['class']]
for train_index, val_index in skf.split(np.zeros(len(Y)),Y):
	print("K-Fold"+str(fold_var))
	training_data = df_train.iloc[train_index]
	validation_data = df_train.iloc[val_index]
	
	train_data_generator = train_datagen.flow_from_dataframe(dataframe=training_data,x_col="image",y_col="class",target_size=(224,224),
                                               batch_size=16,class_mode='categorical',shuffle=True)
	valid_data_generator  = test_datagen.flow_from_dataframe(dataframe=validation_data,x_col="image",y_col="class",target_size=(224,224),
                                               batch_size=16,class_mode='categorical',shuffle=False)
        
 	# CREATE NEW MODEL
	model = Sequential()
	conv_base = EfficientNetV2L(input_shape=[224,224]+[3], include_top=False, weights='imagenet')
	for layer in conv_base.layers[:fine_tune_at]:
		layer.trainable = False
	x=  conv_base.output
	x = GlobalAveragePooling2D()(x)
	x = BatchNormalization()(x)
	x = Dropout(0.3)(x) 
	x = Dense(512, activation ='relu')(x)
	x = BatchNormalization()(x)
	x = Dropout(0.5)(x)
	x = Dense(2, activation ='sigmoid')(x)
	model = Model(conv_base.input, x)
	reduce_lr = ReduceLROnPlateau(monitor='val_loss',patience=8)
	early_stopping = EarlyStopping(monitor = "val_accuracy",patience = 9,verbose = 1,mode = "max",)
	checkpoint = ModelCheckpoint(monitor = "val_accuracy",filepath = "/content/drive/MyDrive/Capstone_data/crefv2lmnt_adam"+str(fold_var)+".h5",verbose = 1,save_best_only = True, )
	opt = keras.optimizers.Adam(lr=0.0001)
	model.compile(loss = "binary_crossentropy", optimizer =opt, metrics = "accuracy")
	s1=train_data_generator.n//train_data_generator.batch_size
	s2=valid_data_generator.n//valid_data_generator.batch_size
	lr_sched = LearningRateScheduler(lambda epoch: 1e-4 * (0.75 ** np.floor(epoch / 2)))
	history = model.fit(train_data_generator,
    epochs = 30, 
    batch_size = 16,
    validation_data = valid_data_generator,
    validation_steps = s2,
    steps_per_epoch = s1,
    callbacks = [reduce_lr, early_stopping, checkpoint,lr_sched])
	printHistory(history,"EfficientNetV2L_Adam",early_stopping.stopped_epoch+1)
	modela = load_model("/content/drive/MyDrive/Capstone_data/crefv2lmnt_adam"+str(fold_var)+".h5") 
	
	results = modela.evaluate(valid_data_generator)
	results = dict(zip(model.metrics_names,results))
	Y_pred = modela.predict_generator(valid_data_generator)
	y_pred = np.argmax(Y_pred, axis=1)
	target_names = ['Normal','Pneumonia']
	cm = confusion_matrix(valid_data_generator.classes, y_pred)
	conf(cm,target_names)
	print('Classification Report')
	print(classification_report(valid_data_generator.classes, y_pred, target_names=target_names))
	auc = roc_auc_score(valid_data_generator.classes, y_pred) 
	plot_roc_curve(valid_data_generator.classes, y_pred,auc)
	TRAINING_ACCURACY.append(history.history['accuracy'])
	TRAINING_LOSS.append(history.history['loss'])
	VALIDATION_ACCURACY.append(history.history['val_accuracy'])
	VALIDATION_LOSS.append(history.history['val_loss'])

	fold_var += 1
# Out:
# K-Fold1
# Found 4172 validated image filenames belonging to 2 classes.
# Found 1044 validated image filenames belonging to 2 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-l_notop.h5
# 473176280/473176280 [==============================] - 12s 0us/step
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/30
# 260/260 [==============================] - ETA: 0s - loss: 0.6508 - accuracy: 0.7613
# Epoch 1: val_accuracy improved from -inf to 0.85962, saving model to /content/drive/MyDrive/Capstone_data/crefv2lmnt_adam1.h5
# 260/260 [==============================] - 2762s 10s/step - loss: 0.6508 - accuracy: 0.7613 - val_loss: 0.3632 - val_accuracy: 0.8596 - lr: 1.0000e-04
# Epoch 2/30
# 260/260 [==============================] - ETA: 0s - loss: 0.5066 - accuracy: 0.8429
# Epoch 2: val_accuracy improved from 0.85962 to 0.94423, saving model to /content/drive/MyDrive/Capstone_data/crefv2lmnt_adam1.h5
# 260/260 [==============================] - 223s 855ms/step - loss: 0.5066 - accuracy: 0.8429 - val_loss: 0.2168 - val_accuracy: 0.9442 - lr: 1.0000e-04
# Epoch 3/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3630 - accuracy: 0.8934
# Epoch 3: val_accuracy did not improve from 0.94423
# 260/260 [==============================] - 206s 792ms/step - loss: 0.3630 - accuracy: 0.8934 - val_loss: 0.2324 - val_accuracy: 0.9346 - lr: 7.5000e-05
# Epoch 4/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3243 - accuracy: 0.8987
# Epoch 4: val_accuracy improved from 0.94423 to 0.95288, saving model to /content/drive/MyDrive/Capstone_data/crefv2lmnt_adam1.h5
# 260/260 [==============================] - 226s 868ms/step - loss: 0.3243 - accuracy: 0.8987 - val_loss: 0.1667 - val_accuracy: 0.9529 - lr: 7.5000e-05
# Epoch 5/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3069 - accuracy: 0.9018
# Epoch 5: val_accuracy did not improve from 0.95288
# 260/260 [==============================] - 206s 792ms/step - loss: 0.3069 - accuracy: 0.9018 - val_loss: 0.1719 - val_accuracy: 0.9404 - lr: 5.6250e-05
# Epoch 6/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2551 - accuracy: 0.9201
# Epoch 6: val_accuracy did not improve from 0.95288
# 260/260 [==============================] - 208s 797ms/step - loss: 0.2551 - accuracy: 0.9201 - val_loss: 0.3249 - val_accuracy: 0.9019 - lr: 5.6250e-05
# Epoch 7/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2498 - accuracy: 0.9237
# Epoch 7: val_accuracy did not improve from 0.95288
# 260/260 [==============================] - 207s 795ms/step - loss: 0.2498 - accuracy: 0.9237 - val_loss: 0.1521 - val_accuracy: 0.9500 - lr: 4.2188e-05
# Epoch 8/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2238 - accuracy: 0.9329
# Epoch 8: val_accuracy did not improve from 0.95288
# 260/260 [==============================] - 206s 792ms/step - loss: 0.2238 - accuracy: 0.9329 - val_loss: 0.1910 - val_accuracy: 0.9356 - lr: 4.2188e-05
# Epoch 9/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2022 - accuracy: 0.9403
# Epoch 9: val_accuracy did not improve from 0.95288
# 260/260 [==============================] -
saving model to /content/drive/MyDrive/Capstone_data/crefv2lmnt_adam3.h5
# 260/260 [==============================] - 224s 859ms/step - loss: 0.2266 - accuracy: 0.9314 - val_loss: 0.1031 - val_accuracy: 0.9740 - lr: 4.2188e-05
# Epoch 9/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2085 - accuracy: 0.9350
# Epoch 9: val_accuracy did not improve from 0.97404
# 260/260 [==============================] - 206s 791ms/step - loss: 0.2085 - accuracy: 0.9350 - val_loss: 0.1541 - val_accuracy: 0.9538 - lr: 3.1641e-05
# Epoch 10/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1718 - accuracy: 0.9478
# Epoch 10: val_accuracy did not improve from 0.97404
# 260/260 [==============================] - 206s 792ms/step - loss: 0.1718 - accuracy: 0.9478 - val_loss: 0.2576 - val_accuracy: 0.9481 - lr: 3.1641e-05
# Epoch 11/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2039 - accuracy: 0.9387
# Epoch 11: val_accuracy did not improve from 0.97404
# 260/260 [==============================] - 206s 791ms/step - loss: 0.2039 - accuracy: 0.9387 - val_loss: 0.2169 - val_accuracy: 0.9423 - lr: 2.3730e-05
# Epoch 12/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1767 - accuracy: 0.9423
# Epoch 12: val_accuracy did not improve from 0.97404
# 260/260 [==============================] - 206s 791ms/step - loss: 0.1767 - accuracy: 0.9423 - val_loss: 0.2419 - val_accuracy: 0.9625 - lr: 2.3730e-05
# Epoch 13/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1466 - accuracy: 0.9521
# Epoch 13: val_accuracy did not improve from 0.97404
# 260/260 [==============================] - 206s 792ms/step - loss: 0.1466 - accuracy: 0.9521 - val_loss: 0.3285 - val_accuracy: 0.9404 - lr: 1.7798e-05
# Epoch 14/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1601 - accuracy: 0.9541
# Epoch 14: val_accuracy did not improve from 0.97404
# 260/260 [==============================] - 206s 791ms/step - loss: 0.1601 - accuracy: 0.9541 - val_loss: 0.2468 - val_accuracy: 0.9587 - lr: 1.7798e-05
# Epoch 15/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1510 - accuracy: 0.9536
# Epoch 15: val_accuracy did not improve from 0.97404
# 260/260 [==============================] - 206s 792ms/step - loss: 0.1510 - accuracy: 0.9536 - val_loss: 0.1875 - val_accuracy: 0.9481 - lr: 1.3348e-05
# Epoch 16/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1431 - accuracy: 0.9589
# Epoch 16: val_accuracy did not improve from 0.97404
# 260/260 [==============================] - 206s 792ms/step - loss: 0.1431 - accuracy: 0.9589 - val_loss: 0.3019 - val_accuracy: 0.9279 - lr: 1.3348e-06
# Epoch 17/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1299 - accuracy: 0.9620
# Epoch 17: val_accuracy did not improve from 0.97404
# 260/260 [==============================] - 206s 792ms/step - loss: 0.1299 - accuracy: 0.9620 - val_loss: 0.3325 - val_accuracy: 0.9365 - lr: 1.0011e-05
# Epoch 17: early stopping
# 66/66 [==============================] - 21s 226ms/step - loss: 0.1049 - accuracy: 0.9732
# <ipython-input-21-fb8dc7c3523f>:54: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   Y_pred = modela.predict_generator(valid_data_generator)
# Classification Report
#               precision    recall  f1-score   support
#
#       Normal       0.98      0.92      0.95       268
#    Pneumonia       0.97      0.99      0.98       775
#
#     accuracy                           0.97      1043
#    macro avg       0.97      0.96      0.96      1043
# weighted avg       0.97      0.97      0.97      1043
# K-Fold4
# Found 4173 validated image filenames belonging to 2 classes.
# Found 1043 validated image filenames belonging to 2 classes.
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/30
# 260/260 [==============================] - ETA: 0s - loss: 0.6812 - accuracy: 0.7541
# Epoch 1: val_accuracy improved from -inf to 0.78077, saving model to /content/drive/MyDrive/Capstone_data/crefv2lmnt_adam4.h5
# 260/260 [==============================] - 391s 951ms/step - loss: 0.6812 - accuracy: 0.7541 - val_loss: 0.8844 - val_accuracy: 0.7808 - lr: 1.0000e-04
# Epoch 2/30
# 260/260 [==============================] - ETA: 0s - loss: 0.4624 - accuracy: 0.8629
# Epoch 2: val_accuracy improved from 0.78077 to 0.92788, saving model to /content/drive/MyDrive/Capstone_data/crefv2lmnt_adam4.h5
# 260/260 [==============================] - 226s 863ms/step - loss: 0.4624 - accuracy: 0.8629 - val_loss: 0.4481 - val_accuracy: 0.9279 - lr: 1.0000e-04
# Epoch 3/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3866 - accuracy: 0.8850
# Epoch 3: val_accuracy did not improve from 0.92788
# 260/260 [==============================] - 206s 793ms/step - loss: 0.3866 - accuracy: 0.8850 - val_loss: 0.3879 - val_accuracy: 0.9135 - lr: 7.5000e-05
# Epoch 4/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3228 - accuracy: 0.8982
# Epoch 4: val_accuracy did not improve from 0.92788
# 260/260 [==============================] - 206s 793ms/step - loss: 0.3228 - accuracy: 0.8982 - val_loss: 0.5295 - val_accuracy: 0.8673 - lr: 7.5000e-05
# Epoch 5/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3156 - accuracy: 0.9071
# Epoch 5: val_accuracy improved from 0.92788 to 0.95865, saving model to /content/drive/MyDrive/Capstone_data/crefv2lmnt_adam4.h5
# 260/260 [==============================] - 225s 866ms/step - loss: 0.3156 - accuracy: 0.9071 - val_loss: 0.1677 - val_accuracy: 0.9587 - lr: 5.6250e-05
# Epoch 6/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2747 - accuracy: 0.9199
# Epoch 6: val_accuracy did not improve from 0.95865
# 260/260 [==============================] - 206s 793ms/step - loss: 0.2747 - accuracy: 0.9199 - val_loss: 0.3013 - val_accuracy: 0.9337 - lr: 5.6250e-05
# Epoch 7/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2344 - accuracy: 0.9254
# Epoch 7: val_accuracy did not improve from 0.95865
# 260/260 [==============================] - 206s 792ms/step - loss: 0.2344 - accuracy: 0.9254 - val_loss: 0.2684 - val_accuracy: 0.9269 - lr: 4.2188e-05
# Epoch 8/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2238 - accuracy: 0.9278
# Epoch 8: val_accuracy did not improve from 0.95865
# 260/260 [==============================] - 206s 793ms/step - loss: 0.2238 - accuracy: 0.9278 - val_loss: 0.1796 - val_accuracy: 0.9500 - lr: 4.2188e-05
# Epoch 9/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2269 - accuracy: 0.9312
# Epoch 9: val_accuracy did not improve from 0.95865
# 260/260 [==============================] - 207s 793ms/step - loss: 0.2269 - accuracy: 0.9312 - val_loss: 0.3082 - val_accuracy: 0.9096 - lr: 3.1641e-05
# Epoch 10/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1963 - accuracy: 0.9411
# Epoch 10: val_accuracy did not improve from 0.95865
# 260/260 [==============================] - 204s 784ms/step - loss: 0.1963 - accuracy: 0.9411 - val_loss: 0.5420 - val_accuracy: 0.9212 - lr: 3.1641e-05
# Epoch 11/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1764 - accuracy: 0.9478
# Epoch 11: val_accuracy did not improve from 0.95865
# 260/260 [==============================] - 206s 792ms/step - loss: 0.1764 - accuracy: 0.9478 - val_loss: 0.3114 - val_accuracy: 0.9317 - lr: 2.3730e-05
# Epoch 12/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1870 - accuracy: 0.9427
# Epoch 12: val_accuracy did not improve from 0.95865
# 260/260 [==============================] - 206s 792ms/step - loss: 0.1870 - accuracy: 0.9427 - val_loss: 0.2469 - val_accuracy: 0.9202 - lr: 2.3730e-05
# Epoch 13/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1667 - accuracy: 0.9483
# Epoch 13: val_accuracy did not improve from 0.95865
# 260/260 [==============================] - 206s 793ms/step - loss: 0.1667 - accuracy: 0.9483 - val_loss: 0.2624 - val_accuracy: 0.9173 - lr: 1.7798e-06
# Epoch 14/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1541 - accuracy: 0.9509
# Epoch 14: val_accuracy did not improve from 0.95865
# 260/260 [==============================] - 206s 792ms/step - loss: 0.1541 - accuracy: 0.9509 - val_loss: 0.2150 - val_accuracy: 0.9337 - lr: 1.7798e-05
# Epoch 14: early stopping
# 66/66 [==============================] - 20s 224ms/step - loss: 0.1685 - accuracy: 0.9578
# <ipython-input-21-fb8dc7c3523f>:54: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   Y_pred = modela.predict_generator(valid_data_generator)
# Classification Report
#               precision    recall  f1-score   support
#
#       Normal       0.89      0.96      0.92       268
#    Pneumonia       0.99      0.96      0.97       775
#
#     accuracy                           0.96      1043
#    macro avg       0.94      0.96      0.95      1043
# weighted avg       0.96      0.96      0.96      1043
# K-Fold5
# Found 4173 validated image filenames belonging to 2 classes.
# Found 1043 validated image filenames belonging to 2 classes.
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/30
# 260/260 [==============================] - ETA: 0s - loss: 0.6651 - accuracy: 0.7582
# Epoch 1: val_accuracy improved from -inf to 0.86442, saving model to /content/drive/MyDrive/Capstone_data/crefv2lmnt_adam5.h5
# 260/260 [==============================] - 390s 936ms/step - loss: 0.6651 - accuracy: 0.7582 - val_loss: 0.4995 - val_accuracy: 0.8644 - lr: 1.0000e-04
# Epoch 2/30
# 260/260 [==============================] - ETA: 0s - loss: 0.4485 - accuracy: 0.8682
# Epoch 2: val_accuracy improved from 0.86442 to 0.93654, saving model to /content/drive/MyDrive/Capstone_data/crefv2lmnt_adam5.h5
# 260/260 [==============================] - 224s 861ms/step - loss: 0.4485 - accuracy: 0.8682 - val_loss: 0.2407 - val_accuracy: 0.9365 - lr: 1.0000e-04
# Epoch 3/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3664 - accuracy: 0.8850
# Epoch 3: val_accuracy did not improve from 0.93654
# 260/260 [==============================] - 206s 790ms/step - loss: 0.3664 - accuracy: 0.8850 - val_loss: 0.9091 - val_accuracy: 0.8567 - lr: 7.5000e-05
# Epoch 4/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3579 - accuracy: 0.8881
# Epoch 4: val_accuracy did not improve from 0.93654
# 260/260 [==============================] - 206s 793ms/step - loss: 0.3579 - accuracy: 0.8881 - val_loss: 0.3164 - val_accuracy: 0.9029 - lr: 7.5000e-05
# Epoch 5/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3224 - accuracy: 0.8978
# Epoch 5: val_accuracy improved from 0.93654 to 0.94231, saving model to /content/drive/MyDrive/Capstone_data/crefv2lmnt_adam5.h5
# 260/260 [==============================] - 224s 862ms/step - loss: 0.3224 - accuracy: 0.8978 - val_loss: 0.2126 - val_accuracy: 0.9423 - lr: 5.6250e-05
# Epoch 6/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3098 - accuracy: 0.9059
# Epoch 6: val_accuracy improved from 0.94231 to 0.94808, saving model to /content/drive/MyDrive/Capstone_data/crefv2lmnt_adam5.h5
# 260/260 [==============================] - 225s 866ms/step - loss: 0.3098 - accuracy: 0.9059 - val_loss: 0.1876 - val_accuracy: 0.9481 - lr: 5.6250e-05
# Epoch 7/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2682 - accuracy: 0.9160
# Epoch 7: val_accuracy improved from 0.94808 to 0.95673, saving model to /content/drive/MyDrive/Capstone_data/crefv2lmnt_adam5.h5
# 260/260 [==============================] - 227s 873ms/step - loss: 0.2682 - accuracy: 0.9160 - val_loss: 0.1398 - val_accuracy: 0.9567 - lr: 4.2188e-05
# Epoch 8/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2520 - accuracy: 0.9168
# Epoch 8: val_accuracy did not improve from 0.95673
# 260/260 [==============================] - 206s 790ms/step - loss: 0.2520 - accuracy: 0.9168 - val_loss: 0.3533 - val_accuracy: 0.8740 - lr: 4.2188e-05
# Epoch 9/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2164 - accuracy: 0.9312
# Epoch 9: val_accuracy did not improve from 0.95673
# 260/260 [==============================] - 207s 794ms/step - loss: 0.2164 - accuracy: 0.9312 - val_loss: 0.2795 - val_accuracy: 0.9077 - lr: 3.1641e-05
# Epoch 10/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2392 - accuracy: 0.9249
# Epoch 10: val_accuracy did not improve from 0.95673
# 260/260 [==============================] - 206s 793ms/step - loss: 0.2392 - accuracy: 0.9249 - val_loss: 0.3692 - val_accuracy: 0.8962 - lr: 3.1641e-05
# Epoch 11/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2163 - accuracy: 0.9317
# Epoch 11: val_accuracy did not improve from 0.95673
# 260/260 [==============================] - 206s 792ms/step - loss: 0.2163 - accuracy: 0.9317 - val_loss: 0.2228 - val_accuracy: 0.9365 - lr: 2.3730e-05
# Epoch 12/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1852 - accuracy: 0.9435
# Epoch 12: val_accuracy did not improve from 0.95673
# 260/260 [==============================] - 206s 792ms/step - loss: 0.1852 - accuracy: 0.9435 - val_loss: 0.3638 - val_accuracy: 0.9106 - lr: 2.3730e-05
# Epoch 13/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1776 - accuracy: 0.9456
# Epoch 13: val_accuracy did not improve from 0.95673
# 260/260 [==============================] - 206s 793ms/step - loss: 0.1776 - accuracy: 0.9456 - val_loss: 0.3981 - val_accuracy: 0.8808 - lr: 1.7798e-05
# Epoch 14/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1804 - accuracy: 0.9483
# Epoch 14: val_accuracy did not improve from 0.95673
# 260/260 [==============================] - 206s 792ms/step - loss: 0.1804 - accuracy: 0.9483 - val_loss: 0.3896 - val_accuracy: 0.8885 - lr: 1.7798e-05
# Epoch 15/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1428 - accuracy: 0.9514
# Epoch 15: val_accuracy did not improve from 0.95673
# 260/260 [==============================] - 206s 792ms/step - loss: 0.1428 - accuracy: 0.9514 - val_loss: 0.2144 - val_accuracy: 0.9404 - lr: 1.3348e-06
# Epoch 16/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1565 - accuracy: 0.9521
# Epoch 16: val_accuracy did not improve from 0.95673
# 260/260 [==============================] - 206s 793ms/step - loss: 0.1565 - accuracy: 0.9521 - val_loss: 0.2515 - val_accuracy: 0.9087 - lr: 1.3348e-05
# Epoch 16: early stopping
# 66/66 [==============================] - 20s 222ms/step - loss: 0.1395 - accuracy: 0.9569
# <ipython-input-21-fb8dc7c3523f>:54: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   Y_pred = modela.predict_generator(valid_data_generator)
# Classification Report
#               precision    recall  f1-score   support
#
#       Normal       0.88      0.96      0.92       268
#    Pneumonia       0.99      0.95      0.97       775
#
#     accuracy                           0.96      1043
#    macro avg       0.93      0.96      0.95      1043
# weighted avg       0.96      0.96      0.96      1043

# %% [markdown]
# # New Section

# %%
l1=max(VALIDATION_ACCURACY[0])
l2=max(VALIDATION_ACCURACY[1])
l3=max(VALIDATION_ACCURACY[2])
l4=max(VALIDATION_ACCURACY[3])
l5=max(VALIDATION_ACCURACY[4])

avg=(l1+l2+l3+l4+l5)/5
avg
# Out:
# 0.9646154046058655
