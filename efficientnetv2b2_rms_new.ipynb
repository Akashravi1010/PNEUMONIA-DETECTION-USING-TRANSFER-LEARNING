# %%
import keras
import tensorflow as tf
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten,Conv2D
from keras.models import Model
from keras import backend as K
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np
import cv2
import sklearn
import os
import seaborn as sns
from google.colab.patches import cv2_imshow
import glob
import keras
from keras.models import Sequential
from tensorflow.python.keras.layers import Dense, Flatten, GlobalAveragePooling2D, Activation, Flatten, Dropout
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import callbacks
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam, SGD

# %%
seed = 10

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
 batch_size=16

# %%
train_path="/content/drive/MyDrive/Capstone_data/Clahe_train"
test_path="/content/drive/MyDrive/Capstone_data/Clahe_test"
val_path="/content/drive/MyDrive/Capstone_data/Clahe_val"

# %%
train_normal = glob.glob(train_path+"/normal/*.jpeg")
train_pneumonia = glob.glob(train_path+"/pneumonia/*.jpeg")

test_normal = glob.glob(test_path+"/normal/*.jpeg")
test_pneumonia = glob.glob(test_path+"/pneumonia/*.jpeg")

val_normal = glob.glob(val_path+"/normal/*.jpeg")
val_pneumonia = glob.glob(val_path+"/pneumonia/*.jpeg")

# %%
train_list = [x for x in train_normal]
train_list.extend([x for x in train_pneumonia])

df_train = pd.DataFrame(np.concatenate([['Normal']*len(train_normal) , ['Pneumonia']*len(train_pneumonia)]), columns = ['class'])
df_train['image'] = [x for x in train_list]

test_list = [x for x in test_normal]
test_list.extend([x for x in test_pneumonia])

df_test = pd.DataFrame(np.concatenate([['Normal']*len(test_normal) , ['Pneumonia']*len(test_pneumonia)]), columns = ['class'])
df_test['image'] = [x for x in test_list]

val_list = [x for x in val_normal]
val_list.extend([x for x in val_pneumonia])

df_val = pd.DataFrame(np.concatenate([['Normal']*len(val_normal) , ['Pneumonia']*len(val_pneumonia)]), columns = ['class'])
df_val['image'] = [x for x in val_list]

# %%
df_train.head()
df_test.head()
df_val.head()
# Out:
#     class                                              image
# 0  Normal  /content/drive/MyDrive/Capstone_data/Clahe_val...
# 1  Normal  /content/drive/MyDrive/Capstone_data/Clahe_val...
# 2  Normal  /content/drive/MyDrive/Capstone_data/Clahe_val...
# 3  Normal  /content/drive/MyDrive/Capstone_data/Clahe_val...
# 4  Normal  /content/drive/MyDrive/Capstone_data/Clahe_val...

# %%
df_train=df_train.sample(frac=1)

# %%
df_train.head()
# Out:
#           class                                              image
# 2876  Pneumonia  /content/drive/MyDrive/Capstone_data/Clahe_tra...
# 1276     Normal  /content/drive/MyDrive/Capstone_data/Clahe_tra...
# 3338  Pneumonia  /content/drive/MyDrive/Capstone_data/Clahe_tra...
# 487      Normal  /content/drive/MyDrive/Capstone_data/Clahe_tra...
# 806      Normal  /content/drive/MyDrive/Capstone_data/Clahe_tra...

# %%
from sklearn.model_selection import KFold, StratifiedKFold
Y = df_train[['class']]

kf = KFold(n_splits = 5)
                         
skf = StratifiedKFold(n_splits = 5, random_state = 7, shuffle = True)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator ,load_img,img_to_array

train_datagen = ImageDataGenerator(
        rescale = 1./255,
        shear_range=10,
        zoom_range=0.3,
        horizontal_flip=True,
        vertical_flip=True,
        brightness_range=[0.5,2.0],
        width_shift_range = 0.2,
        rotation_range=20,
        fill_mode = 'nearest',
)
test_datagen = ImageDataGenerator(
        rescale = 1./255)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Input, Flatten, SeparableConv2D
from tensorflow.keras.layers import GlobalMaxPooling2D,GlobalAveragePooling2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from tensorflow.keras.callbacks import ModelCheckpoint, Callback, EarlyStopping
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.applications import ResNet50, InceptionV3, EfficientNetV2B2
from tensorflow.keras.layers.experimental.preprocessing import Normalization

# %%
df_train.shape
n=5216

# %%
x=len(train_normal)
y=len(train_pneumonia)
s1=(x+y)//batch_size
a=len(test_normal)
b=len(test_pneumonia)
s2=(a+b)//batch_size

# %%
from keras.callbacks import ReduceLROnPlateau
import numpy as np
from keras.callbacks import LearningRateScheduler
from tensorflow.keras.models import load_model
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix ,classification_report
import numpy as np

# %%
from tensorflow import keras
from keras import optimizers
import matplotlib.pyplot as plt

# %%
def printHistory(history, title, epochs):
    f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
    t = f.suptitle(title, fontsize=12)
    f.subplots_adjust(top=0.85, wspace=0.3)

    epoch_list = list(range(1,epochs+1))
    ax1.plot(epoch_list, history.history['accuracy'], label='Train Accuracy')
    ax1.plot(epoch_list, history.history['val_accuracy'], label='Validation Accuracy')
    ax1.set_xticks(np.arange(0, epochs+1, 5))
    ax1.set_ylabel('Accuracy Value')
    ax1.set_xlabel('Epoch')
    ax1.set_title('Accuracy')
    l1 = ax1.legend(loc="best")

    ax2.plot(epoch_list, history.history['loss'], label='Train Loss')
    ax2.plot(epoch_list, history.history['val_loss'], label='Validation Loss')
    ax2.set_xticks(np.arange(0, epochs+1, 5))
    ax2.set_ylabel('Loss Value')
    ax2.set_xlabel('Epoch')
    ax2.set_title('Loss')
    l2 = ax2.legend(loc="best")

# %%
from sklearn.metrics import roc_curve, roc_auc_score
def plot_roc_curve(predictions, labels,auc):
    fpr, tpr, thresholds = roc_curve(labels, predictions) 
    plt.title('Receiver Operating Characteristic (ROC)  Curve',fontsize=14)
    plt.xlim([0, 1])
    plt.ylim([0, 1])
    plt.plot(fpr, tpr, 'g',label = 'AUC Score = %0.2f' % auc)
    plt.plot([0, 1], [0, 1],'r--')
    plt.ylabel('\nTrue Positive Rate (TPR)', fontsize=12)
    plt.xlabel('\nFalse Positive Rate (FPR)', fontsize=12)
    plt.legend()
    plt.grid()
    plt.show()

# %%
def conf(cm,target_names):
    plt.figure(figsize=(5,3))
    sns.set(font_scale=1.2)
    ax = sns.heatmap(cm, annot=True,xticklabels=['H', 'P'], yticklabels=['H', 'P'], cbar=False, cmap='Blues',linewidths=1, linecolor='black', fmt='.0f')
    plt.yticks(rotation=0)
    plt.xlabel('Predicted labels')
    plt.ylabel('True labels')
    ax.xaxis.set_ticks_position('top') 
    plt.title('Confusion matrix')
    plt.show()

# %%
VALIDATION_ACCURACY = []
VALIDATION_LOSS = []
TRAINING_ACCURACY=[]
TRAINING_LOSS=[]

save_dir = '/content/drive/MyDrive/Capstone_data/Clahe_train'
fold_var=1
fine_tune_at=30
t=df_train[['class']]
for train_index, val_index in skf.split(np.zeros(len(Y)),Y):
	print("K-Fold"+str(fold_var))
	training_data = df_train.iloc[train_index]
	validation_data = df_train.iloc[val_index]
	
	train_data_generator = train_datagen.flow_from_dataframe(dataframe=training_data,x_col="image",y_col="class",target_size=(224,224),
                                               batch_size=16,class_mode='categorical',shuffle=True)
	valid_data_generator  = test_datagen.flow_from_dataframe(dataframe=validation_data,x_col="image",y_col="class",target_size=(224,224),
                                               batch_size=16,class_mode='categorical',shuffle=False)
        
 	# CREATE NEW MODEL
	model = Sequential()
	conv_base = EfficientNetV2B2(input_shape=[224,224]+[3], include_top=False, weights='imagenet')
	for layer in conv_base.layers[:fine_tune_at]:
		layer.trainable = False
	x=  conv_base.output
	x = GlobalAveragePooling2D()(x)
	x = BatchNormalization()(x)
	x = Dropout(0.3)(x) 
	x = Dense(512, activation ='relu')(x)
	x = BatchNormalization()(x)
	x = Dropout(0.5)(x)
	x = Dense(2, activation ='sigmoid')(x)
	model = Model(conv_base.input, x)
	reduce_lr = ReduceLROnPlateau(monitor='val_loss',patience=7)
	early_stopping = EarlyStopping(monitor = "val_accuracy",patience = 9,verbose = 1,mode = "max",)
	checkpoint = ModelCheckpoint(monitor = "val_accuracy",filepath = "/content/drive/MyDrive/Capstone_data/crefv2b2mnt_rms"+str(fold_var)+".h5",verbose = 1,save_best_only = True, )
	opt = keras.optimizers.RMSprop(lr=0.0001)
	model.compile(loss = "binary_crossentropy", optimizer =opt, metrics = "accuracy")
	s1=train_data_generator.n//train_data_generator.batch_size
	s2=valid_data_generator.n//valid_data_generator.batch_size
	lr_sched = LearningRateScheduler(lambda epoch: 1e-4 * (0.75 ** np.floor(epoch / 2)))
	history = model.fit(train_data_generator,
    epochs = 30, 
    batch_size = 16,
    validation_data = valid_data_generator,
    validation_steps = s2,
    steps_per_epoch = s1,
    callbacks = [reduce_lr, early_stopping, checkpoint,lr_sched])
	if early_stopping.stopped_epoch==0:
		x=30
	else:
		x=early_stopping.stopped_epoch+1
	printHistory(history,"EfficientNetV2B2_RMSProp",x)
	modela = load_model("/content/drive/MyDrive/Capstone_data/crefv2b2mnt_rms"+str(fold_var)+".h5") 
	
	results = modela.evaluate(valid_data_generator)
	results = dict(zip(model.metrics_names,results))
	Y_pred = modela.predict_generator(valid_data_generator)
	y_pred = np.argmax(Y_pred, axis=1)
	target_names = ['Normal','Pneumonia']
	cm = confusion_matrix(valid_data_generator.classes, y_pred)
	conf(cm,target_names)
	print('Classification Report')
	print(classification_report(valid_data_generator.classes, y_pred, target_names=target_names))
	auc = roc_auc_score(valid_data_generator.classes, y_pred) 
	plot_roc_curve(valid_data_generator.classes, y_pred,auc)
	TRAINING_ACCURACY.append(history.history['accuracy'])
	TRAINING_LOSS.append(history.history['loss'])
	VALIDATION_ACCURACY.append(history.history['val_accuracy'])
	VALIDATION_LOSS.append(history.history['val_loss'])

	fold_var += 1
# Out:
# K-Fold1
# Found 4172 validated image filenames belonging to 2 classes.
# Found 1044 validated image filenames belonging to 2 classes.
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.RMSprop.
# Epoch 1/30
# 260/260 [==============================] - ETA: 0s - loss: 0.7535 - accuracy: 0.7007
# Epoch 1: val_accuracy improved from -inf to 0.88750, saving model to /content/drive/MyDrive/Capstone_data/crefv2b2mnt_rms1.h5
# 260/260 [==============================] - 165s 478ms/step - loss: 0.7535 - accuracy: 0.7007 - val_loss: 0.3139 - val_accuracy: 0.8875 - lr: 1.0000e-04
# Epoch 2/30
# 260/260 [==============================] - ETA: 0s - loss: 0.5404 - accuracy: 0.8231
# Epoch 2: val_accuracy improved from 0.88750 to 0.93462, saving model to /content/drive/MyDrive/Capstone_data/crefv2b2mnt_rms1.h5
# 260/260 [==============================] - 128s 493ms/step - loss: 0.5404 - accuracy: 0.8231 - val_loss: 0.2901 - val_accuracy: 0.9346 - lr: 1.0000e-04
# Epoch 3/30
# 260/260 [==============================] - ETA: 0s - loss: 0.4785 - accuracy: 0.8465
# Epoch 3: val_accuracy improved from 0.93462 to 0.94423, saving model to /content/drive/MyDrive/Capstone_data/crefv2b2mnt_rms1.h5
# 260/260 [==============================] - 121s 467ms/step - loss: 0.4785 - accuracy: 0.8465 - val_loss: 0.1805 - val_accuracy: 0.9442 - lr: 7.5000e-05
# Epoch 4/30
# 260/260 [==============================] - ETA: 0s - loss: 0.4035 - accuracy: 0.8710
# Epoch 4: val_accuracy did not improve from 0.94423
# 260/260 [==============================] - 118s 452ms/step - loss: 0.4035 - accuracy: 0.8710 - val_loss: 0.2602 - val_accuracy: 0.9346 - lr: 7.5000e-05
# Epoch 5/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3858 - accuracy: 0.8778
# Epoch 5: val_accuracy did not improve from 0.94423
# 260/260 [==============================] - 117s 451ms/step - loss: 0.3858 - accuracy: 0.8778 - val_loss: 0.2017 - val_accuracy: 0.9365 - lr: 5.6250e-05
# Epoch 6/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3438 - accuracy: 0.8886
# Epoch 6: val_accuracy improved from 0.94423 to 0.95385, saving model to /content/drive/MyDrive/Capstone_data/crefv2b2mnt_rms1.h5
# 260/260 [==============================] - 120s 462ms/step - loss: 0.3438 - accuracy: 0.8886 - val_loss: 0.1714 - val_accuracy: 0.9538 - lr: 5.6250e-05
# Epoch 7/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3332 - accuracy: 0.8953
# Epoch 7: val_accuracy did not improve from 0.95385
# 260/260 [==============================] - 124s 477ms/step - loss: 0.3332 - accuracy: 0.8953 - val_loss: 0.1951 - val_accuracy: 0.9375 - lr: 4.2188e-05
# Epoch 8/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3066 - accuracy: 0.9023
# Epoch 8: val_accuracy did not improve from 0.95385
# 260/260 [==============================] - 116s 446ms/step - loss: 0.3066 - accuracy: 0.9023 - val_loss: 0.2940 - val_accuracy: 0.9212 - lr: 4.2188e-05
# Epoch 9/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3129 - accuracy: 0.8965
# Epoch 9: val_accuracy did not improve from 0.95385
# 260/260 [==============================] -
saving model to /content/drive/MyDrive/Capstone_data/crefv2b2mnt_rms2.h5
# 260/260 [==============================] - 118s 456ms/step - loss: 0.2435 - accuracy: 0.9163 - val_loss: 0.1348 - val_accuracy: 0.9644 - lr: 1.3348e-05
# Epoch 16/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2608 - accuracy: 0.9136
# Epoch 16: val_accuracy did not improve from 0.96442
# 260/260 [==============================] - 115s 442ms/step - loss: 0.2608 - accuracy: 0.9136 - val_loss: 0.1721 - val_accuracy: 0.9481 - lr: 1.3348e-05
# Epoch 17/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2466 - accuracy: 0.9146
# Epoch 17: val_accuracy did not improve from 0.96442
# 260/260 [==============================] - 115s 443ms/step - loss: 0.2466 - accuracy: 0.9146 - val_loss: 0.1817 - val_accuracy: 0.9471 - lr: 1.0011e-06
# Epoch 18/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2370 - accuracy: 0.9201
# Epoch 18: val_accuracy did not improve from 0.96442
# 260/260 [==============================] - 115s 441ms/step - loss: 0.2370 - accuracy: 0.9201 - val_loss: 0.1738 - val_accuracy: 0.9490 - lr: 1.0011e-05
# Epoch 19/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2432 - accuracy: 0.9158
# Epoch 19: val_accuracy did not improve from 0.96442
# 260/260 [==============================] - 116s 445ms/step - loss: 0.2432 - accuracy: 0.9158 - val_loss: 0.2398 - val_accuracy: 0.9356 - lr: 7.5085e-06
# Epoch 20/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2286 - accuracy: 0.9192
# Epoch 20: val_accuracy did not improve from 0.96442
# 260/260 [==============================] - 114s 440ms/step - loss: 0.2286 - accuracy: 0.9192 - val_loss: 0.1834 - val_accuracy: 0.9500 - lr: 7.5085e-06
# Epoch 21/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2387 - accuracy: 0.9206
# Epoch 21: val_accuracy did not improve from 0.96442
# 260/260 [==============================] - 115s 441ms/step - loss: 0.2387 - accuracy: 0.9206 - val_loss: 0.1792 - val_accuracy: 0.9490 - lr: 5.6314e-06
# Epoch 22/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2436 - accuracy: 0.9225
# Epoch 22: val_accuracy did not improve from 0.96442
# 260/260 [==============================] - 116s 445ms/step - loss: 0.2436 - accuracy: 0.9225 - val_loss: 0.1664 - val_accuracy: 0.9510 - lr: 5.6314e-06
# Epoch 23/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2580 - accuracy: 0.9139
# Epoch 23: val_accuracy did not improve from 0.96442
# 260/260 [==============================] - 116s 448ms/step - loss: 0.2580 - accuracy: 0.9139 - val_loss: 0.1805 - val_accuracy: 0.9481 - lr: 4.2235e-06
# Epoch 24/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2452 - accuracy: 0.9187
# Epoch 24: val_accuracy did not improve from 0.96442
# 260/260 [==============================] - 117s 449ms/step - loss: 0.2452 - accuracy: 0.9187 - val_loss: 0.1828 - val_accuracy: 0.9452 - lr: 4.2235e-07
# Epoch 24: early stopping
# 66/66 [==============================] - 16s 208ms/step - loss: 0.1347 - accuracy: 0.9645
# <ipython-input-43-8c83a3f565af>:58: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   Y_pred = modela.predict_generator(valid_data_generator)
# Classification Report
#               precision    recall  f1-score   support
#
#       Normal       0.89      0.98      0.93       268
#    Pneumonia       0.99      0.96      0.98       775
#
#     accuracy                           0.96      1043
#    macro avg       0.94      0.97      0.95      1043
# weighted avg       0.97      0.96      0.97      1043
# K-Fold3
# Found 4173 validated image filenames belonging to 2 classes.
# Found 1043 validated image filenames belonging to 2 classes.
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.RMSprop.
# Epoch 1/30
# 260/260 [==============================] - ETA: 0s - loss: 0.7637 - accuracy: 0.7060
# Epoch 1: val_accuracy improved from -inf to 0.79808, saving model to /content/drive/MyDrive/Capstone_data/crefv2b2mnt_rms3.h5
# 260/260 [==============================] - 156s 458ms/step - loss: 0.7637 - accuracy: 0.7060 - val_loss: 0.5390 - val_accuracy: 0.7981 - lr: 1.0000e-04
# Epoch 2/30
# 260/260 [==============================] - ETA: 0s - loss: 0.5518 - accuracy: 0.8201
# Epoch 2: val_accuracy improved from 0.79808 to 0.91538, saving model to /content/drive/MyDrive/Capstone_data/crefv2b2mnt_rms3.h5
# 260/260 [==============================] - 119s 457ms/step - loss: 0.5518 - accuracy: 0.8201 - val_loss: 0.3667 - val_accuracy: 0.9154 - lr: 1.0000e-04
# Epoch 3/30
# 260/260 [==============================] - ETA: 0s - loss: 0.
:58: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   Y_pred = modela.predict_generator(valid_data_generator)
# Classification Report
#               precision    recall  f1-score   support
#
#       Normal       0.89      0.95      0.92       268
#    Pneumonia       0.98      0.96      0.97       775
#
#     accuracy                           0.96      1043
#    macro avg       0.94      0.95      0.95      1043
# weighted avg       0.96      0.96      0.96      1043
# K-Fold4
# Found 4173 validated image filenames belonging to 2 classes.
# Found 1043 validated image filenames belonging to 2 classes.
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.RMSprop.
# Epoch 1/30
# 260/260 [==============================] - ETA: 0s - loss: 0.7304 - accuracy: 0.7123
# Epoch 1: val_accuracy improved from -inf to 0.88558, saving model to /content/drive/MyDrive/Capstone_data/crefv2b2mnt_rms4.h5
# 260/260 [==============================] - 158s 458ms/step - loss: 0.7304 - accuracy: 0.7123 - val_loss: 0.4560 - val_accuracy: 0.8856 - lr: 1.0000e-04
# Epoch 2/30
# 260/260 [==============================] - ETA: 0s - loss: 0.5497 - accuracy: 0.8153
# Epoch 2: val_accuracy did not improve from 0.88558
# 260/260 [==============================] - 116s 445ms/step - loss: 0.5497 - accuracy: 0.8153 - val_loss: 0.6248 - val_accuracy: 0.8635 - lr: 1.0000e-04
# Epoch 3/30
# 260/260 [==============================] - ETA: 0s - loss: 0.4558 - accuracy: 0.8624
# Epoch 3: val_accuracy improved from 0.88558 to 0.92404, saving model to /content/drive/MyDrive/Capstone_data/crefv2b2mnt_rms4.h5
# 260/260 [==============================] - 119s 456ms/step - loss: 0.4558 - accuracy: 0.8624 - val_loss: 0.2799 - val_accuracy: 0.9240 - lr: 7.5000e-05
# Epoch 4/30
# 260/260 [==============================] - ETA: 0s - loss: 0.4028 - accuracy: 0.8759
# Epoch 4: val_accuracy improved from 0.92404 to 0.93942, saving model to /content/drive/MyDrive/Capstone_data/crefv2b2mnt_rms4.h5
# 260/260 [==============================] - 121s 465ms/step - loss: 0.4028 - accuracy: 0.8759 - val_loss: 0.2085 - val_accuracy: 0.9394 - lr: 7.5000e-05
# Epoch 5/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3368 - accuracy: 0.8975
# Epoch 5: val_accuracy did not improve from 0.93942
# 260/260 [==============================] - 120s 459ms/step - loss: 0.3368 - accuracy: 0.8975 - val_loss: 0.2811 - val_accuracy: 0.9240 - lr: 5.6250e-05
# Epoch 6/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3371 - accuracy: 0.8939
# Epoch 6: val_accuracy did not improve from 0.93942
# 260/260 [==============================] - 118s 455ms/step - loss: 0.3371 - accuracy: 0.8939 - val_loss: 0.3558 - val_accuracy: 0.9029 - lr: 5.6250e-05
# Epoch 7/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3108 - accuracy: 0.9033
# Epoch 7: val_accuracy did not improve from 0.93942
# 260/260 [==============================] - 120s 460ms/step - loss: 0.3108 - accuracy: 0.9033 - val_loss: 0.2155 - val_accuracy: 0.9346 - lr: 4.2188e-05
# Epoch 8/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2912 - accuracy: 0.9028
# Epoch 8: val_accuracy did not improve from 0.93942
# 260/260 [==============================] - 119s 456ms/step - loss: 0.2912 - accuracy: 0.9028 - val_loss: 0.3213 - val_accuracy: 0.9144 - lr: 4.2188e-05
# Epoch 9/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2735 - accuracy: 0.9115
# Epoch 9: val_accuracy did not improve from 0.93942
# 260/260 [==============================] - 119s 457ms/step - loss: 0.2735 - accuracy: 0.9115 - val_loss: 0.2874 - val_accuracy: 0.9260 - lr: 3.1641e-05
# Epoch 10/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2821 - accuracy: 0.9050
# Epoch 10: val_accuracy did not improve from 0.93942
# 260/260 [==============================] - 119s 459ms/step - loss: 0.2821 - accuracy: 0.9050 - val_loss: 0.2787 - val_accuracy: 0.9192 - lr: 3.1641e-05
# Epoch 11/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2430 - accuracy: 0.9185
# Epoch 11: val_accuracy did not improve from 0.93942
# 260/260 [==============================] - 119s 457ms/step - loss: 0.2430 - accuracy: 0.9185 - val_loss: 0.3056 - val_accuracy: 0.9260 - lr: 2.3730e-06
# Epoch 12/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2534 - accuracy: 0.9204
# Epoch 12: val_accuracy did not improve from 0.93942
# 260/260 [==============================] - 117s 451ms/step - loss: 0.2534 - accuracy: 0.9204 - val_loss: 0.3400 - val_accuracy: 0.9173 - lr: 2.3730e-05
# Epoch 13/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2484 - accuracy: 0.9216
# Epoch 13: val_accuracy did not improve from 0.93942
# 260/260 [==============================] - 116s 445ms/step - loss: 0.2484 - accuracy: 0.9216 - val_loss: 0.3031 - val_accuracy: 0.9308 - lr: 1.7798e-05
# Epoch 13: early stopping
# 66/66 [==============================] - 16s 207ms/step - loss: 0.2084 - accuracy: 0.9396
# <ipython-input-43-8c83a3f565af>:58: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   Y_pred = modela.predict_generator(valid_data_generator)
# Classification Report
#               precision    recall  f1-score   support
#
#       Normal       0.85      0.93      0.89       268
#    Pneumonia       0.97      0.94      0.96       775
#
#     accuracy                           0.94      1043
#    macro avg       0.91      0.94      0.92      1043
# weighted avg       0.94      0.94      0.94      1043
# K-Fold5
# Found 4173 validated image filenames belonging to 2 classes.
# Found 1043 validated image filenames belonging to 2 classes.
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.RMSprop.
# Epoch 1/30
# 260/260 [==============================] - ETA: 0s - loss: 0.7399 - accuracy: 0.7123
# Epoch 1: val_accuracy improved from -inf to 0.89231, saving model to /content/drive/MyDrive/Capstone_data/crefv2b2mnt_rms5.h5
# 260/260 [==============================] - 156s 456ms/step - loss: 0.7399 - accuracy: 0.7123 - val_loss: 0.3302 - val_accuracy: 0.8923 - lr: 1.0000e-04
# Epoch 2/30
# 260/260 [==============================] - ETA: 0s - loss: 0.5859 - accuracy: 0.8013
# Epoch 2: val_accuracy did not improve from 0.89231
# 260/260 [==============================] - 116s 445ms/step - loss: 0.5859 - accuracy: 0.8013 - val_loss: 0.5866 - val_accuracy: 0.8596 - lr: 1.0000e-04
# Epoch 3/30
# 260/260 [==============================] - ETA: 0s - loss: 0.4338 - accuracy: 0.8590
# Epoch 3: val_accuracy improved from 0.89231 to 0.93462, saving model to /content/drive/MyDrive/Capstone_data/crefv2b2mnt_rms5.h5
# 260/260 [==============================] - 117s 448ms/step - loss: 0.4338 - accuracy: 0.8590 - val_loss: 0.3040 - val_accuracy: 0.9346 - lr: 7.5000e-05
# Epoch 4/30
# 260/260 [==============================] - ETA: 0s - loss: 0.4205 - accuracy: 0.8650
# Epoch 4: val_accuracy did not improve from 0.93462
# 260/260 [==============================] - 115s 443ms/step - loss: 0.4205 - accuracy: 0.8650 - val_loss: 0.2447 - val_accuracy: 0.9327 - lr: 7.5000e-05
# Epoch 5/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3890 - accuracy: 0.8785
# Epoch 5: val_accuracy improved from 0.93462 to 0.93654, saving model to /content/drive/MyDrive/Capstone_data/crefv2b2mnt_rms5.h5
# 260/260 [==============================] - 117s 451ms/step - loss: 0.3890 - accuracy: 0.8785 - val_loss: 0.1957 - val_accuracy: 0.9365 - lr: 5.6250e-05
# Epoch 6/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3701 - accuracy: 0.8819
# Epoch 6: val_accuracy improved from 0.93654 to 0.93942, saving model to /content/drive/MyDrive/Capstone_data/crefv2b2mnt_rms5.h5
# 260/260 [==============================] - 117s 451ms/step - loss: 0.3701 - accuracy: 0.8819 - val_loss: 0.2133 - val_accuracy: 0.9394 - lr: 5.6250e-05
# Epoch 7/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3234 - accuracy: 0.8905
# Epoch 7: val_accuracy did not improve from 0.93942
# 260/260 [==============================] - 115s 443ms/step - loss: 0.3234 - accuracy: 0.8905 - val_loss: 0.2232 - val_accuracy: 0.9346 - lr: 4.2188e-05
# Epoch 8/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3124 - accuracy: 0.9028
# Epoch 8: val_accuracy did not improve from 0.93942
# 260/260 [==============================] - 116s 446ms/step - loss: 0.3124 - accuracy: 0.9028 - val_loss: 0.2981 - val_accuracy: 0.9279 - lr: 4.2188e-05
# Epoch 9/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3137 - accuracy: 0.8946
# Epoch 9: val_accuracy improved from 0.93942 to 0.94519, saving model to /content/drive/MyDrive/Capstone_data/crefv2b2mnt_rms5.h5
# 260/260 [==============================] - 117s 451ms/step - loss: 0.3137 - accuracy: 0.8946 - val_loss: 0.1715 - val_accuracy: 0.9452 - lr: 3.1641e-05
# Epoch 10/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3134 - accuracy: 0.8992
# Epoch 10: val_accuracy did not improve from 0.94519
# 260/260 [==============================] - 115s 442ms/step - loss: 0.3134 - accuracy: 0.8992 - val_loss: 0.2652 - val_accuracy: 0.9317 - lr: 3.1641e-05
# Epoch 11/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3005 - accuracy: 0.9083
# Epoch 11: val_accuracy did not improve from 0.94519
# 260/260 [==============================] - 115s 441ms/step - loss: 0.3005 - accuracy: 0.9083 - val_loss: 0.2116 - val_accuracy: 0.9413 - lr: 2.3730e-05
# Epoch 12/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2730 - accuracy: 0.9146
# Epoch 12: val_accuracy did not improve from 0.94519
# 260/260 [==============================] - 115s 442ms/step - loss: 0.2730 - accuracy: 0.9146 - val_loss: 0.4127 - val_accuracy: 0.9087 - lr: 2.3730e-05
# Epoch 13/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2608 - accuracy: 0.9105
# Epoch 13: val_accuracy did not improve from 0.94519
# 260/260 [==============================] - 115s 441ms/step - loss: 0.2608 - accuracy: 0.9105 - val_loss: 0.3421 - val_accuracy: 0.9279 - lr: 1.7798e-05
# Epoch 14/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2617 - accuracy: 0.9144
# Epoch 14: val_accuracy did not improve from 0.94519
# 260/260 [==============================] - 115s 442ms/step - loss: 0.2617 - accuracy: 0.9144 - val_loss: 0.1949 - val_accuracy: 0.9423 - lr: 1.7798e-05
# Epoch 15/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2586 - accuracy: 0.9146
# Epoch 15: val_accuracy did not improve from 0.94519
# 260/260 [==============================] - 115s 443ms/step - loss: 0.2586 - accuracy: 0.9146 - val_loss: 0.2133 - val_accuracy: 0.9423 - lr: 1.3348e-05
# Epoch 16/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2572 - accuracy: 0.9134
# Epoch 16: val_accuracy improved from 0.94519 to 0.95288, saving model to /content/drive/MyDrive/Capstone_data/crefv2b2mnt_rms5.h5
# 260/260 [==============================] - 117s 450ms/step - loss: 0.2572 - accuracy: 0.9134 - val_loss: 0.1729 - val_accuracy: 0.9529 - lr: 1.3348e-06
# Epoch 17/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2767 - accuracy: 0.9083
# Epoch 17: val_accuracy did not improve from 0.95288
# 260/260 [==============================] - 116s 446ms/step - loss: 0.2767 - accuracy: 0.9083 - val_loss: 0.2395 - val_accuracy: 0.9356 - lr: 1.0011e-05
# Epoch 18/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2510 - accuracy: 0.9144
# Epoch 18: val_accuracy did not improve from 0.95288
# 260/260 [==============================] - 115s 441ms/step - loss: 0.2510 - accuracy: 0.9144 - val_loss: 0.2161 - val_accuracy: 0.9433 - lr: 1.0011e-05
# Epoch 19/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2503 - accuracy: 0.9127
# Epoch 19: val_accuracy did not improve from 0.95288
# 260/260 [==============================] - 115s 443ms/step - loss: 0.2503 - accuracy: 0.9127 - val_loss: 0.2431 - val_accuracy: 0.9375 - lr: 7.5085e-06
# Epoch 20/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2432 - accuracy: 0.9242
# Epoch 20: val_accuracy did not improve from 0.95288
# 260/260 [==============================] - 115s 442ms/step - loss: 0.2432 - accuracy: 0.9242 - val_loss: 0.2469 - val_accuracy: 0.9365 - lr: 7.5085e-06
# Epoch 21/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2354 - accuracy: 0.9201
# Epoch 21: val_accuracy did not improve from 0.95288
# 260/260 [==============================] - 116s 446ms/step - loss: 0.2354 - accuracy: 0.9201 - val_loss: 0.2120 - val_accuracy: 0.9404 - lr: 5.6314e-06
# Epoch 22/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2308 - accuracy: 0.9264
# Epoch 22: val_accuracy did not improve from 0.95288
# 260/260 [==============================] - 115s 442ms/step - loss: 0.2308 - accuracy: 0.9264 - val_loss: 0.3171 - val_accuracy: 0.9250 - lr: 5.6314e-06
# Epoch 23/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2460 - accuracy: 0.9139
# Epoch 23: val_accuracy did not improve from 0.95288
# 260/260 [==============================] - 116s 447ms/step - loss: 0.2460 - accuracy: 0.9139 - val_loss: 0.2378 - val_accuracy: 0.9365 - lr: 4.2235e-07
# Epoch 24/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2335 - accuracy: 0.9201
# Epoch 24: val_accuracy did not improve from 0.95288
# 260/260 [==============================] - 115s 442ms/step - loss: 0.2335 - accuracy: 0.9201 - val_loss: 0.3654 - val_accuracy: 0.9183 - lr: 4.2235e-06
# Epoch 25/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2175 - accuracy: 0.9300
# Epoch 25: val_accuracy did not improve from 0.95288
# 260/260 [==============================] - 115s 443ms/step - loss: 0.2175 - accuracy: 0.9300 - val_loss: 0.2763 - val_accuracy: 0.9231 - lr: 3.1676e-06
# Epoch 25: early stopping
# 66/66 [==============================] - 16s 210ms/step - loss: 0.1726 - accuracy: 0.9530
# <ipython-input-43-8c83a3f565af>:58: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   Y_pred = modela.predict_generator(valid_data_generator)
# Classification Report
#               precision    recall  f1-score   support
#
#       Normal       0.87      0.97      0.91       268
#    Pneumonia       0.99      0.95      0.97       775
#
#     accuracy                           0.95      1043
#    macro avg       0.93      0.96      0.94      1043
# weighted avg       0.96      0.95      0.95      1043

# %%
l1=max(VALIDATION_ACCURACY[0])
l2=max(VALIDATION_ACCURACY[1])
l3=max(VALIDATION_ACCURACY[2])
l4=max(VALIDATION_ACCURACY[3])
l5=max(VALIDATION_ACCURACY[4])

avg=(l1+l2+l3+l4+l5)/5
avg
# Out:
# 0.9544230818748474
