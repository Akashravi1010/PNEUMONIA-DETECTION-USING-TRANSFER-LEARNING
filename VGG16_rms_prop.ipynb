# %%
import keras
import tensorflow as tf
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten,Conv2D
from keras.models import Model
from keras import backend as K
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np
import cv2
import sklearn
import os
import seaborn as sns
from google.colab.patches import cv2_imshow
import glob
import keras
from keras.models import Sequential
from tensorflow.python.keras.layers import Dense, Flatten, GlobalAveragePooling2D, Activation, Flatten, Dropout
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import callbacks
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam, SGD

# %%
seed = 10

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
 batch_size=16

# %%
train_path="/content/drive/MyDrive/Capstone_data/Clahe_train"
test_path="/content/drive/MyDrive/Capstone_data/Clahe_test"
val_path="/content/drive/MyDrive/Capstone_data/Clahe_val"

# %%
train_normal = glob.glob(train_path+"/normal/*.jpeg")
train_pneumonia = glob.glob(train_path+"/pneumonia/*.jpeg")

test_normal = glob.glob(test_path+"/normal/*.jpeg")
test_pneumonia = glob.glob(test_path+"/pneumonia/*.jpeg")

val_normal = glob.glob(val_path+"/normal/*.jpeg")
val_pneumonia = glob.glob(val_path+"/pneumonia/*.jpeg")

# %%
train_list = [x for x in train_normal]
train_list.extend([x for x in train_pneumonia])

df_train = pd.DataFrame(np.concatenate([['Normal']*len(train_normal) , ['Pneumonia']*len(train_pneumonia)]), columns = ['class'])
df_train['image'] = [x for x in train_list]

test_list = [x for x in test_normal]
test_list.extend([x for x in test_pneumonia])

df_test = pd.DataFrame(np.concatenate([['Normal']*len(test_normal) , ['Pneumonia']*len(test_pneumonia)]), columns = ['class'])
df_test['image'] = [x for x in test_list]

val_list = [x for x in val_normal]
val_list.extend([x for x in val_pneumonia])

df_val = pd.DataFrame(np.concatenate([['Normal']*len(val_normal) , ['Pneumonia']*len(val_pneumonia)]), columns = ['class'])
df_val['image'] = [x for x in val_list]

# %%
df_train.head()
df_test.head()
df_val.head()
# Out:
#     class                                              image
# 0  Normal  /content/drive/MyDrive/Capstone_data/Clahe_val...
# 1  Normal  /content/drive/MyDrive/Capstone_data/Clahe_val...
# 2  Normal  /content/drive/MyDrive/Capstone_data/Clahe_val...
# 3  Normal  /content/drive/MyDrive/Capstone_data/Clahe_val...
# 4  Normal  /content/drive/MyDrive/Capstone_data/Clahe_val...

# %%
df_train=df_train.sample(frac=1)

# %%
df_train.head()
# Out:
#           class                                              image
# 332      Normal  /content/drive/MyDrive/Capstone_data/Clahe_tra...
# 4823  Pneumonia  /content/drive/MyDrive/Capstone_data/Clahe_tra...
# 198      Normal  /content/drive/MyDrive/Capstone_data/Clahe_tra...
# 5037  Pneumonia  /content/drive/MyDrive/Capstone_data/Clahe_tra...
# 226      Normal  /content/drive/MyDrive/Capstone_data/Clahe_tra...

# %%
from sklearn.model_selection import KFold, StratifiedKFold
Y = df_train[['class']]

kf = KFold(n_splits = 5)
                         
skf = StratifiedKFold(n_splits = 5, random_state = 7, shuffle = True)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator ,load_img,img_to_array

train_datagen = ImageDataGenerator(
        rescale = 1./255,
        shear_range=10,
        zoom_range=0.3,
        horizontal_flip=True,
        vertical_flip=True,
        brightness_range=[0.5,2.0],
        width_shift_range = 0.2,
        rotation_range=20,
        fill_mode = 'nearest',
)
test_datagen = ImageDataGenerator(
        rescale = 1./255)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Input, Flatten, SeparableConv2D
from tensorflow.keras.layers import GlobalMaxPooling2D,GlobalAveragePooling2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from tensorflow.keras.callbacks import ModelCheckpoint, Callback, EarlyStopping
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.applications import ResNet50, InceptionV3, VGG16
from tensorflow.keras.layers.experimental.preprocessing import Normalization

# %%
df_train.shape
n=5216

# %%
x=len(train_normal)
y=len(train_pneumonia)
s1=(x+y)//batch_size
a=len(test_normal)
b=len(test_pneumonia)
s2=(a+b)//batch_size

# %%
from keras.callbacks import ReduceLROnPlateau
import numpy as np
from keras.callbacks import LearningRateScheduler
from tensorflow.keras.models import load_model
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix ,classification_report
import numpy as np

# %%
from tensorflow import keras
from keras import optimizers
import matplotlib.pyplot as plt

# %%
def printHistory(history, title, epochs):
    f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
    t = f.suptitle(title, fontsize=12)
    f.subplots_adjust(top=0.85, wspace=0.3)

    epoch_list = list(range(1,epochs+1))
    ax1.plot(epoch_list, history.history['accuracy'], label='Train Accuracy')
    ax1.plot(epoch_list, history.history['val_accuracy'], label='Validation Accuracy')
    ax1.set_xticks(np.arange(0, epochs+1, 5))
    ax1.set_ylabel('Accuracy Value')
    ax1.set_xlabel('Epoch')
    ax1.set_title('Accuracy')
    l1 = ax1.legend(loc="best")

    ax2.plot(epoch_list, history.history['loss'], label='Train Loss')
    ax2.plot(epoch_list, history.history['val_loss'], label='Validation Loss')
    ax2.set_xticks(np.arange(0, epochs+1, 5))
    ax2.set_ylabel('Loss Value')
    ax2.set_xlabel('Epoch')
    ax2.set_title('Loss')
    l2 = ax2.legend(loc="best")

# %%
from sklearn.metrics import roc_curve, roc_auc_score
def plot_roc_curve(predictions, labels,auc):
    fpr, tpr, thresholds = roc_curve(labels, predictions) 
    plt.title('Receiver Operating Characteristic (ROC)  Curve',fontsize=14)
    plt.xlim([0, 1])
    plt.ylim([0, 1])
    plt.plot(fpr, tpr, 'g',label = 'AUC Score = %0.2f' % auc)
    plt.plot([0, 1], [0, 1],'r--')
    plt.ylabel('\nTrue Positive Rate (TPR)', fontsize=12)
    plt.xlabel('\nFalse Positive Rate (FPR)', fontsize=12)
    plt.legend()
    plt.grid()
    plt.show()

# %%
def conf(cm,target_names):
    plt.figure(figsize=(5,3))
    sns.set(font_scale=1.2)
    ax = sns.heatmap(cm, annot=True,xticklabels=['H', 'P'], yticklabels=['H', 'P'], cbar=False, cmap='Blues',linewidths=1, linecolor='black', fmt='.0f')
    plt.yticks(rotation=0)
    plt.xlabel('Predicted labels')
    plt.ylabel('True labels')
    ax.xaxis.set_ticks_position('top') 
    plt.title('Confusion matrix')
    plt.show()

# %%
from keras.regularizers import l1
from keras.regularizers import l1_l2

# %%
VALIDATION_ACCURACY = []
VALIDATION_LOSS = []
TRAINING_ACCURACY=[]
TRAINING_LOSS=[]

save_dir = '/content/drive/MyDrive/Capstone_data/Clahe_train'
fold_var=1
fine_tune_at=8
t=df_train[['class']]
for train_index, val_index in skf.split(np.zeros(len(Y)),Y):
	print("K-Fold"+str(fold_var))
	training_data = df_train.iloc[train_index]
	validation_data = df_train.iloc[val_index]
	
	train_data_generator = train_datagen.flow_from_dataframe(dataframe=training_data,x_col="image",y_col="class",target_size=(224,224),
                                               batch_size=16,class_mode='categorical',shuffle=True)
	valid_data_generator  = test_datagen.flow_from_dataframe(dataframe=validation_data,x_col="image",y_col="class",target_size=(224,224),
                                               batch_size=16,class_mode='categorical',shuffle=False)
        
 	# CREATE NEW MODEL
	model = Sequential()
	conv_base = VGG16(input_shape=[224,224]+[3], include_top=False, weights='imagenet')
	for layer in conv_base.layers[:fine_tune_at]:
		layer.trainable = False
	x=  conv_base.output
	x = GlobalAveragePooling2D()(x)
	x = BatchNormalization()(x)
	x = Dropout(0.3)(x) 
	x = Dense(512, activation ='relu',kernel_regularizer=l1(1))(x)
	x = BatchNormalization()(x)
	x = Dropout(0.5)(x)
	x = Dense(2, activation ='sigmoid')(x)
	model = Model(conv_base.input, x)
	reduce_lr = ReduceLROnPlateau(monitor='val_loss',patience=7)
	early_stopping = EarlyStopping(monitor = "val_accuracy",patience = 7,verbose = 1,mode = "max",)
	checkpoint = ModelCheckpoint(monitor = "val_accuracy",filepath = "/content/drive/MyDrive/Capstone_data/crvgg16mnt_rms"+str(fold_var)+".h5",verbose = 1,save_best_only = True, )
	opt = keras.optimizers.RMSprop(lr=0.0001)
	model.compile(loss = "binary_crossentropy", optimizer =opt, metrics = "accuracy")
	s1=train_data_generator.n//train_data_generator.batch_size
	s2=valid_data_generator.n//valid_data_generator.batch_size
	lr_sched = LearningRateScheduler(lambda epoch: 1e-4 * (0.75 ** np.floor(epoch / 2)))
	history = model.fit(train_data_generator,
    epochs = 30, 
    batch_size = 16,
    validation_data = valid_data_generator,
    validation_steps = s2,
    steps_per_epoch = s1,
    callbacks = [reduce_lr, early_stopping, checkpoint,lr_sched])
	if early_stopping.stopped_epoch==0:
		x=30
	else:
		x=early_stopping.stopped_epoch+1
	printHistory(history,"VGG16_RMSprop",x)
	modela = load_model("/content/drive/MyDrive/Capstone_data/crvgg16mnt_rms"+str(fold_var)+".h5") 
	
	results = modela.evaluate(valid_data_generator)
	results = dict(zip(model.metrics_names,results))
	Y_pred = modela.predict_generator(valid_data_generator)
	y_pred = np.argmax(Y_pred, axis=1)
	target_names = ['Normal','Pneumonia']
	cm = confusion_matrix(valid_data_generator.classes, y_pred)
	conf(cm,target_names)
	print('Classification Report')
	print(classification_report(valid_data_generator.classes, y_pred, target_names=target_names))
	auc = roc_auc_score(valid_data_generator.classes, y_pred) 
	plot_roc_curve(valid_data_generator.classes, y_pred,auc)
	TRAINING_ACCURACY.append(history.history['accuracy'])
	TRAINING_LOSS.append(history.history['loss'])
	VALIDATION_ACCURACY.append(history.history['val_accuracy'])
	VALIDATION_LOSS.append(history.history['val_loss'])

	fold_var += 1
# Out:
# K-Fold1
# Found 4172 validated image filenames belonging to 2 classes.
# Found 1044 validated image filenames belonging to 2 classes.
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.RMSprop.
# Epoch 1/30
# 260/260 [==============================] - ETA: 0s - loss: 684.2078 - accuracy: 0.7019
# Epoch 1: val_accuracy improved from -inf to 0.86346, saving model to /content/drive/MyDrive/Capstone_data/crvgg16mnt_rms1.h5
# 260/260 [==============================] - 129s 480ms/step - loss: 684.2078 - accuracy: 0.7019 - val_loss: 424.8500 - val_accuracy: 0.8635 - lr: 1.0000e-04
# Epoch 2/30
# 260/260 [==============================] - ETA: 0s - loss: 245.7904 - accuracy: 0.8181
# Epoch 2: val_accuracy did not improve from 0.86346
# 260/260 [==============================] - 123s 472ms/step - loss: 245.7904 - accuracy: 0.8181 - val_loss: 103.7378 - val_accuracy: 0.7423 - lr: 1.0000e-04
# Epoch 3/30
# 260/260 [==============================] - ETA: 0s - loss: 45.4454 - accuracy: 0.8744
# Epoch 3: val_accuracy improved from 0.86346 to 0.94712, saving model to /content/drive/MyDrive/Capstone_data/crvgg16mnt_rms1.h5
# 260/260 [==============================] - 125s 479ms/step - loss: 45.4454 - accuracy: 0.8744 - val_loss: 8.1433 - val_accuracy: 0.9471 - lr: 7.5000e-05
# Epoch 4/30
# 260/260 [==============================] - ETA: 0s - loss: 2.9043 - accuracy: 0.8833
# Epoch 4: val_accuracy did not improve from 0.94712
# 260/260 [==============================] - 122s 469ms/step - loss: 2.9043 - accuracy: 0.8833 - val_loss: 1.7941 - val_accuracy: 0.7856 - lr: 7.5000e-05
# Epoch 5/30
# 260/260 [==============================] - ETA: 0s - loss: 1.1343 - accuracy: 0.9107
# Epoch 5: val_accuracy did not improve from 0.94712
# 260/260 [==============================] - 123s 471ms/step - loss: 1.1343 - accuracy: 0.9107 - val_loss: 1.5362 - val_accuracy: 0.7163 - lr: 5.6250e-05
# Epoch 6/30
# 260/260 [==============================] - ETA: 0s - loss:
- lr: 1.0000e-04
# Epoch 2/30
# 260/260 [==============================] - ETA: 0s - loss: 246.3679 - accuracy: 0.7924
# Epoch 2: val_accuracy did not improve from 0.74327
# 260/260 [==============================] - 116s 445ms/step - loss: 246.3679 - accuracy: 0.7924 - val_loss: 104.5613 - val_accuracy: 0.2885 - lr: 1.0000e-04
# Epoch 3/30
# 260/260 [==============================] - ETA: 0s - loss: 45.3963 - accuracy: 0.8701
# Epoch 3: val_accuracy improved from 0.74327 to 0.85288, saving model to /content/drive/MyDrive/Capstone_data/crvgg16mnt_rms3.h5
# 260/260 [==============================] - 118s 452ms/step - loss: 45.3963 - accuracy: 0.8701 - val_loss: 8.0895 - val_accuracy: 0.8529 - lr: 7.5000e-05
# Epoch 4/30
# 260/260 [==============================] - ETA: 0s - loss: 2.6843 - accuracy: 0.8966
# Epoch 4: val_accuracy did not improve from 0.85288
# 260/260 [==============================] - 118s 455ms/step - loss: 2.6843 - accuracy: 0.8966 - val_loss: 4.5891 - val_accuracy: 0.3702 - lr: 7.5000e-05
# Epoch 5/30
# 260/260 [==============================] - ETA: 0s - loss: 1.1373 - accuracy: 0.9019
# Epoch 5: val_accuracy did not improve from 0.85288
# 260/260 [==============================] - 117s 451ms/step - loss: 1.1373 - accuracy: 0.9019 - val_loss: 1.3686 - val_accuracy: 0.8135 - lr: 5.6250e-05
# Epoch 6/30
# 260/260 [==============================] - ETA: 0s - loss: 1.0894 - accuracy: 0.9091
# Epoch 6: val_accuracy did not improve from 0.85288
# 260/260 [==============================] - 117s 449ms/step - loss: 1.0894 - accuracy: 0.9091 - val_loss: 2.6270 - val_accuracy: 0.4038 - lr: 5.6250e-05
# Epoch 7/30
# 260/260 [==============================] - ETA: 0s - loss: 0.8965 - accuracy: 0.9083
# Epoch 7: val_accuracy did not improve from 0.85288
# 260/260 [==============================] - 117s 451ms/step - loss: 0.8965 - accuracy: 0.9083 - val_loss: 1.1734 - val_accuracy: 0.8250 - lr: 4.2188e-05
# Epoch 8/30
# 260/260 [==============================] - ETA: 0s - loss: 0.8923 - accuracy: 0.9083
# Epoch 8: val_accuracy did not improve from 0.85288
# 260/260 [==============================] - 116s 447ms/step - loss: 0.8923 - accuracy: 0.9083 - val_loss: 1.5203 - val_accuracy: 0.7298 - lr: 4.2188e-05
# Epoch 9/30
# 260/260 [==============================] - ETA: 0s - loss: 0.7066 - accuracy: 0.9276
# Epoch 9: val_accuracy improved from 0.85288 to 0.87019, saving model to /content/drive/MyDrive/Capstone_data/crvgg16mnt_rms3.h5
# 260/260 [==============================] - 117s 450ms/step - loss: 0.7066 - accuracy: 0.9276 - val_loss: 0.9399 - val_accuracy: 0.8702 - lr: 3.1641e-05
# Epoch 10/30
# 260/260 [==============================] - ETA: 0s - loss: 0.7230 - accuracy: 0.9175
# Epoch 10: val_accuracy did not improve from 0.87019
# 260/260 [==============================] - 116s 446ms/step - loss: 0.7230 - accuracy: 0.9175 - val_loss: 0.9953 - val_accuracy: 0.8577 - lr: 3.1641e-05
# Epoch 11/30
# 260/260 [==============================] - ETA: 0s - loss: 0.6041 - accuracy: 0.9237
# Epoch 11: val_accuracy did not improve from 0.87019
# 260/260 [==============================] - 116s 445ms/step - loss: 0.6041 - accuracy: 0.9237 - val_loss: 1.0702 - val_accuracy: 0.8067 - lr: 2.3730e-05
# Epoch 12/30
# 260/260 [==============================] - ETA: 0s - loss: 0.5923 - accuracy: 0.9259
# Epoch 12: val_accuracy did not improve from 0.87019
# 260/260 [==============================] - 116s 444ms/step - loss: 0.5923 - accuracy: 0.9259 - val_loss: 0.9163 - val_accuracy: 0.8260 - lr: 2.3730e-05
# Epoch 13/30
# 260/260 [==============================] - ETA: 0s - loss: 0.5118 - accuracy: 0.9230
# Epoch 13: val_accuracy improved from 0.87019 to 0.97115, saving model to /content/drive/MyDrive/Capstone_data/crvgg16mnt_rms3.h5
# 260/260 [==============================] - 118s 452ms/step - loss: 0.5118 - accuracy: 0.9230 - val_loss: 0.5202 - val_accuracy: 0.9712 - lr: 1.7798e-05
# Epoch 14/30
# 260/260 [==============================] - ETA: 0s - loss: 0.4857 - accuracy: 0.9406
# Epoch 14: val_accuracy did not improve from 0.97115
# 260/260 [==============================] - 116s 445ms/step - loss: 0.4857 - accuracy: 0.9406 - val_loss: 0.4846 - val_accuracy: 0.9692 - lr: 1.7798e-05
# Epoch 15/30
# 260/260 [==============================] - ETA: 0s - loss: 0.4287 - accuracy: 0.9389
# Epoch 15: val_accuracy did not improve from 0.97115
# 260/260 [==============================] - 116s 446ms/step - loss: 0.4287 - accuracy: 0.9389 - val_loss: 0.6465 - val_accuracy: 0.8192 - lr: 1.3348e-05
# Epoch 16/30
# 260/260 [==============================] - ETA: 0s - loss: 0.4301 - accuracy: 0.9365
# Epoch 16: val_accuracy did not improve from 0.97115
# 260/260 [==============================] - 115s 442ms/step - loss: 0.4301 - accuracy: 0.9365 - val_loss: 0.4213 - val_accuracy: 0.9702 - lr: 1.3348e-05
# Epoch 17/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3731 - accuracy: 0.9432
# Epoch 17: val_accuracy did not improve from 0.97115
# 260/260 [==============================] - 116s 445ms/step - loss: 0.3731 - accuracy: 0.9432 - val_loss: 0.4321 - val_accuracy: 0.9298 - lr: 1.0011e-05
# Epoch 18/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3609 - accuracy: 0.9464
# Epoch 18: val_accuracy did not improve from 0.97115
# 260/260 [==============================] - 117s 448ms/step - loss: 0.3609 - accuracy: 0.9464 - val_loss: 0.6578 - val_accuracy: 0.8740 - lr: 1.0011e-05
# Epoch 19/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3341 - accuracy: 0.9435
# Epoch 19: val_accuracy did not improve from 0.97115
# 260/260 [==============================] - 117s 451ms/step - loss: 0.3341 - accuracy: 0.9435 - val_loss: 0.3882 - val_accuracy: 0.9308 - lr: 7.5085e-06
# Epoch 20/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3372 - accuracy: 0.9423
# Epoch 20: val_accuracy did not improve from 0.97115
# 260/260 [==============================] - 117s 451ms/step - loss: 0.3372 - accuracy: 0.9423 - val_loss: 0.3453 - val_accuracy: 0.9471 - lr: 7.5085e-06
# Epoch 20: early stopping
# 66/66 [==============================] - 15s 226ms/step - loss: 0.5200 - accuracy: 0.9712
# <ipython-input-29-05ced6527f74>:58: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   Y_pred = modela.predict_generator(valid_data_generator)
# Classification Report
#               precision    recall  f1-score   support
#
#       Normal       0.93      0.96      0.95       268
#    Pneumonia       0.99      0.97      0.98       775
#
#     accuracy                           0.97      1043
#    macro avg       0.96      0.97      0.96      1043
# weighted avg       0.97      0.97      0.97      1043
# K-Fold4
# Found 4173 validated image filenames belonging to 2 classes.
# Found 1043 validated image filenames belonging to 2 classes.
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.RMSprop.
# Epoch 1/30
# 260/260 [==============================] - ETA: 0s - loss: 684.6932 - accuracy: 0.6866
# Epoch 1: val_accuracy improved from -inf to 0.74615, saving model to /content/drive/MyDrive/Capstone_data/crvgg16mnt_rms4.h5
# 260/260 [==============================] - 119s 447ms/step - loss: 684.6932 - accuracy: 0.6866 - val_loss: 425.5422 - val_accuracy: 0.7462 - lr: 1.0000e-04
# Epoch 2/30
# 260/260 [==============================] - ETA: 0s - loss: 245.8786 - accuracy: 0.8150
# Epoch 2: val_accuracy improved from 0.74615 to 0.87788, saving model to /content/drive/MyDrive/Capstone_data/crvgg16mnt_rms4.h5
# 260/260 [==============================] - 119s 459ms/step - loss: 245.8786 - accuracy: 0.8150 - val_loss: 105.4887 - val_accuracy: 0.8779 - lr: 1.0000e-04
# Epoch 3/30
# 260/260 [==============================] - ETA: 0s - loss: 45.7639 - accuracy: 0.8667
# Epoch 3: val_accuracy did not improve from 0.87788
# 260/260 [==============================] - 122s 468ms/step - loss: 45.7639 - accuracy: 0.8667 - val_loss: 12.1778 - val_accuracy: 0.2577 - lr: 7.5000e-05
# Epoch 4/30
# 260/260 [==============================] - ETA: 0s - loss: 2.9307 - accuracy: 0.8884
# Epoch 4: val_accuracy did not improve from 0.87788
# 260/260 [==============================] - 117s 448ms/step - loss: 2.9307 - accuracy: 0.8884 - val_loss: 3.2201 - val_accuracy: 0.2577 - lr: 7.5000e-05
# Epoch 5/30
# 260/260 [==============================] - ETA: 0s - loss:
# Found 4173 validated image filenames belonging to 2 classes.
# Found 1043 validated image filenames belonging to 2 classes.
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.RMSprop.
# Epoch 1/30
# 260/260 [==============================] - ETA: 0s - loss: 686.1195 - accuracy: 0.6738
# Epoch 1: val_accuracy improved from -inf to 0.25673, saving model to /content/drive/MyDrive/Capstone_data/crvgg16mnt_rms5.h5
# 260/260 [==============================] - 120s 448ms/step - loss: 686.1195 - accuracy: 0.6738 - val_loss: 429.3639 - val_accuracy: 0.2567 - lr: 1.0000e-04
# Epoch 2/30
# 260/260 [==============================] - ETA: 0s - loss: 244.9177 - accuracy: 0.8030
# Epoch 2: val_accuracy improved from 0.25673 to 0.74327, saving model to /content/drive/MyDrive/Capstone_data/crvgg16mnt_rms5.h5
# 260/260 [==============================] - 120s 463ms/step - loss: 244.9177 - accuracy: 0.8030 - val_loss: 109.7167 - val_accuracy: 0.7433 - lr: 1.0000e-04
# Epoch 3/30
# 260/260 [==============================] - ETA: 0s - loss: 42.9529 - accuracy: 0.8711
# Epoch 3: val_accuracy did not improve from 0.74327
# 260/260 [==============================] - 117s 448ms/step - loss: 42.9529 - accuracy: 0.8711 - val_loss: 9.7100 - val_accuracy: 0.2567 - lr: 7.5000e-05
# Epoch 4/30
# 260/260 [==============================] - ETA: 0s - loss: 2.3073 - accuracy: 0.8920
# Epoch 4: val_accuracy improved from 0.74327 to 0.82500, saving model to /content/drive/MyDrive/Capstone_data/crvgg16mnt_rms5.h5
# 260/260 [==============================] - 117s 449ms/step - loss: 2.3073 - accuracy: 0.8920 - val_loss: 1.7301 - val_accuracy: 0.8250 - lr: 7.5000e-05
# Epoch 5/30
# 260/260 [==============================] - ETA: 0s - loss: 1.1627 - accuracy: 0.8978
# Epoch 5: val_accuracy improved from 0.82500 to 0.94519, saving model to /content/drive/MyDrive/Capstone_data/crvgg16mnt_rms5.h5
# 260/260 [==============================] - 117s 450ms/step - loss: 1.1627 - accuracy: 0.8978 - val_loss: 1.2133 - val_accuracy: 0.9452 - lr: 5.6250e-05
# Epoch 6/30
# 260/260 [==============================] - ETA: 0s - loss: 1.0983 - accuracy: 0.9006
# Epoch 6: val_accuracy improved from 0.94519 to 0.97019, saving model to /content/drive/MyDrive/Capstone_data/crvgg16mnt_rms5.h5
# 260/260 [==============================] - 116s 447ms/step - loss: 1.0983 - accuracy: 0.9006 - val_loss: 1.1360 - val_accuracy: 0.9702 - lr: 5.6250e-05
# Epoch 7/30
# 260/260 [==============================] - ETA: 0s - loss: 0.8744 - accuracy: 0.9117
# Epoch 7: val_accuracy did not improve from 0.97019
# 260/260 [==============================] - 115s 441ms/step - loss: 0.8744 - accuracy: 0.9117 - val_loss: 1.6512 - val_accuracy: 0.6702 - lr: 4.2188e-05
# Epoch 8/30
# 260/260 [==============================] - ETA: 0s - loss: 0.8629 - accuracy: 0.9160
# Epoch 8: val_accuracy did not improve from 0.97019
# 260/260 [==============================] - 115s 443ms/step - loss: 0.8629 - accuracy: 0.9160 - val_loss: 0.9889 - val_accuracy: 0.9462 - lr: 4.2188e-05
# Epoch 9/30
# 260/260 [==============================] - ETA: 0s - loss: 0.7128 - accuracy: 0.9204
# Epoch 9: val_accuracy did not improve from 0.97019
# 260/260 [==============================] - 115s 443ms/step - loss: 0.7128 - accuracy: 0.9204 - val_loss: 1.6204 - val_accuracy: 0.6183 - lr: 3.1641e-05
# Epoch 10/30
# 260/260 [==============================] - ETA: 0s - loss: 0.7235 - accuracy: 0.9124
# Epoch 10: val_accuracy improved from 0.97019 to 0.97212, saving model to /content/drive/MyDrive/Capstone_data/crvgg16mnt_rms5.h5
# 260/260 [==============================] - 116s 447ms/step - loss: 0.7235 - accuracy: 0.9124 - val_loss: 0.7345 - val_accuracy: 0.9721 - lr: 3.1641e-05
# Epoch 11/30
# 260/260 [==============================] - ETA: 0s - loss: 0.5904 - accuracy: 0.9269
# Epoch 11: val_accuracy did not improve from 0.97212
# 260/260 [==============================] - 116s 444ms/step - loss: 0.5904 - accuracy: 0.9269 - val_loss: 0.6814 - val_accuracy: 0.9644 - lr: 2.3730e-05
# Epoch 12/30
# 260/260 [==============================] - ETA: 0s - loss: 0.5855 - accuracy: 0.9293
# Epoch 12: val_accuracy did not improve from 0.97212
# 260/260 [==============================] - 117s 450ms/step - loss: 0.5855 - accuracy: 0.9293 - val_loss: 1.0904 - val_accuracy: 0.7856 - lr: 2.3730e-05
# Epoch 13/30
# 260/260 [==============================] - ETA: 0s - loss: 0.4986 - accuracy: 0.9288
# Epoch 13: val_accuracy did not improve from 0.97212
# 260/260 [==============================] - 117s 451ms/step - loss: 0.4986 - accuracy: 0.9288 - val_loss: 0.7555 - val_accuracy: 0.8442 - lr: 1.7798e-05
# Epoch 14/30
# 260/260 [==============================] - ETA: 0s - loss: 0.5107 - accuracy: 0.9225
# Epoch 14: val_accuracy did not improve from 0.97212
# 260/260 [==============================] - 118s 453ms/step - loss: 0.5107 - accuracy: 0.9225 - val_loss: 0.7411 - val_accuracy: 0.8779 - lr: 1.7798e-05
# Epoch 15/30
# 260/260 [==============================] - ETA: 0s - loss: 0.4347 - accuracy: 0.9348
# Epoch 15: val_accuracy improved from 0.97212 to 0.98077, saving model to /content/drive/MyDrive/Capstone_data/crvgg16mnt_rms5.h5
# 260/260 [==============================] - 120s 463ms/step - loss: 0.4347 - accuracy: 0.9348 - val_loss: 0.4171 - val_accuracy: 0.9808 - lr: 1.3348e-05
# Epoch 16/30
# 260/260 [==============================] - ETA: 0s - loss: 0.4210 - accuracy: 0.9363
# Epoch 16: val_accuracy did not improve from 0.98077
# 260/260 [==============================] - 118s 452ms/step - loss: 0.4210 - accuracy: 0.9363 - val_loss: 0.3964 - val_accuracy: 0.9798 - lr: 1.3348e-05
# Epoch 17/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3775 - accuracy: 0.9367
# Epoch 17: val_accuracy did not improve from 0.98077
# 260/260 [==============================] - 119s 456ms/step - loss: 0.3775 - accuracy: 0.9367 - val_loss: 0.7153 - val_accuracy: 0.8385 - lr: 1.0011e-05
# Epoch 18/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3751 - accuracy: 0.9408
# Epoch 18: val_accuracy did not improve from 0.98077
# 260/260 [==============================] - 118s 453ms/step - loss: 0.3751 - accuracy: 0.9408 - val_loss: 0.4392 - val_accuracy: 0.9558 - lr: 1.0011e-05
# Epoch 19/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3326 - accuracy: 0.9447
# Epoch 19: val_accuracy did not improve from 0.98077
# 260/260 [==============================] - 118s 452ms/step - loss: 0.3326 - accuracy: 0.9447 - val_loss: 0.5003 - val_accuracy: 0.8865 - lr: 7.5085e-06
# Epoch 20/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3303 - accuracy: 0.9468
# Epoch 20: val_accuracy did not improve from 0.98077
# 260/260 [==============================] - 119s 457ms/step - loss: 0.3303 - accuracy: 0.9468 - val_loss: 0.4226 - val_accuracy: 0.9135 - lr: 7.5085e-06
# Epoch 21/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3087 - accuracy: 0.9452
# Epoch 21: val_accuracy did not improve from 0.98077
# 260/260 [==============================] - 120s 460ms/step - loss: 0.3087 - accuracy: 0.9452 - val_loss: 0.4090 - val_accuracy: 0.8971 - lr: 5.6314e-06
# Epoch 22/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3089 - accuracy: 0.9425
# Epoch 22: val_accuracy did not improve from 0.98077
# 260/260 [==============================] - 119s 456ms/step - loss: 0.3089 - accuracy: 0.9425 - val_loss: 0.6873 - val_accuracy: 0.7894 - lr: 5.6314e-06
# Epoch 22: early stopping
# 66/66 [==============================] - 15s 219ms/step - loss: 0.4183 - accuracy: 0.9799
# <ipython-input-29-05ced6527f74>:58: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   Y_pred = modela.predict_generator(valid_data_generator)
# Classification Report
#               precision    recall  f1-score   support
#
#       Normal       0.96      0.96      0.96       268
#    Pneumonia       0.99      0.99      0.99       775
#
#     accuracy                           0.98      1043
#    macro avg       0.97      0.97      0.97      1043
# weighted avg       0.98      0.98      0.98      1043

# %%
l1=max(VALIDATION_ACCURACY[0])
l2=max(VALIDATION_ACCURACY[1])
l3=max(VALIDATION_ACCURACY[2])
l4=max(VALIDATION_ACCURACY[3])
l5=max(VALIDATION_ACCURACY[4])

avg=(l1+l2+l3+l4+l5)/5
avg
# Out:
# 0.9648076891899109
