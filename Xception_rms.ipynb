# %%
import keras
import tensorflow as tf
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten,Conv2D
from keras.models import Model
from keras import backend as K
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np
import cv2
import sklearn
import os
import seaborn as sns
from google.colab.patches import cv2_imshow
import glob
import keras
from keras.models import Sequential
from tensorflow.python.keras.layers import Dense, Flatten, GlobalAveragePooling2D, Activation, Flatten, Dropout
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import callbacks
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam, SGD

# %%
seed = 10

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
 batch_size=16

# %%
train_path="/content/drive/MyDrive/Capstone_data/Clahe_train"
test_path="/content/drive/MyDrive/Capstone_data/Clahe_test"
val_path="/content/drive/MyDrive/Capstone_data/Clahe_val"

# %%
train_normal = glob.glob(train_path+"/normal/*.jpeg")
train_pneumonia = glob.glob(train_path+"/pneumonia/*.jpeg")

test_normal = glob.glob(test_path+"/normal/*.jpeg")
test_pneumonia = glob.glob(test_path+"/pneumonia/*.jpeg")

val_normal = glob.glob(val_path+"/normal/*.jpeg")
val_pneumonia = glob.glob(val_path+"/pneumonia/*.jpeg")

# %%
train_list = [x for x in train_normal]
train_list.extend([x for x in train_pneumonia])

df_train = pd.DataFrame(np.concatenate([['Normal']*len(train_normal) , ['Pneumonia']*len(train_pneumonia)]), columns = ['class'])
df_train['image'] = [x for x in train_list]

test_list = [x for x in test_normal]
test_list.extend([x for x in test_pneumonia])

df_test = pd.DataFrame(np.concatenate([['Normal']*len(test_normal) , ['Pneumonia']*len(test_pneumonia)]), columns = ['class'])
df_test['image'] = [x for x in test_list]

val_list = [x for x in val_normal]
val_list.extend([x for x in val_pneumonia])

df_val = pd.DataFrame(np.concatenate([['Normal']*len(val_normal) , ['Pneumonia']*len(val_pneumonia)]), columns = ['class'])
df_val['image'] = [x for x in val_list]

# %%
df_train.head()
df_test.head()
df_val.head()
# Out:
#     class                                              image
# 0  Normal  /content/drive/MyDrive/Capstone_data/Clahe_val...
# 1  Normal  /content/drive/MyDrive/Capstone_data/Clahe_val...
# 2  Normal  /content/drive/MyDrive/Capstone_data/Clahe_val...
# 3  Normal  /content/drive/MyDrive/Capstone_data/Clahe_val...
# 4  Normal  /content/drive/MyDrive/Capstone_data/Clahe_val...

# %%
df_train=df_train.sample(frac=1)

# %%
df_train.head()
# Out:
#           class                                              image
# 2573  Pneumonia  /content/drive/MyDrive/Capstone_data/Clahe_tra...
# 3986  Pneumonia  /content/drive/MyDrive/Capstone_data/Clahe_tra...
# 3501  Pneumonia  /content/drive/MyDrive/Capstone_data/Clahe_tra...
# 750      Normal  /content/drive/MyDrive/Capstone_data/Clahe_tra...
# 343      Normal  /content/drive/MyDrive/Capstone_data/Clahe_tra...

# %%
from sklearn.model_selection import KFold, StratifiedKFold
Y = df_train[['class']]

kf = KFold(n_splits = 5)
                         
skf = StratifiedKFold(n_splits = 5, random_state = 7, shuffle = True)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator ,load_img,img_to_array

train_datagen = ImageDataGenerator(
        rescale = 1./255,
        shear_range=10,
        zoom_range=0.3,
        horizontal_flip=True,
        vertical_flip=True,
        brightness_range=[0.5,2.0],
        width_shift_range = 0.2,
        rotation_range=20,
        fill_mode = 'nearest',
)
test_datagen = ImageDataGenerator(
        rescale = 1./255)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Input, Flatten, SeparableConv2D
from tensorflow.keras.layers import GlobalMaxPooling2D,GlobalAveragePooling2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from tensorflow.keras.callbacks import ModelCheckpoint, Callback, EarlyStopping
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.applications import ResNet50, InceptionV3, Xception
from tensorflow.keras.layers.experimental.preprocessing import Normalization

# %%
df_train.shape
n=5216

# %%
x=len(train_normal)
y=len(train_pneumonia)
s1=(x+y)//batch_size
a=len(test_normal)
b=len(test_pneumonia)
s2=(a+b)//batch_size

# %%
from keras.callbacks import ReduceLROnPlateau
import numpy as np
from keras.callbacks import LearningRateScheduler
from tensorflow.keras.models import load_model
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix ,classification_report
import numpy as np

# %%
from tensorflow import keras
from keras import optimizers
import matplotlib.pyplot as plt

# %%
def printHistory(history, title, epochs):
    f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
    t = f.suptitle(title, fontsize=12)
    f.subplots_adjust(top=0.85, wspace=0.3)

    epoch_list = list(range(1,epochs+1))
    ax1.plot(epoch_list, history.history['accuracy'], label='Train Accuracy')
    ax1.plot(epoch_list, history.history['val_accuracy'], label='Validation Accuracy')
    ax1.set_xticks(np.arange(0, epochs+1, 5))
    ax1.set_ylabel('Accuracy Value')
    ax1.set_xlabel('Epoch')
    ax1.set_title('Accuracy')
    l1 = ax1.legend(loc="best")

    ax2.plot(epoch_list, history.history['loss'], label='Train Loss')
    ax2.plot(epoch_list, history.history['val_loss'], label='Validation Loss')
    ax2.set_xticks(np.arange(0, epochs+1, 5))
    ax2.set_ylabel('Loss Value')
    ax2.set_xlabel('Epoch')
    ax2.set_title('Loss')
    l2 = ax2.legend(loc="best")

# %%
from sklearn.metrics import roc_curve, roc_auc_score
def plot_roc_curve(predictions, labels,auc):
    fpr, tpr, thresholds = roc_curve(labels, predictions) 
    plt.title('Receiver Operating Characteristic (ROC)  Curve',fontsize=14)
    plt.xlim([0, 1])
    plt.ylim([0, 1])
    plt.plot(fpr, tpr, 'g',label = 'AUC Score = %0.2f' % auc)
    plt.plot([0, 1], [0, 1],'r--')
    plt.ylabel('\nTrue Positive Rate (TPR)', fontsize=12)
    plt.xlabel('\nFalse Positive Rate (FPR)', fontsize=12)
    plt.legend()
    plt.grid()
    plt.show()

# %%
def conf(cm,target_names):
    plt.figure(figsize=(5,3))
    sns.set(font_scale=1.2)
    ax = sns.heatmap(cm, annot=True,xticklabels=['H', 'P'], yticklabels=['H', 'P'], cbar=False, cmap='Blues',linewidths=1, linecolor='black', fmt='.0f')
    plt.yticks(rotation=0)
    plt.xlabel('Predicted labels')
    plt.ylabel('True labels')
    ax.xaxis.set_ticks_position('top') 
    plt.title('Confusion matrix')
    plt.show()

# %%
VALIDATION_ACCURACY = []
VALIDATION_LOSS = []
TRAINING_ACCURACY=[]
TRAINING_LOSS=[]

save_dir = '/content/drive/MyDrive/Capstone_data/Clahe_train'
fold_var=1
fine_tune_at=30
t=df_train[['class']]
for train_index, val_index in skf.split(np.zeros(len(Y)),Y):
	print("K-Fold"+str(fold_var))
	training_data = df_train.iloc[train_index]
	validation_data = df_train.iloc[val_index]
	
	train_data_generator = train_datagen.flow_from_dataframe(dataframe=training_data,x_col="image",y_col="class",target_size=(224,224),
                                               batch_size=16,class_mode='categorical',shuffle=True)
	valid_data_generator  = test_datagen.flow_from_dataframe(dataframe=validation_data,x_col="image",y_col="class",target_size=(224,224),
                                               batch_size=16,class_mode='categorical',shuffle=False)
        
 	# CREATE NEW MODEL
	model = Sequential()
	conv_base =Xception(input_shape=[224,224]+[3], include_top=False, weights='imagenet')
	for layer in conv_base.layers[:fine_tune_at]:
		layer.trainable = False
	x=  conv_base.output
	x = GlobalAveragePooling2D()(x)
	x = BatchNormalization()(x)
	x = Dropout(0.3)(x) 
	x = Dense(512, activation ='relu')(x)
	x = BatchNormalization()(x)
	x = Dropout(0.5)(x)
	x = Dense(2, activation ='sigmoid')(x)
	model = Model(conv_base.input, x)
	reduce_lr = ReduceLROnPlateau(monitor='val_loss',patience=7)
	early_stopping = EarlyStopping(monitor = "val_accuracy",patience = 9,verbose = 1,mode = "max",)
	checkpoint = ModelCheckpoint(monitor = "val_accuracy",filepath = "/content/drive/MyDrive/Capstone_data/crxcepmnt_rms"+str(fold_var)+".h5",verbose = 1,save_best_only = True, )
	opt = keras.optimizers.RMSprop(lr=0.0001)
	model.compile(loss = "binary_crossentropy", optimizer =opt, metrics = "accuracy")
	s1=train_data_generator.n//train_data_generator.batch_size
	s2=valid_data_generator.n//valid_data_generator.batch_size
	lr_sched = LearningRateScheduler(lambda epoch: 1e-4 * (0.75 ** np.floor(epoch / 2)))
	history = model.fit(train_data_generator,
    epochs = 30, 
    batch_size = 16,
    validation_data = valid_data_generator,
    validation_steps = s2,
    steps_per_epoch = s1,
    callbacks = [reduce_lr, early_stopping, checkpoint,lr_sched])
	if early_stopping.stopped_epoch==0:
		x=30
	else:
		x=early_stopping.stopped_epoch+1
	printHistory(history,"Xception_RMSprop",x)
	modela = load_model("/content/drive/MyDrive/Capstone_data/crxcepmnt_rms"+str(fold_var)+".h5") 
	
	results = modela.evaluate(valid_data_generator)
	results = dict(zip(model.metrics_names,results))
	Y_pred = modela.predict_generator(valid_data_generator)
	y_pred = np.argmax(Y_pred, axis=1)
	target_names = ['Normal','Pneumonia']
	cm = confusion_matrix(valid_data_generator.classes, y_pred)
	conf(cm,target_names)
	print('Classification Report')
	print(classification_report(valid_data_generator.classes, y_pred, target_names=target_names))
	auc = roc_auc_score(valid_data_generator.classes, y_pred) 
	plot_roc_curve(valid_data_generator.classes, y_pred,auc)
	TRAINING_ACCURACY.append(history.history['accuracy'])
	TRAINING_LOSS.append(history.history['loss'])
	VALIDATION_ACCURACY.append(history.history['val_accuracy'])
	VALIDATION_LOSS.append(history.history['val_loss'])

	fold_var += 1
# Out:
# K-Fold1
# Found 4172 validated image filenames belonging to 2 classes.
# Found 1044 validated image filenames belonging to 2 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 [==============================] - 1s 0us/step
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.RMSprop.
# Epoch 1/30
# 260/260 [==============================] - ETA: 0s - loss: 0.5041 - accuracy: 0.8397
# Epoch 1: val_accuracy improved from -inf to 0.51154, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_rms1.h5
# 260/260 [==============================] - 471s 2s/step - loss: 0.5041 - accuracy: 0.8397 - val_loss: 3.0135 - val_accuracy: 0.5115 - lr: 1.0000e-04
# Epoch 2/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3218 - accuracy: 0.9189
# Epoch 2: val_accuracy improved from 0.51154 to 0.90577, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_rms1.h5
# 260/260 [==============================] - 111s 427ms/step - loss: 0.3218 - accuracy: 0.9189 - val_loss: 0.6344 - val_accuracy: 0.9058 - lr: 1.0000e-04
# Epoch 3/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2498 - accuracy: 0.9283
# Epoch 3: val_accuracy did not improve from 0.90577
# 260/260 [==============================] - 109s 418ms/step - loss: 0.2498 - accuracy: 0.9283 - val_loss: 0.6154 - val_accuracy: 0.8692 - lr: 7.5000e-05
# Epoch 4/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2089 - accuracy: 0.9418
# Epoch 4: val_accuracy did not improve from 0.90577
# 260/260 [==============================] - 109s 419ms/step - loss: 0.2089 - accuracy: 0.9418 - val_loss: 0.6760 - val_accuracy: 0.8885 - lr: 7.5000e-05
# Epoch 5/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2050 - accuracy: 0.9442
# Epoch 5: val_accuracy improved from 0.90577 to 0.94038, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_rms1.h5
# 260/260 [==============================] - 111s 426ms/step - loss: 0.2050 - accuracy: 0.9442 - val_loss: 0.2825 - val_accuracy: 0.9404 - lr: 5.6250e-05
# Epoch 6/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1832 - accuracy: 0.9483
# Epoch 6: val_accuracy did not improve from 0.94038
# 260/260 [==============================] - 110s 422ms/step - loss: 0.1832 - accuracy: 0.9483 - val_loss: 0.6197 - val_accuracy: 0.8817 - lr: 5.6250e-05
# Epoch 7/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1718 - accuracy: 0.9545
# Epoch 7: val_accuracy did not improve from 0.94038
# 260/260 [==============================] - 109s 420ms/step - loss: 0.1718 - accuracy: 0.9545 - val_loss: 0.3203 - val_accuracy: 0.9260 - lr: 4.2188e-05
# Epoch 8/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1513 - accuracy: 0.9526
# Epoch 8: val_accuracy did not improve from 0.94038
# 260/260 [==============================] - 109s 420ms/step - loss: 0.1513 - accuracy: 0.9526 - val_loss: 0.2987 - val_accuracy: 0.9375 - lr: 4.2188e-05
# Epoch 9/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1219 - accuracy: 0.9564
# Epoch 9: val_accuracy did not improve from 0.94038
# 260/260 [==============================] - 109s 420ms/step - loss: 0.1219 - accuracy: 0.9564 - val_loss: 0.3699 - val_accuracy: 0.9288 - lr: 3.1641e-05
# Epoch 10/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1374 - accuracy: 0.9656
# Epoch 10: val_accuracy did not improve from 0.94038
# 260/260 [==============================] - 110s 421ms/step - loss: 0.1374 - accuracy: 0.9656 - val_loss: 0.5831 - val_accuracy: 0.9048 - lr: 3.1641e-05
# Epoch 11/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1242 - accuracy: 0.9658
# Epoch 11: val_accuracy did not improve from 0.94038
# 260/260 [==============================] - 109s 420ms/step - loss: 0.1242 - accuracy: 0.9658 - val_loss: 0.3110 - val_accuracy: 0.9317 - lr: 2.3730e-05
# Epoch 12/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1210 - accuracy: 0.9654
# Epoch 12: val_accuracy did not improve from 0.94038
# 260/260 [==============================] - 109s 417ms/step - loss: 0.1210 - accuracy: 0.9654 - val_loss: 0.2177 - val_accuracy: 0.9356 - lr: 2.3730e-05
# Epoch 13/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1166 - accuracy: 0.9675
# Epoch 13: val_accuracy did not improve from 0.94038
# 260/260 [==============================] - 109s 420ms/step - loss: 0.1166 - accuracy: 0.9675 - val_loss: 0.3191 - val_accuracy: 0.9317 - lr: 1.7798e-05
# Epoch 14/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1003 - accuracy: 0.9699
# Epoch 14: val_accuracy did not improve from 0.94038
# 260/260 [==============================] - 110s 423ms/step - loss: 0.1003 - accuracy: 0.9699 - val_loss: 0.3846 - val_accuracy: 0.9221 - lr: 1.7798e-05
# Epoch 14: early stopping
# 66/66 [==============================] - 15s 210ms/step - loss: 0.2815 - accuracy: 0.9406
# <ipython-input-21-de7d9776c39a>:58: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   Y_pred = modela.predict_generator(valid_data_generator)
# Classification Report
#               precision    recall  f1-score   support
#
#       Normal       0.82      0.98      0.89       269
#    Pneumonia       0.99      0.93      0.96       775
#
#     accuracy                           0.94      1044
#    macro avg       0.91      0.95      0.93      1044
# weighted avg       0.95      0.94      0.94      1044
# K-Fold2
# Found 4173 validated image filenames belonging to 2 classes.
# Found 1043 validated image filenames belonging to 2 classes.
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.RMSprop.
# Epoch 1/30
# 260/260 [==============================] - ETA: 0s - loss: 0.5050 - accuracy: 0.8482
# Epoch 1: val_accuracy improved from -inf to 0.60769, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_rms2.h5
# 260/260 [==============================] - 130s 448ms/step - loss: 0.5050 - accuracy: 0.8482 - val_loss: 2.2202 - val_accuracy: 0.6077 - lr: 1.0000e-04
# Epoch 2/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3021 - accuracy: 0.9223
# Epoch 2: val_accuracy improved from 0.60769 to 0.70962, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_rms2.h5
# 260/260 [==============================] - 112s 429ms/step - loss: 0.3021 - accuracy: 0.9223 - val_loss: 3.5184 - val_accuracy: 0.7096 - lr: 1.0000e-04
# Epoch 3/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2224 - accuracy: 0.9439
# Epoch 3: val_accuracy improved from 0.70962 to 0.87500, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_rms2.h5
# 260/260 [==============================] - 113s 433ms/step - loss: 0.2224 - accuracy: 0.9439 - val_loss: 1.3072 - val_accuracy: 0.8750 - lr: 7.5000e-05
# Epoch 4/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2178 - accuracy: 0.9452
# Epoch 4: val_accuracy improved from 0.87500 to 0.89615, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_rms2.h5
# 260/260 [==============================] - 113s 432ms/step - loss: 0.2178 - accuracy: 0.9452 - val_loss: 0.6985 - val_accuracy: 0.8962 - lr: 7.5000e-05
# Epoch 5/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1958 - accuracy: 0.9495
# Epoch 5: val_accuracy did not improve from 0.89615
# 260/260 [==============================] - 110s 422ms/step - loss: 0.1958 - accuracy: 0.9495 - val_loss: 1.1295 - val_accuracy: 0.8510 - lr: 5.6250e-05
# Epoch 6/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1821 - accuracy: 0.9504
# Epoch 6: val_accuracy improved from 0.89615 to 0.91923, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_rms2.h5
# 260/260 [==============================] - 112s 429ms/step - loss: 0.1821 - accuracy: 0.9504 - val_loss: 0.4455 - val_accuracy: 0.9192 - lr: 5.6250e-05
# Epoch 7/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1666 - accuracy: 0.9584
# Epoch 7: val_accuracy did not improve from 0.91923
# 260/260 [==============================] - 110s 421ms/step - loss: 0.1666 - accuracy: 0.9584 - val_loss: 0.6619 - val_accuracy: 0.8990 - lr: 4.2188e-05
# Epoch 8/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1345 - accuracy: 0.9634
# Epoch 8: val_accuracy improved from 0.91923 to 0.92404, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_rms2.h5
# 260/260 [==============================] - 111s 428ms/step - loss: 0.1345 - accuracy: 0.9634 - val_loss: 0.4264 - val_accuracy: 0.9240 - lr: 4.2188e-05
# Epoch 9/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1449 - accuracy: 0.9634
# Epoch 9: val_accuracy did not improve from 0.92404
# 260/260 [==============================] - 109s 417ms/step - loss: 0.1449 - accuracy: 0.9634 - val_loss: 0.5433 - val_accuracy: 0.9058 - lr: 3.1641e-05
# Epoch 10/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1381 - accuracy: 0.9608
# Epoch 10: val_accuracy improved from 0.92404 to 0.93365, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_rms2.h5
# 260/260 [==============================] - 112s 429ms/step - loss: 0.1381 - accuracy: 0.9608 - val_loss: 0.2964 - val_accuracy: 0.9337 - lr: 3.1641e-05
# Epoch 11/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1293 - accuracy: 0.9639
# Epoch 11: val_accuracy improved from 0.93365 to 0.94231, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_rms2.h5
# 260/260 [==============================] - 112s 428ms/step - loss: 0.1293 - accuracy: 0.9639 - val_loss: 0.2460 - val_accuracy: 0.9423 - lr: 2.3730e-05
# Epoch 12/30
# 260/260 [==============================] - ETA: 0s - loss: 0.0989 - accuracy: 0.9723
# Epoch 12: val_accuracy did not improve from 0.94231
# 260/260 [==============================] - 109s 419ms/step - loss: 0.0989 - accuracy: 0.9723 - val_loss: 0.2933 - val_accuracy: 0.9404 - lr: 2.3730e-05
# Epoch 13/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1289 - accuracy: 0.9642
# Epoch 13: val_accuracy improved from 0.94231 to 0.94423, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_rms2.h5
# 260/260 [==============================] - 111s 426ms/step - loss: 0.1289 - accuracy: 0.9642 - val_loss: 0.2558 - val_accuracy: 0.9442 - lr: 1.7798e-05
# Epoch 14/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1137 - accuracy: 0.9687
# Epoch 14: val_accuracy improved from 0.94423 to 0.94615, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_rms2.h5
# 260/260 [==============================] - 111s 427ms/step - loss: 0.1137 - accuracy: 0.9687 - val_loss: 0.2290 - val_accuracy: 0.9462 - lr: 1.7798e-05
# Epoch 15/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1002 - accuracy: 0.9762
# Epoch 15: val_accuracy did not improve from 0.94615
# 260/260 [==============================] - 109s 417ms/step - loss: 0.1002 - accuracy: 0.9762 - val_loss: 0.3264 - val_accuracy: 0.9356 - lr: 1.3348e-05
# Epoch 16/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1050 - accuracy: 0.9709
# Epoch 16: val_accuracy did not improve from 0.94615
# 260/260 [==============================] - 109s 419ms/step - loss: 0.1050 - accuracy: 0.9709 - val_loss: 0.2404 - val_accuracy: 0.9423 - lr: 1.3348e-05
# Epoch 17/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1099 - accuracy: 0.9721
# Epoch 17: val_accuracy did not improve from 0.94615
# 260/260 [==============================] - 109s 418ms/step - loss: 0.1099 - accuracy: 0.9721 - val_loss: 0.2746 - val_accuracy: 0.9413 - lr: 1.0011e-05
# Epoch 18/30
# 260/260 [==============================] - ETA: 0s - loss: 0.0928 - accuracy: 0.9731
# Epoch 18: val_accuracy did not improve from 0.94615
# 260/260 [==============================] - 109s 420ms/step - loss: 0.0928 - accuracy: 0.9731 - val_loss: 0.2236 - val_accuracy: 0.9394 - lr: 1.0011e-05
# Epoch 19/30
# 260/260 [==============================] - ETA: 0s - loss: 0.0899 - accuracy: 0.9747
# Epoch 19: val_accuracy did not improve from 0.94615
# 260/260 [==============================] - 109s 416ms/step - loss: 0.0899 - accuracy: 0.9747 - val_loss: 0.2695 - val_accuracy: 0.9365 - lr: 7.5085e-06
# Epoch 20/30
# 260/260 [==============================] - ETA: 0s - loss: 0.0912 - accuracy: 0.9757
# Epoch 20: val_accuracy improved from 0.94615 to 0.95096, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_rms2.h5
# 260/260 [==============================] - 111s 427ms/step - loss: 0.0912 - accuracy: 0.9757 - val_loss: 0.2005 - val_accuracy: 0.9510 - lr: 7.5085e-06
# Epoch 21/30
# 260/260 [==============================] - ETA: 0s - loss: 0.0815 - accuracy: 0.9783
# Epoch 21: val_accuracy did not improve from 0.95096
# 260/260 [==============================] - 110s 421ms/step - loss: 0.0815 - accuracy: 0.9783 - val_loss: 0.2094 - val_accuracy: 0.9481 - lr: 5.6314e-06
# Epoch 22/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1062 - accuracy: 0.9750
# Epoch 22: val_accuracy did not improve from 0.95096
# 260/260 [==============================] - 110s 421ms/step - loss: 0.1062 - accuracy: 0.9750 - val_loss: 0.2529 - val_accuracy: 0.9423 - lr: 5.6314e-06
# Epoch 23/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1003 - accuracy: 0.9735
# Epoch 23: val_accuracy did not improve from 0.95096
# 260/260 [==============================] - 109s 419ms/step - loss: 0.1003 - accuracy: 0.9735 - val_loss: 0.2487 - val_accuracy: 0.9442 - lr: 4.2235e-06
# Epoch 24/30
# 260/260 [==============================] - ETA: 0s - loss: 0.0697 - accuracy: 0.9824
# Epoch 24: val_accuracy did not improve from 0.95096
# 260/260 [==============================] - 117s 450ms/step - loss: 0.0697 - accuracy: 0.9824 - val_loss: 0.2571 - val_accuracy: 0.9423 - lr: 4.2235e-06
# Epoch 25/30
# 260/260 [==============================] - ETA: 0s - loss: 0.0788 - accuracy: 0.9779
# Epoch 25: val_accuracy did not improve from 0.95096
# 260/260 [==============================] - 109s 417ms/step - loss: 0.0788 - accuracy: 0.9779 - val_loss: 0.2325 - val_accuracy: 0.9433 - lr: 3.1676e-06
# Epoch 26/30
# 260/260 [==============================] - ETA: 0s - loss: 0.0962 - accuracy: 0.9719
# Epoch 26: val_accuracy did not improve from 0.95096
# 260/260 [==============================] - 109s 419ms/step - loss: 0.0962 - accuracy: 0.9719 - val_loss: 0.2255 - val_accuracy: 0.9452 - lr: 3.1676e-06
# Epoch 27/30
# 260/260 [==============================] - ETA: 0s - loss: 0.0733 - accuracy: 0.9815
# Epoch 27: val_accuracy did not improve from 0.95096
# 260/260 [==============================] - 116s 448ms/step - loss: 0.0733 - accuracy: 0.9815 - val_loss: 0.2632 - val_accuracy: 0.9375 - lr: 2.3757e-07
# Epoch 28/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1043 - accuracy: 0.9771
# Epoch 28: val_accuracy did not improve from 0.95096
# 260/260 [==============================] - 108s 417ms/step - loss: 0.1043 - accuracy: 0.9771 - val_loss: 0.2651 - val_accuracy: 0.9413 - lr: 2.3757e-06
# Epoch 29/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1035 - accuracy: 0.9750
# Epoch 29: val_accuracy did not improve from 0.95096
# 260/260 [==============================] - 109s 419ms/step - loss: 0.1035 - accuracy: 0.9750 - val_loss: 0.2619 - val_accuracy: 0.9404 - lr: 1.7818e-06
# Epoch 29: early stopping
# 66/66 [==============================] - 14s 204ms/step - loss: 0.1999 - accuracy: 0.9511
# <ipython-input-21-de7d9776c39a>:58: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   Y_pred = modela.predict_generator(valid_data_generator)
# Classification Report
#               precision    recall  f1-score   support
#
#       Normal       0.85      0.98      0.91       268
#    Pneumonia       0.99      0.94      0.97       775
#
#     accuracy                           0.95      1043
#    macro avg       0.92      0.96      0.94      1043
# weighted avg       0.96      0.95      0.95      1043
# K-Fold3
# Found 4173 validated image filenames belonging to 2 classes.
# Found 1043 validated image filenames belonging to 2 classes.
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.RMSprop.
# Epoch 1/30
# 260/260 [==============================] - ETA: 0s - loss: 0.4877 - accuracy: 0.8545
# Epoch 1: val_accuracy improved from -inf to 0.39808, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_rms3.h5
# 260/260 [==============================] - 125s 427ms/step - loss: 0.4877 - accuracy: 0.8545 - val_loss: 2.4188 - val_accuracy: 0.3981 - lr: 1.0000e-04
# Epoch 2/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2915 - accuracy: 0.9223
# Epoch 2: val_accuracy improved from 0.39808 to 0.86635, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_rms3.h5
# 260/260 [==============================] - 111s 427ms/step - loss: 0.2915 - accuracy: 0.9223 - val_loss: 0.9187 - val_accuracy: 0.8663 - lr: 1.0000e-04
# Epoch 3/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2266 - accuracy: 0.9387
# Epoch 3: val_accuracy improved from 0.86635 to 0.90288, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_rms3.h5
# 260/260 [==============================] - 112s 428ms/step - loss: 0.2266 - accuracy: 0.9387 - val_loss: 0.4137 - val_accuracy: 0.9029 - lr: 7.5000e-05
# Epoch 4/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2245 - accuracy: 0.9401
# Epoch 4: val_accuracy did not improve from 0.90288
# 260/260 [==============================] - 109s 419ms/step - loss: 0.2245 - accuracy: 0.9401 - val_loss: 1.0553 - val_accuracy: 0.8298 - lr: 7.5000e-05
# Epoch 5/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1828 - accuracy: 0.9471
# Epoch 5: val_accuracy did not improve from 0.90288
# 260/260 [==============================] - 109s 419ms/step - loss: 0.1828 - accuracy: 0.9471 - val_loss: 0.5778 - val_accuracy: 0.8615 - lr: 5.6250e-05
# Epoch 6/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1777 - accuracy: 0.9495
# Epoch 6: val_accuracy did not improve from 0.90288
# 260/260 [==============================] - 109s 419ms/step - loss: 0.1777 - accuracy: 0.9495 - val_loss: 0.7545 - val_accuracy: 0.8779 - lr: 5.6250e-05
# Epoch 7/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1524 - accuracy: 0.9548
# Epoch 7: val_accuracy improved from 0.90288 to 0.90481, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_rms3.h5
# 260/260 [==============================] - 110s 424ms/step - loss: 0.1524 - accuracy: 0.9548 - val_loss: 0.4870 - val_accuracy: 0.9048 - lr: 4.2188e-05
# Epoch 8/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1214 - accuracy: 0.9651
# Epoch 8: val_accuracy improved from 0.90481 to 0.90769, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_rms3.h5
# 260/260 [==============================] - 110s 424ms/step - loss: 0.1214 - accuracy: 0.9651 - val_loss: 0.5068 - val_accuracy: 0.9077 - lr: 4.2188e-05
# Epoch 9/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1250 - accuracy: 0.9630
# Epoch 9: val_accuracy did not improve from 0.90769
# 260/260 [==============================] - 108s 415ms/step - loss: 0.1250 - accuracy: 0.9630 - val_loss: 0.5176 - val_accuracy: 0.8971 - lr: 3.1641e-05
# Epoch 10/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1346 - accuracy: 0.9627
# Epoch 10: val_accuracy improved from 0.90769 to 0.90865, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_rms3.h5
# 260/260 [==============================] - 111s 426ms/step - loss: 0.1346 - accuracy: 0.9627 - val_loss: 0.3479 - val_accuracy: 0.9087 - lr: 3.1641e-05
# Epoch 11/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1150 - accuracy: 0.9697
# Epoch 11: val_accuracy improved from 0.90865 to 0.92692, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_rms3.h5
# 260/260 [==============================] - 112s 428ms/step - loss: 0.1150 - accuracy: 0.9697 - val_loss: 0.4751 - val_accuracy: 0.9269 - lr: 2.3730e-05
# Epoch 12/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1310 - accuracy: 0.9654
# Epoch 12: val_accuracy improved from 0.92692 to 0.93269, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_rms3.h5
# 260/260 [==============================] - 111s 426ms/step - loss: 0.1310 - accuracy: 0.9654 - val_loss: 0.4537 - val_accuracy: 0.9327 - lr: 2.3730e-05
# Epoch 13/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1112 - accuracy: 0.9752
# Epoch 13: val_accuracy did not improve from 0.93269
# 260/260 [==============================] - 109s 419ms/step - loss: 0.1112 - accuracy: 0.9752 - val_loss: 0.4276 - val_accuracy: 0.9269 - lr: 1.7798e-05
# Epoch 14/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1134 - accuracy: 0.9690
# Epoch 14: val_accuracy improved from 0.93269 to 0.94327, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_rms3.h5
# 260/260 [==============================] - 112s 429ms/step - loss: 0.1134 - accuracy: 0.9690 - val_loss: 0.2911 - val_accuracy: 0.9433 - lr: 1.7798e-05
# Epoch 15/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1472 - accuracy: 0.9728
# Epoch 15: val_accuracy did not improve from 0.94327
# 260/260 [==============================] - 110s 422ms/step - loss: 0.1472 - accuracy: 0.9728 - val_loss: 0.4145 - val_accuracy: 0.9212 - lr: 1.3348e-05
# Epoch 16/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1008 - accuracy: 0.9755
# Epoch 16: val_accuracy did not improve from 0.94327
# 260/260 [==============================] - 109s 417ms/step - loss: 0.1008 - accuracy: 0.9755 - val_loss: 0.4522 - val_accuracy: 0.9212 - lr: 1.3348e-05
# Epoch 17/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1053 - accuracy: 0.9771
# Epoch 17: val_accuracy did not improve from 0.94327
# 260/260 [==============================] - 108s 416ms/step - loss: 0.1053 - accuracy: 0.9771 - val_loss: 0.4532 - val_accuracy: 0.9269 - lr: 1.0011e-05
# Epoch 18/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1128 - accuracy: 0.9750
# Epoch 18: val_accuracy did not improve from 0.94327
# 260/260 [==============================] - 108s 415ms/step - loss: 0.1128 - accuracy: 0.9750 - val_loss: 0.4272 - val_accuracy: 0.9279 - lr: 1.0011e-05
# Epoch 19/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1006 - accuracy: 0.9759
# Epoch 19: val_accuracy did not improve from 0.94327
# 260/260 [==============================] - 109s 419ms/step - loss: 0.1006 - accuracy: 0.9759 - val_loss: 0.3476 - val_accuracy: 0.9413 - lr: 7.5085e-06
# Epoch 20/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1220 - accuracy: 0.9723
# Epoch 20: val_accuracy did not improve from 0.94327
# 260/260 [==============================] - 108s 416ms/step - loss: 0.1220 - accuracy: 0.9723 - val_loss: 0.3703 - val_accuracy: 0.9423 - lr: 7.5085e-06
# Epoch 21/30
# 260/260 [==============================] - ETA: 0s - loss: 0.0771 - accuracy: 0.9774
# Epoch 21: val_accuracy did not improve from 0.94327
# 260/260 [==============================] - 108s 415ms/step - loss: 0.0771 - accuracy: 0.9774 - val_loss: 0.4051 - val_accuracy: 0.9337 - lr: 5.6314e-07
# Epoch 22/30
# 260/260 [==============================] - ETA: 0s - loss: 0.0973 - accuracy: 0.9779
# Epoch 22: val_accuracy did not improve from 0.94327
# 260/260 [==============================] - 109s 417ms/step - loss: 0.0973 - accuracy: 0.9779 - val_loss: 0.3246 - val_accuracy: 0.9365 - lr: 5.6314e-06
# Epoch 23/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1050 - accuracy: 0.9759
# Epoch 23: val_accuracy did not improve from 0.94327
# 260/260 [==============================] - 109s 420ms/step - loss: 0.1050 - accuracy: 0.9759 - val_loss: 0.3598 - val_accuracy: 0.9279 - lr: 4.2235e-06
# Epoch 23: early stopping
# 66/66 [==============================] - 14s 199ms/step - loss: 0.2908 - accuracy: 0.9434
# <ipython-input-21-de7d9776c39a>:58: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   Y_pred = modela.predict_generator(valid_data_generator)
# Classification Report
#               precision    recall  f1-score   support
#
#       Normal       0.82      1.00      0.90       268
#    Pneumonia       1.00      0.92      0.96       775
#
#     accuracy                           0.94      1043
#    macro avg       0.91      0.96      0.93      1043
# weighted avg       0.95      0.94      0.95      1043
# K-Fold4
# Found 4173 validated image filenames belonging to 2 classes.
# Found 1043 validated image filenames belonging to 2 classes.
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.RMSprop.
# Epoch 1/30
# 260/260 [==============================] - ETA: 0s - loss: 0.5157 - accuracy: 0.8381
# Epoch 1: val_accuracy improved from -inf to 0.61635, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_rms4.h5
# 260/260 [==============================] - 127s 437ms/step - loss: 0.5157 - accuracy: 0.8381 - val_loss: 1.5375 - val_accuracy: 0.6163 - lr: 1.0000e-04
# Epoch 2/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3134 - accuracy: 0.9204
# Epoch 2: val_accuracy improved from 0.61635 to 0.78365, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_rms4.h5
# 260/260 [==============================] - 111s 427ms/step - loss: 0.3134 - accuracy: 0.9204 - val_loss: 1.5816 - val_accuracy: 0.7837 - lr: 1.0000e-04
# Epoch 3/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2485 - accuracy: 0.9365
# Epoch 3: val_accuracy improved from 0.78365 to 0.81635, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_rms4.h5
# 260/260 [==============================] - 111s 425ms/step - loss: 0.2485 - accuracy: 0.9365 - val_loss: 1.3564 - val_accuracy: 0.8163 - lr: 7.5000e-05
# Epoch 4/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2159 - accuracy: 0.9435
# Epoch 4: val_accuracy improved from 0.81635 to 0.89615, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_rms4.h5
# 260/260 [==============================] - 110s 423ms/step - loss: 0.2159 - accuracy: 0.9435 - val_loss: 0.5502 - val_accuracy: 0.8962 - lr: 7.5000e-05
# Epoch 5/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2144 - accuracy: 0.9442
# Epoch 5: val_accuracy did not improve from 0.89615
# 260/260 [==============================] - 109s 418ms/step - loss: 0.2144 - accuracy: 0.9442 - val_loss: 0.5871 - val_accuracy: 0.8750 - lr: 5.6250e-05
# Epoch 6/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1798 - accuracy: 0.9514
# Epoch 6: val_accuracy did not improve from 0.89615
# 260/260 [==============================] - 109s 419ms/step - loss: 0.1798 - accuracy: 0.9514 - val_loss: 0.5984 - val_accuracy: 0.8817 - lr: 5.6250e-05
# Epoch 7/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1923 - accuracy: 0.9466
# Epoch 7: val_accuracy improved from 0.89615 to 0.90000, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_rms4.h5
# 260/260 [==============================] - 110s 423ms/step - loss: 0.1923 - accuracy: 0.9466 - val_loss: 0.4027 - val_accuracy: 0.9000 - lr: 4.2188e-05
# Epoch 8/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1580 - accuracy: 0.9567
# Epoch 8: val_accuracy did not improve from 0.90000
# 260/260 [==============================] - 109s 418ms/step - loss: 0.1580 - accuracy: 0.9567 - val_loss: 0.5548 - val_accuracy: 0.8981 - lr: 4.2188e-05
# Epoch 9/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1322 - accuracy: 0.9620
# Epoch 9: val_accuracy did not improve from 0.90000
# 260/260 [==============================] - 109s 418ms/step - loss: 0.1322 - accuracy: 0.9620 - val_loss: 0.6697 - val_accuracy: 0.8885 - lr: 3.1641e-05
# Epoch 10/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1244 - accuracy: 0.9622
# Epoch 10: val_accuracy did not improve from 0.90000
# 260/260 [==============================] - 108s 416ms/step - loss: 0.1244 - accuracy: 0.9622 - val_loss: 0.6058 - val_accuracy: 0.8962 - lr: 3.1641e-05
# Epoch 11/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1260 - accuracy: 0.9639
# Epoch 11: val_accuracy improved from 0.90000 to 0.92596, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_rms4.h5
# 260/260 [==============================] - 111s 425ms/step - loss: 0.1260 - accuracy: 0.9639 - val_loss: 0.3366 - val_accuracy: 0.9260 - lr: 2.3730e-05
# Epoch 12/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1003 - accuracy: 0.9738
# Epoch 12: val_accuracy did not improve from 0.92596
# 260/260 [==============================] - 109s 420ms/step - loss: 0.1003 - accuracy: 0.9738 - val_loss: 0.4424 - val_accuracy: 0.9154 - lr: 2.3730e-05
# Epoch 13/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1226 - accuracy: 0.9685
# Epoch 13: val_accuracy improved from 0.92596 to 0.93365, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_rms4.h5
# 260/260 [==============================] - 111s 425ms/step - loss: 0.1226 - accuracy: 0.9685 - val_loss: 0.3209 - val_accuracy: 0.9337 - lr: 1.7798e-05
# Epoch 14/30
# 260/260 [==============================] - ETA: 0s - loss: 0.0966 - accuracy: 0.9764
# Epoch 14: val_accuracy did not improve from 0.93365
# 260/260 [==============================] - 109s 418ms/step - loss: 0.0966 - accuracy: 0.9764 - val_loss: 0.3382 - val_accuracy: 0.9269 - lr: 1.7798e-05
# Epoch 15/30
# 260/260 [==============================] - ETA: 0s - loss: 0.0954 - accuracy: 0.9707
# Epoch 15: val_accuracy did not improve from 0.93365
# 260/260 [==============================] - 108s 416ms/step - loss: 0.0954 - accuracy: 0.9707 - val_loss: 0.3532 - val_accuracy: 0.9221 - lr: 1.3348e-05
# Epoch 16/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1049 - accuracy: 0.9704
# Epoch 16: val_accuracy improved from 0.93365 to 0.93462, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_rms4.h5
# 260/260 [==============================] - 110s 424ms/step - loss: 0.1049 - accuracy: 0.9704 - val_loss: 0.2987 - val_accuracy: 0.9346 - lr: 1.3348e-05
# Epoch 17/30
# 260/260 [==============================] - ETA: 0s - loss: 0.0854 - accuracy: 0.9783
# Epoch 17: val_accuracy did not improve from 0.93462
# 260/260 [==============================] - 110s 421ms/step - loss: 0.0854 - accuracy: 0.9783 - val_loss: 0.2871 - val_accuracy: 0.9288 - lr: 1.0011e-05
# Epoch 18/30
# 260/260 [==============================] - ETA: 0s - loss: 0.0927 - accuracy: 0.9755
# Epoch 18: val_accuracy did not improve from 0.93462
# 260/260 [==============================] - 109s 417ms/step - loss: 0.0927 - accuracy: 0.9755 - val_loss: 0.3051 - val_accuracy: 0.9308 - lr: 1.0011e-05
# Epoch 19/30
# 260/260 [==============================] - ETA: 0s - loss: 0.0823 - accuracy: 0.9764
# Epoch 19: val_accuracy did not improve from 0.93462
# 260/260 [==============================] - 109s 418ms/step - loss: 0.0823 - accuracy: 0.9764 - val_loss: 0.2900 - val_accuracy: 0.9298 - lr: 7.5085e-06
# Epoch 20/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1190 - accuracy: 0.9699
# Epoch 20: val_accuracy did not improve from 0.93462
# 260/260 [==============================] - 108s 416ms/step - loss: 0.1190 - accuracy: 0.9699 - val_loss: 0.2811 - val_accuracy: 0.9308 - lr: 7.5085e-06
# Epoch 21/30
# 260/260 [==============================] - ETA: 0s - loss: 0.0858 - accuracy: 0.9776
# Epoch 21: val_accuracy improved from 0.93462 to 0.94038, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_rms4.h5
# 260/260 [==============================] - 110s 424ms/step - loss: 0.0858 - accuracy: 0.9776 - val_loss: 0.2546 - val_accuracy: 0.9404 - lr: 5.6314e-06
# Epoch 22/30
# 260/260 [==============================] - ETA: 0s - loss: 0.0912 - accuracy: 0.9735
# Epoch 22: val_accuracy did not improve from 0.94038
# 260/260 [==============================] - 109s 418ms/step - loss: 0.0912 - accuracy: 0.9735 - val_loss: 0.2847 - val_accuracy: 0.9337 - lr: 5.6314e-06
# Epoch 23/30
# 260/260 [==============================] - ETA: 0s - loss: 0.0838 - accuracy: 0.9757
# Epoch 23: val_accuracy did not improve from 0.94038
# 260/260 [==============================] - 109s 418ms/step - loss: 0.0838 - accuracy: 0.9757 - val_loss: 0.3127 - val_accuracy: 0.9298 - lr: 4.2235e-06
# Epoch 24/30
# 260/260 [==============================] - ETA: 0s - loss: 0.0826 - accuracy: 0.9755
# Epoch 24: val_accuracy did not improve from 0.94038
# 260/260 [==============================] - 109s 417ms/step - loss: 0.0826 - accuracy: 0.9755 - val_loss: 0.3317 - val_accuracy: 0.9250 - lr: 4.2235e-06
# Epoch 25/30
# 260/260 [==============================] - ETA: 0s - loss: 0.0854 - accuracy: 0.9755
# Epoch 25: val_accuracy did not improve from 0.94038
# 260/260 [==============================] - 108s 415ms/step - loss: 0.0854 - accuracy: 0.9755 - val_loss: 0.3201 - val_accuracy: 0.9260 - lr: 3.1676e-06
# Epoch 26/30
# 260/260 [==============================] - ETA: 0s - loss: 0.0893 - accuracy: 0.9764
# Epoch 26: val_accuracy did not improve from 0.94038
# 260/260 [==============================] - 109s 420ms/step - loss: 0.0893 - accuracy: 0.9764 - val_loss: 0.3592 - val_accuracy: 0.9231 - lr: 3.1676e-06
# Epoch 27/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1013 - accuracy: 0.9757
# Epoch 27: val_accuracy did not improve from 0.94038
# 260/260 [==============================] - 108s 415ms/step - loss: 0.1013 - accuracy: 0.9757 - val_loss: 0.3348 - val_accuracy: 0.9240 - lr: 2.3757e-06
# Epoch 28/30
# 260/260 [==============================] - ETA: 0s - loss: 0.0917 - accuracy: 0.9747
# Epoch 28: val_accuracy did not improve from 0.94038
# 260/260 [==============================] - 109s 417ms/step - loss: 0.0917 - accuracy: 0.9747 - val_loss: 0.3060 - val_accuracy: 0.9317 - lr: 2.3757e-07
# Epoch 29/30
# 260/260 [==============================] - ETA: 0s - loss: 0.0764 - accuracy: 0.9779
# Epoch 29: val_accuracy did not improve from 0.94038
# 260/260 [==============================] - 108s 415ms/step - loss: 0.0764 - accuracy: 0.9779 - val_loss: 0.3309 - val_accuracy: 0.9269 - lr: 1.7818e-06
# Epoch 30/30
# 260/260 [==============================] - ETA: 0s - loss: 0.0885 - accuracy: 0.9796
# Epoch 30: val_accuracy did not improve from 0.94038
# 260/260 [==============================] - 108s 416ms/step - loss: 0.0885 - accuracy: 0.9796 - val_loss: 0.3158 - val_accuracy: 0.9279 - lr: 1.7818e-06
# Epoch 30: early stopping
# 66/66 [==============================] - 14s 193ms/step - loss: 0.2539 - accuracy: 0.9406
# <ipython-input-21-de7d9776c39a>:58: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   Y_pred = modela.predict_generator(valid_data_generator)
# Classification Report
#               precision    recall  f1-score   support
#
#       Normal       0.81      1.00      0.90       268
#    Pneumonia       1.00      0.92      0.96       775
#
#     accuracy                           0.94      1043
#    macro avg       0.91      0.96      0.93      1043
# weighted avg       0.95      0.94      0.94      1043
# K-Fold5
# Found 4173 validated image filenames belonging to 2 classes.
# Found 1043 validated image filenames belonging to 2 classes.
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.RMSprop.
# Epoch 1/30
# 260/260 [==============================] - ETA: 0s - loss: 0.4923 - accuracy: 0.8448
# Epoch 1: val_accuracy improved from -inf to 0.28654, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_rms5.h5
# 260/260 [==============================] - 128s 438ms/step - loss: 0.4923 - accuracy: 0.8448 - val_loss: 3.7289 - val_accuracy: 0.2865 - lr: 1.0000e-04
# Epoch 2/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3238 - accuracy: 0.9165
# Epoch 2: val_accuracy improved from 0.28654 to 0.79135, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_rms5.h5
# 260/260 [==============================] - 110s 424ms/step - loss: 0.3238 - accuracy: 0.9165 - val_loss: 1.5078 - val_accuracy: 0.7913 - lr: 1.0000e-04
# Epoch 3/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2487 - accuracy: 0.9288
# Epoch 3: val_accuracy improved from 0.79135 to 0.87115, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_rms5.h5
# 260/260 [==============================] - 111s 425ms/step - loss: 0.2487 - accuracy: 0.9288 - val_loss: 0.8177 - val_accuracy: 0.8712 - lr: 7.5000e-05
# Epoch 4/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2230 - accuracy: 0.9411
# Epoch 4: val_accuracy did not improve from 0.87115
# 260/260 [==============================] - 108s 414ms/step - loss: 0.2230 - accuracy: 0.9411 - val_loss: 1.5757 - val_accuracy: 0.7952 - lr: 7.5000e-05
# Epoch 5/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2012 - accuracy: 0.9502
# Epoch 5: val_accuracy did not improve from 0.87115
# 260/260 [==============================] - 108s 415ms/step - loss: 0.2012 - accuracy: 0.9502 - val_loss: 0.7545 - val_accuracy: 0.8452 - lr: 5.6250e-05
# Epoch 6/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1732 - accuracy: 0.9500
# Epoch 6: val_accuracy improved from 0.87115 to 0.88750, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_rms5.h5
# 260/260 [==============================] - 109s 421ms/step - loss: 0.1732 - accuracy: 0.9500 - val_loss: 0.6861 - val_accuracy: 0.8875 - lr: 5.6250e-05
# Epoch 7/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1773 - accuracy: 0.9519
# Epoch 7: val_accuracy improved from 0.88750 to 0.92212, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_rms5.h5
# 260/260 [==============================] - 110s 423ms/step - loss: 0.1773 - accuracy: 0.9519 - val_loss: 0.4269 - val_accuracy: 0.9221 - lr: 4.2188e-05
# Epoch 8/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1508 - accuracy: 0.9543
# Epoch 8: val_accuracy did not improve from 0.92212
# 260/260 [==============================] - 109s 417ms/step - loss: 0.1508 - accuracy: 0.9543 - val_loss: 0.5631 - val_accuracy: 0.9173 - lr: 4.2188e-05
# Epoch 9/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1505 - accuracy: 0.9596
# Epoch 9: val_accuracy improved from 0.92212 to 0.93942, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_rms5.h5
# 260/260 [==============================] - 110s 422ms/step - loss: 0.1505 - accuracy: 0.9596 - val_loss: 0.3100 - val_accuracy: 0.9394 - lr: 3.1641e-05
# Epoch 10/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1473 - accuracy: 0.9618
# Epoch 10: val_accuracy did not improve from 0.93942
# 260/260 [==============================] - 108s 415ms/step - loss: 0.1473 - accuracy: 0.9618 - val_loss: 0.5096 - val_accuracy: 0.9010 - lr: 3.1641e-05
# Epoch 11/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1240 - accuracy: 0.9656
# Epoch 11: val_accuracy did not improve from 0.93942
# 260/260 [==============================] - 108s 415ms/step - loss: 0.1240 - accuracy: 0.9656 - val_loss: 0.3274 - val_accuracy: 0.9346 - lr: 2.3730e-05
# Epoch 12/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1130 - accuracy: 0.9711
# Epoch 12: val_accuracy did not improve from 0.93942
# 260/260 [==============================] - 108s 414ms/step - loss: 0.1130 - accuracy: 0.9711 - val_loss: 0.2582 - val_accuracy: 0.9394 - lr: 2.3730e-05
# Epoch 13/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1416 - accuracy: 0.9642
# Epoch 13: val_accuracy did not improve from 0.93942
# 260/260 [==============================] - 108s 414ms/step - loss: 0.1416 - accuracy: 0.9642 - val_loss: 0.3318 - val_accuracy: 0.9279 - lr: 1.7798e-05
# Epoch 14/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1046 - accuracy: 0.9721
# Epoch 14: val_accuracy did not improve from 0.93942
# 260/260 [==============================] - 108s 414ms/step - loss: 0.1046 - accuracy: 0.9721 - val_loss: 0.3348 - val_accuracy: 0.9365 - lr: 1.7798e-05
# Epoch 15/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1085 - accuracy: 0.9728
# Epoch 15: val_accuracy improved from 0.93942 to 0.94423, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_rms5.h5
# 260/260 [==============================] - 111s 427ms/step - loss: 0.1085 - accuracy: 0.9728 - val_loss: 0.2887 - val_accuracy: 0.9442 - lr: 1.3348e-05
# Epoch 16/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1006 - accuracy: 0.9738
# Epoch 16: val_accuracy did not improve from 0.94423
# 260/260 [==============================] - 108s 415ms/step - loss: 0.1006 - accuracy: 0.9738 - val_loss: 0.3899 - val_accuracy: 0.9337 - lr: 1.3348e-05
# Epoch 17/30
# 260/260 [==============================] - ETA: 0s - loss: 0.0999 - accuracy: 0.9740
# Epoch 17: val_accuracy did not improve from 0.94423
# 260/260 [==============================] - 108s 416ms/step - loss: 0.0999 - accuracy: 0.9740 - val_loss: 0.2607 - val_accuracy: 0.9413 - lr: 1.0011e-05
# Epoch 18/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1009 - accuracy: 0.9743
# Epoch 18: val_accuracy did not improve from 0.94423
# 260/260 [==============================] - 108s 414ms/step - loss: 0.1009 - accuracy: 0.9743 - val_loss: 0.4203 - val_accuracy: 0.9279 - lr: 1.0011e-05
# Epoch 19/30
# 260/260 [==============================] - ETA: 0s - loss: 0.0870 - accuracy: 0.9740
# Epoch 19: val_accuracy did not improve from 0.94423
# 260/260 [==============================] - 108s 414ms/step - loss: 0.0870 - accuracy: 0.9740 - val_loss: 0.3194 - val_accuracy: 0.9375 - lr: 7.5085e-07
# Epoch 20/30
# 260/260 [==============================] - ETA: 0s - loss: 0.0999 - accuracy: 0.9755
# Epoch 20: val_accuracy did not improve from 0.94423
# 260/260 [==============================] - 108s 414ms/step - loss: 0.0999 - accuracy: 0.9755 - val_loss: 0.2958 - val_accuracy: 0.9385 - lr: 7.5085e-06
# Epoch 21/30
# 260/260 [==============================] - ETA: 0s - loss: 0.0852 - accuracy: 0.9738
# Epoch 21: val_accuracy did not improve from 0.94423
# 260/260 [==============================] - 108s 415ms/step - loss: 0.0852 - accuracy: 0.9738 - val_loss: 0.2860 - val_accuracy: 0.9423 - lr: 5.6314e-06
# Epoch 22/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1120 - accuracy: 0.9716
# Epoch 22: val_accuracy did not improve from 0.94423
# 260/260 [==============================] - 108s 415ms/step - loss: 0.1120 - accuracy: 0.9716 - val_loss: 0.3136 - val_accuracy: 0.9385 - lr: 5.6314e-06
# Epoch 23/30
# 260/260 [==============================] - ETA: 0s - loss: 0.0957 - accuracy: 0.9750
# Epoch 23: val_accuracy did not improve from 0.94423
# 260/260 [==============================] - 108s 417ms/step - loss: 0.0957 - accuracy: 0.9750 - val_loss: 0.3119 - val_accuracy: 0.9385 - lr: 4.2235e-06
# Epoch 24/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1079 - accuracy: 0.9740
# Epoch 24: val_accuracy did not improve from 0.94423
# 260/260 [==============================] - 108s 415ms/step - loss: 0.1079 - accuracy: 0.9740 - val_loss: 0.3133 - val_accuracy: 0.9385 - lr: 4.2235e-06
# Epoch 24: early stopping
# 66/66 [==============================] - 14s 196ms/step - loss: 0.2892 - accuracy: 0.9434
# <ipython-input-21-de7d9776c39a>:58: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   Y_pred = modela.predict_generator(valid_data_generator)
# Classification Report
#               precision    recall  f1-score   support
#
#       Normal       0.82      0.99      0.90       268
#    Pneumonia       1.00      0.93      0.96       775
#
#     accuracy                           0.94      1043
#    macro avg       0.91      0.96      0.93      1043
# weighted avg       0.95      0.94      0.95      1043

# %%
l1=max(VALIDATION_ACCURACY[0])
l2=max(VALIDATION_ACCURACY[1])
l3=max(VALIDATION_ACCURACY[2])
l4=max(VALIDATION_ACCURACY[3])
l5=max(VALIDATION_ACCURACY[4])

avg=(l1+l2+l3+l4+l5)/5
avg
# Out:
# 0.9438461661338806
