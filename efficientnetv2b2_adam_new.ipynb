# %%
import keras
import tensorflow as tf
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten,Conv2D
from keras.models import Model
from keras import backend as K
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np
import cv2
import sklearn
import os
import seaborn as sns
from google.colab.patches import cv2_imshow
import glob
import keras
from keras.models import Sequential
from tensorflow.python.keras.layers import Dense, Flatten, GlobalAveragePooling2D, Activation, Flatten, Dropout
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import callbacks
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam, SGD

# %%
seed = 10

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
 batch_size=16

# %%
train_path="/content/drive/MyDrive/Capstone_data/Clahe_train"
test_path="/content/drive/MyDrive/Capstone_data/Clahe_test"
val_path="/content/drive/MyDrive/Capstone_data/Clahe_val"

# %%
train_normal = glob.glob(train_path+"/normal/*.jpeg")
train_pneumonia = glob.glob(train_path+"/pneumonia/*.jpeg")

test_normal = glob.glob(test_path+"/normal/*.jpeg")
test_pneumonia = glob.glob(test_path+"/pneumonia/*.jpeg")

val_normal = glob.glob(val_path+"/normal/*.jpeg")
val_pneumonia = glob.glob(val_path+"/pneumonia/*.jpeg")

# %%
train_list = [x for x in train_normal]
train_list.extend([x for x in train_pneumonia])

df_train = pd.DataFrame(np.concatenate([['Normal']*len(train_normal) , ['Pneumonia']*len(train_pneumonia)]), columns = ['class'])
df_train['image'] = [x for x in train_list]

test_list = [x for x in test_normal]
test_list.extend([x for x in test_pneumonia])

df_test = pd.DataFrame(np.concatenate([['Normal']*len(test_normal) , ['Pneumonia']*len(test_pneumonia)]), columns = ['class'])
df_test['image'] = [x for x in test_list]

val_list = [x for x in val_normal]
val_list.extend([x for x in val_pneumonia])

df_val = pd.DataFrame(np.concatenate([['Normal']*len(val_normal) , ['Pneumonia']*len(val_pneumonia)]), columns = ['class'])
df_val['image'] = [x for x in val_list]

# %%
df_train.head()
df_test.head()
df_val.head()
# Out:
#     class                                              image
# 0  Normal  /content/drive/MyDrive/Capstone_data/Clahe_val...
# 1  Normal  /content/drive/MyDrive/Capstone_data/Clahe_val...
# 2  Normal  /content/drive/MyDrive/Capstone_data/Clahe_val...
# 3  Normal  /content/drive/MyDrive/Capstone_data/Clahe_val...
# 4  Normal  /content/drive/MyDrive/Capstone_data/Clahe_val...

# %%
df_train=df_train.sample(frac=1)

# %%
df_train.head()
# Out:
#           class                                              image
# 764      Normal  /content/drive/MyDrive/Capstone_data/Clahe_tra...
# 1653  Pneumonia  /content/drive/MyDrive/Capstone_data/Clahe_tra...
# 2726  Pneumonia  /content/drive/MyDrive/Capstone_data/Clahe_tra...
# 714      Normal  /content/drive/MyDrive/Capstone_data/Clahe_tra...
# 5004  Pneumonia  /content/drive/MyDrive/Capstone_data/Clahe_tra...

# %%
from sklearn.model_selection import KFold, StratifiedKFold
Y = df_train[['class']]

kf = KFold(n_splits = 5)
                         
skf = StratifiedKFold(n_splits = 5, random_state = 7, shuffle = True)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator ,load_img,img_to_array

train_datagen = ImageDataGenerator(
        rescale = 1./255,
        shear_range=10,
        zoom_range=0.3,
        horizontal_flip=True,
        vertical_flip=True,
        brightness_range=[0.5,2.0],
        width_shift_range = 0.2,
        rotation_range=20,
        fill_mode = 'nearest',
)
test_datagen = ImageDataGenerator(
        rescale = 1./255)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Input, Flatten, SeparableConv2D
from tensorflow.keras.layers import GlobalMaxPooling2D,GlobalAveragePooling2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from tensorflow.keras.callbacks import ModelCheckpoint, Callback, EarlyStopping
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.applications import ResNet50, InceptionV3, EfficientNetV2B2
from tensorflow.keras.layers.experimental.preprocessing import Normalization

# %%
df_train.shape
n=5216

# %%
x=len(train_normal)
y=len(train_pneumonia)
s1=(x+y)//batch_size
a=len(test_normal)
b=len(test_pneumonia)
s2=(a+b)//batch_size

# %%
from keras.callbacks import ReduceLROnPlateau
import numpy as np
from keras.callbacks import LearningRateScheduler
from tensorflow.keras.models import load_model
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix ,classification_report
import numpy as np

# %%
from tensorflow import keras
from keras import optimizers
import matplotlib.pyplot as plt

# %%
def printHistory(history, title, epochs):
    f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
    t = f.suptitle(title, fontsize=12)
    f.subplots_adjust(top=0.85, wspace=0.3)

    epoch_list = list(range(1,epochs+1))
    ax1.plot(epoch_list, history.history['accuracy'], label='Train Accuracy')
    ax1.plot(epoch_list, history.history['val_accuracy'], label='Validation Accuracy')
    ax1.set_xticks(np.arange(0, epochs+1, 5))
    ax1.set_ylabel('Accuracy Value')
    ax1.set_xlabel('Epoch')
    ax1.set_title('Accuracy')
    l1 = ax1.legend(loc="best")

    ax2.plot(epoch_list, history.history['loss'], label='Train Loss')
    ax2.plot(epoch_list, history.history['val_loss'], label='Validation Loss')
    ax2.set_xticks(np.arange(0, epochs+1, 5))
    ax2.set_ylabel('Loss Value')
    ax2.set_xlabel('Epoch')
    ax2.set_title('Loss')
    l2 = ax2.legend(loc="best")

# %%
from sklearn.metrics import roc_curve, roc_auc_score
def plot_roc_curve(predictions, labels,auc):
    fpr, tpr, thresholds = roc_curve(labels, predictions) 
    plt.title('Receiver Operating Characteristic (ROC)  Curve',fontsize=14)
    plt.xlim([0, 1])
    plt.ylim([0, 1])
    plt.plot(fpr, tpr, 'g',label = 'AUC Score = %0.2f' % auc)
    plt.plot([0, 1], [0, 1],'r--')
    plt.ylabel('\nTrue Positive Rate (TPR)', fontsize=12)
    plt.xlabel('\nFalse Positive Rate (FPR)', fontsize=12)
    plt.legend()
    plt.grid()
    plt.show()

# %%
def conf(cm,target_names):
    plt.figure(figsize=(5,3))
    sns.set(font_scale=1.2)
    ax = sns.heatmap(cm, annot=True,xticklabels=['H', 'P'], yticklabels=['H', 'P'], cbar=False, cmap='Blues',linewidths=1, linecolor='black', fmt='.0f')
    plt.yticks(rotation=0)
    plt.xlabel('Predicted labels')
    plt.ylabel('True labels')
    ax.xaxis.set_ticks_position('top') 
    plt.title('Confusion matrix')
    plt.show()

# %%
VALIDATION_ACCURACY = []
VALIDATION_LOSS = []
TRAINING_ACCURACY=[]
TRAINING_LOSS=[]

save_dir = '/content/drive/MyDrive/Capstone_data/Clahe_train'
fold_var=1
fine_tune_at=30
t=df_train[['class']]
for train_index, val_index in skf.split(np.zeros(len(Y)),Y):
	print("K-Fold"+str(fold_var))
	training_data = df_train.iloc[train_index]
	validation_data = df_train.iloc[val_index]
	
	train_data_generator = train_datagen.flow_from_dataframe(dataframe=training_data,x_col="image",y_col="class",target_size=(224,224),
                                               batch_size=16,class_mode='categorical',shuffle=True)
	valid_data_generator  = test_datagen.flow_from_dataframe(dataframe=validation_data,x_col="image",y_col="class",target_size=(224,224),
                                               batch_size=16,class_mode='categorical',shuffle=False)
        
 	# CREATE NEW MODEL
	model = Sequential()
	conv_base = EfficientNetV2B2(input_shape=[224,224]+[3], include_top=False, weights='imagenet')
	for layer in conv_base.layers[:fine_tune_at]:
		layer.trainable = False
	x=  conv_base.output
	x = GlobalAveragePooling2D()(x)
	x = BatchNormalization()(x)
	x = Dropout(0.3)(x) 
	x = Dense(512, activation ='relu')(x)
	x = BatchNormalization()(x)
	x = Dropout(0.5)(x)
	x = Dense(2, activation ='sigmoid')(x)
	model = Model(conv_base.input, x)
	reduce_lr = ReduceLROnPlateau(monitor='val_loss',patience=7)
	early_stopping = EarlyStopping(monitor = "val_accuracy",patience = 9,verbose = 1,mode = "max",)
	checkpoint = ModelCheckpoint(monitor = "val_accuracy",filepath = "/content/drive/MyDrive/Capstone_data/crefv2b2mnt_adam"+str(fold_var)+".h5",verbose = 1,save_best_only = True, )
	opt = keras.optimizers.Adam(lr=0.0001)
	model.compile(loss = "binary_crossentropy", optimizer =opt, metrics = "accuracy")
	s1=train_data_generator.n//train_data_generator.batch_size
	s2=valid_data_generator.n//valid_data_generator.batch_size
	lr_sched = LearningRateScheduler(lambda epoch: 1e-4 * (0.75 ** np.floor(epoch / 2)))
	history = model.fit(train_data_generator,
    epochs = 30, 
    batch_size = 16,
    validation_data = valid_data_generator,
    validation_steps = s2,
    steps_per_epoch = s1,
    callbacks = [reduce_lr, early_stopping, checkpoint,lr_sched])
	if early_stopping.stopped_epoch==0:
		x=30
	else:
		x=early_stopping.stopped_epoch+1
	printHistory(history,"EfficientNetV2B2_Adam",x)
	modela = load_model("/content/drive/MyDrive/Capstone_data/crefv2b2mnt_adam"+str(fold_var)+".h5") 
	
	results = modela.evaluate(valid_data_generator)
	results = dict(zip(model.metrics_names,results))
	Y_pred = modela.predict_generator(valid_data_generator)
	y_pred = np.argmax(Y_pred, axis=1)
	target_names = ['Normal','Pneumonia']
	cm = confusion_matrix(valid_data_generator.classes, y_pred)
		
	print('Classification Report')
	print(classification_report(valid_data_generator.classes, y_pred, target_names=target_names))
	auc = roc_auc_score(valid_data_generator.classes, y_pred) 
	plot_roc_curve(valid_data_generator.classes, y_pred,auc)
	TRAINING_ACCURACY.append(history.history['accuracy'])
	TRAINING_LOSS.append(history.history['loss'])
	VALIDATION_ACCURACY.append(history.history['val_accuracy'])
	VALIDATION_LOSS.append(history.history['val_loss'])

	fold_var += 1
# Out:
# K-Fold1
# Found 4172 validated image filenames belonging to 2 classes.
# Found 1044 validated image filenames belonging to 2 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-b2_notop.h5
# 35839040/35839040 [==============================] - 2s 0us/step
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/30
# 260/260 [==============================] - ETA: 0s - loss: 0.7497 - accuracy: 0.7031
# Epoch 1: val_accuracy improved from -inf to 0.63558, saving model to /content/drive/MyDrive/Capstone_data/crefv2b2mnt_adam1.h5
# 260/260 [==============================] - 2032s 8s/step - loss: 0.7497 - accuracy: 0.7031 - val_loss: 0.7426 - val_accuracy: 0.6356 - lr: 1.0000e-04
# Epoch 2/30
# 260/260 [==============================] - ETA: 0s - loss: 0.5734 - accuracy: 0.7996
# Epoch 2: val_accuracy improved from 0.63558 to 0.71827, saving model to /content/drive/MyDrive/Capstone_data/crefv2b2mnt_adam1.h5
# 260/260 [==============================] - 114s 439ms/step - loss: 0.5734 - accuracy: 0.7996 - val_loss: 0.9987 - val_accuracy: 0.7183 - lr: 1.0000e-04
# Epoch 3/30
# 260/260 [==============================] - ETA: 0s - loss: 0.4590 - accuracy: 0.8559
# Epoch 3: val_accuracy improved from 0.71827 to 0.92404, saving model to /content/drive/MyDrive/Capstone_data/crefv2b2mnt_adam1.h5
# 260/260 [==============================] - 115s 443ms/step - loss: 0.4590 - accuracy: 0.8559 - val_loss: 0.2986 - val_accuracy: 0.9240 - lr: 7.5000e-05
# Epoch 4/30
# 260/260 [==============================] - ETA: 0s - loss: 0.4173 - accuracy: 0.8621
# Epoch 4: val_accuracy improved from 0.92404 to 0.93558, saving model to /content/drive/MyDrive/Capstone_data/crefv2b2mnt_adam1.h5
# 260/260 [==============================] - 115s 440ms/step - loss: 0.4173 - accuracy: 0.8621 - val_loss: 0.2817 - val_accuracy: 0.9356 - lr: 7.5000e-05
# Epoch 5/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3729 - accuracy: 0.8770
# Epoch 5: val_accuracy did not improve from 0.93558
# 260/260 [==============================] - 112s 431ms/step - loss: 0.3729 - accuracy: 0.8770 - val_loss: 0.4983 - val_accuracy: 0.8933 - lr: 5.6250e-05
# Epoch 6/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3516 - accuracy: 0.8917
# Epoch 6: val_accuracy improved from 0.93558 to 0.93654, saving model to /content/drive/MyDrive/Capstone_data/crefv2b2mnt_adam1.h5
# 260/260 [==============================] - 113s 435ms/step - loss: 0.3516 - accuracy: 0.8917 - val_loss: 0.2275 - val_accuracy: 0.9365 - lr: 5.6250e-05
# Epoch 7/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3560 - accuracy: 0.8822
# Epoch 7: val_accuracy did not improve from 0.93654
# 260/260 [==============================] - 119s 458ms/step - loss: 0.3560 - accuracy: 0.8822 - val_loss: 0.2654 - val_accuracy: 0.9231 - lr: 4.2188e-05
# Epoch 8/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3373 - accuracy: 0.8891
# Epoch 8: val_accuracy did not improve from 0.93654
# 260/260 [==============================] - 112s 430ms/step - loss: 0.3373 - accuracy: 0.8891 - val_loss: 0.2224 - val_accuracy: 0.9365 - lr: 4.2188e-05
# Epoch 9/30
# 260/260 [==============================] - ETA: 0s - loss: 0.
val_accuracy did not improve from 0.95865
# 260/260 [==============================] - 110s 423ms/step - loss: 0.2726 - accuracy: 0.9052 - val_loss: 0.2036 - val_accuracy: 0.9356 - lr: 7.5085e-06
# Epoch 19: early stopping
# 66/66 [==============================] - 15s 198ms/step - loss: 0.1606 - accuracy: 0.9588
# <ipython-input-21-c76f7e09d4cd>:58: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   Y_pred = modela.predict_generator(valid_data_generator)
# Classification Report
#               precision    recall  f1-score   support
#
#       Normal       0.88      0.97      0.92       268
#    Pneumonia       0.99      0.96      0.97       775
#
#     accuracy                           0.96      1043
#    macro avg       0.94      0.96      0.95      1043
# weighted avg       0.96      0.96      0.96      1043
# K-Fold4
# Found 4173 validated image filenames belonging to 2 classes.
# Found 1043 validated image filenames belonging to 2 classes.
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/30
# 260/260 [==============================] - ETA: 0s - loss: 0.7798 - accuracy: 0.6856
# Epoch 1: val_accuracy improved from -inf to 0.81154, saving model to /content/drive/MyDrive/Capstone_data/crefv2b2mnt_adam4.h5
# 260/260 [==============================] - 160s 443ms/step - loss: 0.7798 - accuracy: 0.6856 - val_loss: 0.4589 - val_accuracy: 0.8115 - lr: 1.0000e-04
# Epoch 2/30
# 260/260 [==============================] - ETA: 0s - loss: 0.5851 - accuracy: 0.7871
# Epoch 2: val_accuracy improved from 0.81154 to 0.83750, saving model to /content/drive/MyDrive/Capstone_data/crefv2b2mnt_adam4.h5
# 260/260 [==============================] - 112s 431ms/step - loss: 0.5851 - accuracy: 0.7871 - val_loss: 0.6430 - val_accuracy: 0.8375 - lr: 1.0000e-04
# Epoch 3/30
# 260/260 [==============================] - ETA: 0s - loss: 0.4756 - accuracy: 0.8436
# Epoch 3: val_accuracy improved from 0.83750 to 0.90673, saving model to /content/drive/MyDrive/Capstone_data/crefv2b2mnt_adam4.h5
# 260/260 [==============================] - 112s 429ms/step - loss: 0.4756 - accuracy: 0.8436 - val_loss: 0.3746 - val_accuracy: 0.9067 - lr: 7.5000e-05
# Epoch 4/30
# 260/260 [==============================] - ETA: 0s - loss: 0.4096 - accuracy: 0.8655
# Epoch 4: val_accuracy improved from 0.90673 to 0.91827, saving model to /content/drive/MyDrive/Capstone_data/crefv2b2mnt_adam4.h5
# 260/260 [==============================] - 113s 434ms/step - loss: 0.4096 - accuracy: 0.8655 - val_loss: 0.3061 - val_accuracy: 0.9183 - lr: 7.5000e-05
# Epoch 5/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3618 - accuracy: 0.8778
# Epoch 5: val_accuracy improved from 0.91827 to 0.92404, saving model to /content/drive/MyDrive/Capstone_data/crefv2b2mnt_adam4.h5
# 260/260 [==============================] - 112s 431ms/step - loss: 0.3618 - accuracy: 0.8778 - val_loss: 0.3404 - val_accuracy: 0.9240 - lr: 5.6250e-05
# Epoch 6/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3599 - accuracy: 0.8833
# Epoch 6: val_accuracy did not improve from 0.92404
# 260/260 [==============================] - 110s 423ms/step - loss: 0.3599 - accuracy: 0.8833 - val_loss: 0.3460 - val_accuracy: 0.9106 - lr: 5.6250e-05
# Epoch 7/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3273 - accuracy: 0.8905
# Epoch 7: val_accuracy did not improve from 0.92404
# 260/260 [==============================] - 110s 422ms/step - loss: 0.3273 - accuracy: 0.8905 - val_loss: 0.2892 - val_accuracy: 0.9183 - lr: 4.2188e-05
# Epoch 8/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3162 - accuracy: 0.8961
# Epoch 8: val_accuracy did not improve from 0.92404
# 260/260 [==============================] - 111s 425ms/step - loss: 0.3162 - accuracy: 0.8961 - val_loss: 0.5115 - val_accuracy: 0.8885 - lr: 4.2188e-05
# Epoch 9/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3100 - accuracy: 0.8958
# Epoch 9: val_accuracy improved from 0.92404 to 0.94135, saving model to /content/drive/MyDrive/Capstone_data/crefv2b2mnt_adam4.h5
# 260/260 [==============================] - 113s 434ms/step - loss: 0.3100 - accuracy: 0.8958 - val_loss: 0.2401 - val_accuracy: 0.9413 - lr: 3.1641e-05
# Epoch 10/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2912 - accuracy: 0.9019
# Epoch 10: val_accuracy did not improve from 0.94135
# 260/260 [==============================] - 111s 427ms/step - loss: 0.2912 - accuracy: 0.9019 - val_loss: 0.3933 - val_accuracy: 0.9096 - lr: 3.1641e-05
# Epoch 11/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2787 - accuracy: 0.9081
# Epoch 11: val_accuracy did not improve from 0.94135
# 260/260 [==============================] - 111s 428ms/step - loss: 0.2787 - accuracy: 0.9081 - val_loss: 0.3253 - val_accuracy: 0.9250 - lr: 2.3730e-05
# Epoch 12/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2733 - accuracy: 0.9117
# Epoch 12: val_accuracy did not improve from 0.94135
# 260/260 [==============================] - 111s 429ms/step - loss: 0.2733 - accuracy: 0.9117 - val_loss: 0.2880 - val_accuracy: 0.9298 - lr: 2.3730e-05
# Epoch 13/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2586 - accuracy: 0.9144
# Epoch 13: val_accuracy did not improve from 0.94135
# 260/260 [==============================] - 110s 421ms/step - loss: 0.2586 - accuracy: 0.9144 - val_loss: 0.2436 - val_accuracy: 0.9356 - lr: 1.7798e-05
# Epoch 14/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2493 - accuracy: 0.9160
# Epoch 14: val_accuracy did not improve from 0.94135
# 260/260 [==============================] - 109s 421ms/step - loss: 0.2493 - accuracy: 0.9160 - val_loss: 0.3992 - val_accuracy: 0.9106 - lr: 1.7798e-05
# Epoch 15/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2464 - accuracy: 0.9139
# Epoch 15: val_accuracy did not improve from 0.94135
# 260/260 [==============================] - 109s 420ms/step - loss: 0.2464 - accuracy: 0.9139 - val_loss: 0.3091 - val_accuracy: 0.9221 - lr: 1.3348e-05
# Epoch 16/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2577 - accuracy: 0.9163
# Epoch 16: val_accuracy did not improve from 0.94135
# 260/260 [==============================] - 109s 420ms/step - loss: 0.2577 - accuracy: 0.9163 - val_loss: 0.2504 - val_accuracy: 0.9327 - lr: 1.3348e-06
# Epoch 17/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2531 - accuracy: 0.9187
# Epoch 17: val_accuracy did not improve from 0.94135
# 260/260 [==============================] - 110s 422ms/step - loss: 0.2531 - accuracy: 0.9187 - val_loss: 0.2066 - val_accuracy: 0.9404 - lr: 1.0011e-05
# Epoch 18/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2390 - accuracy: 0.9225
# Epoch 18: val_accuracy improved from 0.94135 to 0.94231, saving model to /content/drive/MyDrive/Capstone_data/crefv2b2mnt_adam4.h5
# 260/260 [==============================] - 112s 431ms/step - loss: 0.2390 - accuracy: 0.9225 - val_loss: 0.2036 - val_accuracy: 0.9423 - lr: 1.0011e-05
# Epoch 19/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2349 - accuracy: 0.9204
# Epoch 19: val_accuracy improved from 0.94231 to 0.94615, saving model to /content/drive/MyDrive/Capstone_data/crefv2b2mnt_adam4.h5
# 260/260 [==============================] - 112s 432ms/step - loss: 0.2349 - accuracy: 0.9204 - val_loss: 0.1933 - val_accuracy: 0.9462 - lr: 7.5085e-06
# Epoch 20/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2320 - accuracy: 0.9221
# Epoch 20: val_accuracy improved from 0.94615 to 0.94904, saving model to /content/drive/MyDrive/Capstone_data/crefv2b2mnt_adam4.h5
# 260/260 [==============================] - 112s 429ms/step - loss: 0.2320 - accuracy: 0.9221 - val_loss: 0.1788 - val_accuracy: 0.9490 - lr: 7.5085e-06
# Epoch 21/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2248 - accuracy: 0.9235
# Epoch 21: val_accuracy did not improve from 0.94904
# 260/260 [==============================] - 109s 421ms/step - loss: 0.2248 - accuracy: 0.9235 - val_loss: 0.3077 - val_accuracy: 0.9308 - lr: 5.6314e-06
# Epoch 22/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2374 - accuracy: 0.9172
# Epoch 22: val_accuracy did not improve from 0.94904
# 260/260 [==============================] - 109s 418ms/step - loss: 0.2374 - accuracy: 0.9172 - val_loss: 0.2448 - val_accuracy: 0.9356 - lr: 5.6314e-06
# Epoch 23/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2302 - accuracy: 0.9194
# Epoch 23: val_accuracy did not improve from 0.94904
# 260/260 [==============================] - 109s 420ms/step - loss: 0.2302 - accuracy: 0.9194 - val_loss: 0.2398 - val_accuracy: 0.9346 - lr: 4.2235e-06
# Epoch 24/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2164 - accuracy: 0.9257
# Epoch 24: val_accuracy did not improve from 0.94904
# 260/260 [==============================] - 112s 431ms/step - loss: 0.2164 - accuracy: 0.9257 - val_loss: 0.3370 - val_accuracy: 0.9202 - lr: 4.2235e-06
# Epoch 25/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2308 - accuracy: 0.9228
# Epoch 25: val_accuracy did not improve from 0.94904
# 260/260 [==============================] - 110s 421ms/step - loss: 0.2308 - accuracy: 0.9228 - val_loss: 0.2595 - val_accuracy: 0.9356 - lr: 3.1676e-06
# Epoch 26/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2257 - accuracy: 0.9230
# Epoch 26: val_accuracy did not improve from 0.94904
# 260/260 [==============================] - 109s 421ms/step - loss: 0.2257 - accuracy: 0.9230 - val_loss: 0.3143 - val_accuracy: 0.9250 - lr: 3.1676e-06
# Epoch 27/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2309 - accuracy: 0.9240
# Epoch 27: val_accuracy did not improve from 0.94904
# 260/260 [==============================] - 109s 418ms/step - loss: 0.2309 - accuracy: 0.9240 - val_loss: 0.3524 - val_accuracy: 0.9183 - lr: 2.3757e-07
# Epoch 28/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2218 - accuracy: 0.9209
# Epoch 28: val_accuracy did not improve from 0.94904
# 260/260 [==============================] - 109s 419ms/step - loss: 0.2218 - accuracy: 0.9209 - val_loss: 0.3141 - val_accuracy: 0.9231 - lr: 2.3757e-06
# Epoch 29/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2423 - accuracy: 0.9168
# Epoch 29: val_accuracy did not improve from 0.94904
# 260/260 [==============================] - 110s 424ms/step - loss: 0.2423 - accuracy: 0.9168 - val_loss: 0.3431 - val_accuracy: 0.9260 - lr: 1.7818e-06
# Epoch 29: early stopping
# 66/66 [==============================] - 15s 195ms/step - loss: 0.1786 - accuracy: 0.9492
# <ipython-input-21-c76f7e09d4cd>:58: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   Y_pred = modela.predict_generator(valid_data_generator)
# Classification Report
#               precision    recall  f1-score   support
#
#       Normal       0.88      0.93      0.90       268
#    Pneumonia       0.98      0.95      0.97       775
#
#     accuracy                           0.95      1043
#    macro avg       0.93      0.94      0.93      1043
# weighted avg       0.95      0.95      0.95      1043
# K-Fold5
# Found 4173 validated image filenames belonging to 2 classes.
# Found 1043 validated image filenames belonging to 2 classes.
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/30
# 260/260 [==============================] - ETA: 0s - loss: 0.7478 - accuracy: 0.6829
# Epoch 1: val_accuracy improved from -inf to 0.70288, saving model to /content/drive/MyDrive/Capstone_data/crefv2b2mnt_adam5.h5
# 260/260 [==============================] - 159s 441ms/step - loss: 0.7478 - accuracy: 0.6829 - val_loss: 0.6653 - val_accuracy: 0.7029 - lr: 1.0000e-04
# Epoch 2/30
# 260/260 [==============================] - ETA: 0s - loss: 0.5573 - accuracy: 0.8001
# Epoch 2: val_accuracy improved from 0.70288 to 0.82981, saving model to /content/drive/MyDrive/Capstone_data/crefv2b2mnt_adam5.h5
# 260/260 [==============================] - 112s 431ms/step - loss: 0.5573 - accuracy: 0.8001 - val_loss: 0.7338 - val_accuracy: 0.8298 - lr: 1.0000e-04
# Epoch 3/30
# 260/260 [==============================] - ETA: 0s - loss: 0.4702 - accuracy: 0.8422
# Epoch 3: val_accuracy improved from 0.82981 to 0.90385, saving model to /content/drive/MyDrive/Capstone_data/crefv2b2mnt_adam5.h5
# 260/260 [==============================] - 111s 427ms/step - loss: 0.4702 - accuracy: 0.8422 - val_loss: 0.3090 - val_accuracy: 0.9038 - lr: 7.5000e-05
# Epoch 4/30
# 260/260 [==============================] - ETA: 0s - loss: 0.4326 - accuracy: 0.8590
# Epoch 4: val_accuracy did not improve from 0.90385
# 260/260 [==============================] - 110s 421ms/step - loss: 0.4326 - accuracy: 0.8590 - val_loss: 0.7415 - val_accuracy: 0.8288 - lr: 7.5000e-05
# Epoch 5/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3890 - accuracy: 0.8660
# Epoch 5: val_accuracy did not improve from 0.90385
# 260/260 [==============================] - 109s 418ms/step - loss: 0.3890 - accuracy: 0.8660 - val_loss: 0.3523 - val_accuracy: 0.8923 - lr: 5.6250e-05
# Epoch 6/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3498 - accuracy: 0.8872
# Epoch 6: val_accuracy did not improve from 0.90385
# 260/260 [==============================] - 109s 419ms/step - loss: 0.3498 - accuracy: 0.8872 - val_loss: 0.3318 - val_accuracy: 0.8923 - lr: 5.6250e-05
# Epoch 7/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3478 - accuracy: 0.8821
# Epoch 7: val_accuracy did not improve from 0.90385
# 260/260 [==============================] - 110s 422ms/step - loss: 0.3478 - accuracy: 0.8821 - val_loss: 0.3805 - val_accuracy: 0.8904 - lr: 4.2188e-05
# Epoch 8/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3189 - accuracy: 0.8913
# Epoch 8: val_accuracy did not improve from 0.90385
# 260/260 [==============================] - 111s 425ms/step - loss: 0.3189 - accuracy: 0.8913 - val_loss: 0.4198 - val_accuracy: 0.8894 - lr: 4.2188e-05
# Epoch 9/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3128 - accuracy: 0.8927
# Epoch 9: val_accuracy did not improve from 0.90385
# 260/260 [==============================] - 109s 417ms/step - loss: 0.3128 - accuracy: 0.8927 - val_loss: 0.3310 - val_accuracy: 0.8952 - lr: 3.1641e-05
# Epoch 10/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2927 - accuracy: 0.9062
# Epoch 10: val_accuracy improved from 0.90385 to 0.92788, saving model to /content/drive/MyDrive/Capstone_data/crefv2b2mnt_adam5.h5
# 260/260 [==============================] - 112s 430ms/step - loss: 0.2927 - accuracy: 0.9062 - val_loss: 0.2174 - val_accuracy: 0.9279 - lr: 3.1641e-05
# Epoch 11/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2700 - accuracy: 0.9081
# Epoch 11: val_accuracy improved from 0.92788 to 0.93750, saving model to /content/drive/MyDrive/Capstone_data/crefv2b2mnt_adam5.h5
# 260/260 [==============================] - 111s 428ms/step - loss: 0.2700 - accuracy: 0.9081 - val_loss: 0.1844 - val_accuracy: 0.9375 - lr: 2.3730e-05
# Epoch 12/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2800 - accuracy: 0.9069
# Epoch 12: val_accuracy did not improve from 0.93750
# 260/260 [==============================] - 109s 419ms/step - loss: 0.2800 - accuracy: 0.9069 - val_loss: 0.3105 - val_accuracy: 0.9096 - lr: 2.3730e-05
# Epoch 13/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2773 - accuracy: 0.9019
# Epoch 13: val_accuracy did not improve from 0.93750
# 260/260 [==============================] - 109s 420ms/step - loss: 0.2773 - accuracy: 0.9019 - val_loss: 0.2670 - val_accuracy: 0.9183 - lr: 1.7798e-05
# Epoch 14/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2679 - accuracy: 0.9158
# Epoch 14: val_accuracy did not improve from 0.93750
# 260/260 [==============================] - 110s 421ms/step - loss: 0.2679 - accuracy: 0.9158 - val_loss: 0.2836 - val_accuracy: 0.9135 - lr: 1.7798e-05
# Epoch 15/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2464 - accuracy: 0.9158
# Epoch 15: val_accuracy did not improve from 0.93750
# 260/260 [==============================] - 109s 418ms/step - loss: 0.2464 - accuracy: 0.9158 - val_loss: 0.2806 - val_accuracy: 0.9125 - lr: 1.3348e-05
# Epoch 16/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2414 - accuracy: 0.9221
# Epoch 16: val_accuracy did not improve from 0.93750
# 260/260 [==============================] - 109s 419ms/step - loss: 0.2414 - accuracy: 0.9221 - val_loss: 0.2693 - val_accuracy: 0.9163 - lr: 1.3348e-05
# Epoch 17/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2456 - accuracy: 0.9175
# Epoch 17: val_accuracy did not improve from 0.93750
# 260/260 [==============================] - 109s 421ms/step - loss: 0.2456 - accuracy: 0.9175 - val_loss: 0.2105 - val_accuracy: 0.9269 - lr: 1.0011e-05
# Epoch 18/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2497 - accuracy: 0.9180
# Epoch 18: val_accuracy did not improve from 0.93750
# 260/260 [==============================] - 109s 421ms/step - loss: 0.2497 - accuracy: 0.9180 - val_loss: 0.2278 - val_accuracy: 0.9202 - lr: 1.0011e-06
# Epoch 19/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2377 - accuracy: 0.9192
# Epoch 19: val_accuracy did not improve from 0.93750
# 260/260 [==============================] - 109s 418ms/step - loss: 0.2377 - accuracy: 0.9192 - val_loss: 0.2231 - val_accuracy: 0.9279 - lr: 7.5085e-06
# Epoch 20/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2336 - accuracy: 0.9209
# Epoch 20: val_accuracy did not improve from 0.93750
# 260/260 [==============================] - 110s 421ms/step - loss: 0.2336 - accuracy: 0.9209 - val_loss: 0.1979 - val_accuracy: 0.9337 - lr: 7.5085e-06
# Epoch 20: early stopping
# 66/66 [==============================] - 15s 196ms/step - loss: 0.1839 - accuracy: 0.9377
# <ipython-input-21-c76f7e09d4cd>:58: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   Y_pred = modela.predict_generator(valid_data_generator)
# Classification Report
#               precision    recall  f1-score   support
#
#       Normal       0.82      0.96      0.89       268
#    Pneumonia       0.99      0.93      0.96       775
#
#     accuracy                           0.94      1043
#    macro avg       0.91      0.95      0.92      1043
# weighted avg       0.94      0.94      0.94      1043

# %%
l1=max(VALIDATION_ACCURACY[0])
l2=max(VALIDATION_ACCURACY[1])
l3=max(VALIDATION_ACCURACY[2])
l4=max(VALIDATION_ACCURACY[3])
l5=max(VALIDATION_ACCURACY[4])

avg=(l1+l2+l3+l4+l5)/5
avg
# Out:
# 0.9463461518287659
