# %%
import keras
import tensorflow as tf
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten,Conv2D
from keras.models import Model
from keras import backend as K
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np
import cv2
import sklearn
import os
import seaborn as sns
from google.colab.patches import cv2_imshow
import glob
import keras
from keras.models import Sequential
from tensorflow.python.keras.layers import Dense, Flatten, GlobalAveragePooling2D, Activation, Flatten, Dropout
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import callbacks
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam, SGD

# %%
seed = 10

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
 batch_size=16

# %%
train_path="/content/drive/MyDrive/Capstone_data/Clahe_train"
test_path="/content/drive/MyDrive/Capstone_data/Clahe_test"
val_path="/content/drive/MyDrive/Capstone_data/Clahe_val"

# %%
train_normal = glob.glob(train_path+"/normal/*.jpeg")
train_pneumonia = glob.glob(train_path+"/pneumonia/*.jpeg")

test_normal = glob.glob(test_path+"/normal/*.jpeg")
test_pneumonia = glob.glob(test_path+"/pneumonia/*.jpeg")

val_normal = glob.glob(val_path+"/normal/*.jpeg")
val_pneumonia = glob.glob(val_path+"/pneumonia/*.jpeg")

# %%
train_list = [x for x in train_normal]
train_list.extend([x for x in train_pneumonia])

df_train = pd.DataFrame(np.concatenate([['Normal']*len(train_normal) , ['Pneumonia']*len(train_pneumonia)]), columns = ['class'])
df_train['image'] = [x for x in train_list]

test_list = [x for x in test_normal]
test_list.extend([x for x in test_pneumonia])

df_test = pd.DataFrame(np.concatenate([['Normal']*len(test_normal) , ['Pneumonia']*len(test_pneumonia)]), columns = ['class'])
df_test['image'] = [x for x in test_list]

val_list = [x for x in val_normal]
val_list.extend([x for x in val_pneumonia])

df_val = pd.DataFrame(np.concatenate([['Normal']*len(val_normal) , ['Pneumonia']*len(val_pneumonia)]), columns = ['class'])
df_val['image'] = [x for x in val_list]

# %%
df_train.head()
df_test.head()
df_val.head()
# Out:
#     class                                              image
# 0  Normal  /content/drive/MyDrive/Capstone_data/Clahe_val...
# 1  Normal  /content/drive/MyDrive/Capstone_data/Clahe_val...
# 2  Normal  /content/drive/MyDrive/Capstone_data/Clahe_val...
# 3  Normal  /content/drive/MyDrive/Capstone_data/Clahe_val...
# 4  Normal  /content/drive/MyDrive/Capstone_data/Clahe_val...

# %%
df_train=df_train.sample(frac=1)

# %%
df_train.head()
# Out:
#           class                                              image
# 973      Normal  /content/drive/MyDrive/Capstone_data/Clahe_tra...
# 685      Normal  /content/drive/MyDrive/Capstone_data/Clahe_tra...
# 2908  Pneumonia  /content/drive/MyDrive/Capstone_data/Clahe_tra...
# 2396  Pneumonia  /content/drive/MyDrive/Capstone_data/Clahe_tra...
# 1337     Normal  /content/drive/MyDrive/Capstone_data/Clahe_tra...

# %%
from sklearn.model_selection import KFold, StratifiedKFold
Y = df_train[['class']]

kf = KFold(n_splits = 5)
                         
skf = StratifiedKFold(n_splits = 5, random_state = 7, shuffle = True)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator ,load_img,img_to_array

train_datagen = ImageDataGenerator(
        rescale = 1./255,
        shear_range=10,
        zoom_range=0.3,
        horizontal_flip=True,
        vertical_flip=True,
        brightness_range=[0.5,2.0],
        width_shift_range = 0.2,
        rotation_range=20,
        fill_mode = 'nearest',
)
test_datagen = ImageDataGenerator(
        rescale = 1./255)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Input, Flatten, SeparableConv2D
from tensorflow.keras.layers import GlobalMaxPooling2D,GlobalAveragePooling2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from tensorflow.keras.callbacks import ModelCheckpoint, Callback, EarlyStopping
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.applications import ResNet50, InceptionV3, EfficientNetV2B1
from tensorflow.keras.layers.experimental.preprocessing import Normalization

# %%
df_train.shape
n=5216

# %%
x=len(train_normal)
y=len(train_pneumonia)
s1=(x+y)//batch_size
a=len(test_normal)
b=len(test_pneumonia)
s2=(a+b)//batch_size

# %%
from keras.callbacks import ReduceLROnPlateau
import numpy as np
from keras.callbacks import LearningRateScheduler
from tensorflow.keras.models import load_model
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix ,classification_report
import numpy as np

# %%
from tensorflow import keras
from keras import optimizers
import matplotlib.pyplot as plt

# %%
def printHistory(history, title, epochs):
    f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
    t = f.suptitle(title, fontsize=12)
    f.subplots_adjust(top=0.85, wspace=0.3)

    epoch_list = list(range(1,epochs+1))
    ax1.plot(epoch_list, history.history['accuracy'], label='Train Accuracy')
    ax1.plot(epoch_list, history.history['val_accuracy'], label='Validation Accuracy')
    ax1.set_xticks(np.arange(0, epochs+1, 5))
    ax1.set_ylabel('Accuracy Value')
    ax1.set_xlabel('Epoch')
    ax1.set_title('Accuracy')
    l1 = ax1.legend(loc="best")

    ax2.plot(epoch_list, history.history['loss'], label='Train Loss')
    ax2.plot(epoch_list, history.history['val_loss'], label='Validation Loss')
    ax2.set_xticks(np.arange(0, epochs+1, 5))
    ax2.set_ylabel('Loss Value')
    ax2.set_xlabel('Epoch')
    ax2.set_title('Loss')
    l2 = ax2.legend(loc="best")

# %%
from sklearn.metrics import roc_curve, roc_auc_score
def plot_roc_curve(predictions, labels,auc):
    fpr, tpr, thresholds = roc_curve(labels, predictions) 
    plt.title('Receiver Operating Characteristic (ROC)  Curve',fontsize=14)
    plt.xlim([0, 1])
    plt.ylim([0, 1])
    plt.plot(fpr, tpr, 'g',label = 'AUC Score = %0.2f' % auc)
    plt.plot([0, 1], [0, 1],'r--')
    plt.ylabel('\nTrue Positive Rate (TPR)', fontsize=12)
    plt.xlabel('\nFalse Positive Rate (FPR)', fontsize=12)
    plt.legend()
    plt.grid()
    plt.show()

# %%
def conf(cm,target_names):
    plt.figure(figsize=(5,3))
    sns.set(font_scale=1.2)
    ax = sns.heatmap(cm, annot=True,xticklabels=['H', 'P'], yticklabels=['H', 'P'], cbar=False, cmap='Blues',linewidths=1, linecolor='black', fmt='.0f')
    plt.yticks(rotation=0)
    plt.xlabel('Predicted labels')
    plt.ylabel('True labels')
    ax.xaxis.set_ticks_position('top') 
    plt.title('Confusion matrix')
    plt.show()

# %%
VALIDATION_ACCURACY = []
VALIDATION_LOSS = []
TRAINING_ACCURACY=[]
TRAINING_LOSS=[]

save_dir = '/content/drive/MyDrive/Capstone_data/Clahe_train'
fold_var=1
fine_tune_at=30
t=df_train[['class']]
for train_index, val_index in skf.split(np.zeros(len(Y)),Y):
	print("K-Fold"+str(fold_var))
	training_data = df_train.iloc[train_index]
	validation_data = df_train.iloc[val_index]
	
	train_data_generator = train_datagen.flow_from_dataframe(dataframe=training_data,x_col="image",y_col="class",target_size=(224,224),
                                               batch_size=16,class_mode='categorical',shuffle=True)
	valid_data_generator  = test_datagen.flow_from_dataframe(dataframe=validation_data,x_col="image",y_col="class",target_size=(224,224),
                                               batch_size=16,class_mode='categorical',shuffle=False)
        
 	# CREATE NEW MODEL
	model = Sequential()
	conv_base = EfficientNetV2B1(input_shape=[224,224]+[3], include_top=False, weights='imagenet')
	for layer in conv_base.layers[:fine_tune_at]:
		layer.trainable = False
	x=  conv_base.output
	x = GlobalAveragePooling2D()(x)
	x = BatchNormalization()(x)
	x = Dropout(0.3)(x) 
	x = Dense(512, activation ='relu')(x)
	x = BatchNormalization()(x)
	x = Dropout(0.5)(x)
	x = Dense(2, activation ='sigmoid')(x)
	model = Model(conv_base.input, x)
	reduce_lr = ReduceLROnPlateau(monitor='val_loss',patience=7)
	early_stopping = EarlyStopping(monitor = "val_accuracy",patience = 9,verbose = 1,mode = "max",)
	checkpoint = ModelCheckpoint(monitor = "val_accuracy",filepath = "/content/drive/MyDrive/Capstone_data/crefv2b1mnt_rms"+str(fold_var)+".h5",verbose = 1,save_best_only = True, )
	opt = keras.optimizers.RMSprop(lr=0.0001)
	model.compile(loss = "binary_crossentropy", optimizer =opt, metrics = "accuracy")
	s1=train_data_generator.n//train_data_generator.batch_size
	s2=valid_data_generator.n//valid_data_generator.batch_size
	lr_sched = LearningRateScheduler(lambda epoch: 1e-4 * (0.75 ** np.floor(epoch / 2)))
	history = model.fit(train_data_generator,
    epochs = 30, 
    batch_size = 16,
    validation_data = valid_data_generator,
    validation_steps = s2,
    steps_per_epoch = s1,
    callbacks = [reduce_lr, early_stopping, checkpoint,lr_sched])
	if early_stopping.stopped_epoch==0:
		x=30
	else:
		x=early_stopping.stopped_epoch+1
	printHistory(history,"EfficientNetV2B1_RMSProp",x)
	modela = load_model("/content/drive/MyDrive/Capstone_data/crefv2b1mnt_rms"+str(fold_var)+".h5") 
	
	results = modela.evaluate(valid_data_generator)
	results = dict(zip(model.metrics_names,results))
	Y_pred = modela.predict_generator(valid_data_generator)
	y_pred = np.argmax(Y_pred, axis=1)
	target_names = ['Normal','Pneumonia']
	cm = confusion_matrix(valid_data_generator.classes, y_pred)
	conf(cm,target_names)
	print('Classification Report')
	print(classification_report(valid_data_generator.classes, y_pred, target_names=target_names))
	auc = roc_auc_score(valid_data_generator.classes, y_pred) 
	plot_roc_curve(valid_data_generator.classes, y_pred,auc)
	TRAINING_ACCURACY.append(history.history['accuracy'])
	TRAINING_LOSS.append(history.history['loss'])
	VALIDATION_ACCURACY.append(history.history['val_accuracy'])
	VALIDATION_LOSS.append(history.history['val_loss'])

	fold_var += 1
# Out:
# K-Fold1
# Found 4172 validated image filenames belonging to 2 classes.
# Found 1044 validated image filenames belonging to 2 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-b1_notop.h5
# 28456008/28456008 [==============================] - 2s 0us/step
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.RMSprop.
# Epoch 1/30
# 260/260 [==============================] - ETA: 0s - loss: 0.7846 - accuracy: 0.6756
# Epoch 1: val_accuracy improved from -inf to 0.62885, saving model to /content/drive/MyDrive/Capstone_data/crefv2b1mnt_rms1.h5
# 260/260 [==============================] - 1127s 4s/step - loss: 0.7846 - accuracy: 0.6756 - val_loss: 0.7161 - val_accuracy: 0.6288 - lr: 1.0000e-04
# Epoch 2/30
# 260/260 [==============================] - ETA: 0s - loss: 0.5748 - accuracy: 0.8010
# Epoch 2: val_accuracy improved from 0.62885 to 0.88558, saving model to /content/drive/MyDrive/Capstone_data/crefv2b1mnt_rms1.h5
# 260/260 [==============================] - 111s 426ms/step - loss: 0.5748 - accuracy: 0.8010 - val_loss: 0.3234 - val_accuracy: 0.8856 - lr: 1.0000e-04
# Epoch 3/30
# 260/260 [==============================] - ETA: 0s - loss: 0.5105 - accuracy: 0.8215
# Epoch 3: val_accuracy did not improve from 0.88558
# 260/260 [==============================] - 108s 416ms/step - loss: 0.5105 - accuracy: 0.8215 - val_loss: 0.7283 - val_accuracy: 0.8519 - lr: 7.5000e-05
# Epoch 4/30
# 260/260 [==============================] - ETA: 0s - loss: 0.4426 - accuracy: 0.8554
# Epoch 4: val_accuracy did not improve from 0.88558
# 260/260 [==============================] - 108s 415ms/step - loss: 0.4426 - accuracy: 0.8554 - val_loss: 0.7268 - val_accuracy: 0.8317 - lr: 7.5000e-05
# Epoch 5/30
# 260/260 [==============================] - ETA: 0s - loss: 0.4143 - accuracy: 0.8636
# Epoch 5: val_accuracy improved from 0.88558 to 0.91731, saving model to /content/drive/MyDrive/Capstone_data/crefv2b1mnt_rms1.h5
# 260/260 [==============================] - 110s 424ms/step - loss: 0.4143 - accuracy: 0.8636 - val_loss: 0.3109 - val_accuracy: 0.9173 - lr: 5.6250e-05
# Epoch 6/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3791 - accuracy: 0.8778
# Epoch 6: val_accuracy improved from 0.91731 to 0.92981, saving model to /content/drive/MyDrive/Capstone_data/crefv2b1mnt_rms1.h5
# 260/260 [==============================] - 110s 423ms/step - loss: 0.3791 - accuracy: 0.8778 - val_loss: 0.2664 - val_accuracy: 0.9298 - lr: 5.6250e-05
# Epoch 7/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3554 - accuracy: 0.8850
# Epoch 7: val_accuracy improved from 0.92981 to 0.94519, saving model to /content/drive/MyDrive/Capstone_data/crefv2b1mnt_r
val_accuracy did not improve from 0.95096
# 260/260 [==============================] - 110s 421ms/step - loss: 0.2761 - accuracy: 0.9071 - val_loss: 0.2523 - val_accuracy: 0.9250 - lr: 4.2235e-06
# Epoch 24/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2769 - accuracy: 0.9074
# Epoch 24: val_accuracy did not improve from 0.95096
# 260/260 [==============================] - 109s 418ms/step - loss: 0.2769 - accuracy: 0.9074 - val_loss: 0.2728 - val_accuracy: 0.9212 - lr: 4.2235e-06
# Epoch 25/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2493 - accuracy: 0.9134
# Epoch 25: val_accuracy did not improve from 0.95096
# 260/260 [==============================] - 109s 420ms/step - loss: 0.2493 - accuracy: 0.9134 - val_loss: 0.2516 - val_accuracy: 0.9298 - lr: 3.1676e-06
# Epoch 26/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2562 - accuracy: 0.9139
# Epoch 26: val_accuracy did not improve from 0.95096
# 260/260 [==============================] - 109s 420ms/step - loss: 0.2562 - accuracy: 0.9139 - val_loss: 0.2698 - val_accuracy: 0.9298 - lr: 3.1676e-07
# Epoch 27/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2529 - accuracy: 0.9177
# Epoch 27: val_accuracy did not improve from 0.95096
# 260/260 [==============================] - 117s 450ms/step - loss: 0.2529 - accuracy: 0.9177 - val_loss: 0.2378 - val_accuracy: 0.9298 - lr: 2.3757e-06
# Epoch 28/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2650 - accuracy: 0.9112
# Epoch 28: val_accuracy did not improve from 0.95096
# 260/260 [==============================] - 109s 420ms/step - loss: 0.2650 - accuracy: 0.9112 - val_loss: 0.2165 - val_accuracy: 0.9365 - lr: 2.3757e-06
# Epoch 28: early stopping
# 66/66 [==============================] - 15s 204ms/step - loss: 0.1817 - accuracy: 0.9492
# <ipython-input-21-036ed5fc9d65>:58: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   Y_pred = modela.predict_generator(valid_data_generator)
# Classification Report
#               precision    recall  f1-score   support
#
#       Normal       0.86      0.95      0.91       268
#    Pneumonia       0.98      0.95      0.97       775
#
#     accuracy                           0.95      1043
#    macro avg       0.92      0.95      0.94      1043
# weighted avg       0.95      0.95      0.95      1043
# K-Fold3
# Found 4173 validated image filenames belonging to 2 classes.
# Found 1043 validated image filenames belonging to 2 classes.
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.RMSprop.
# Epoch 1/30
# 260/260 [==============================] - ETA: 0s - loss: 0.7760 - accuracy: 0.6731
# Epoch 1: val_accuracy improved from -inf to 0.91058, saving model to /content/drive/MyDrive/Capstone_data/crefv2b1mnt_rms3.h5
# 260/260 [==============================] - 147s 436ms/step - loss: 0.7760 - accuracy: 0.6731 - val_loss: 0.3369 - val_accuracy: 0.9106 - lr: 1.0000e-04
# Epoch 2/30
# 260/260 [==============================] - ETA: 0s - loss: 0.5974 - accuracy: 0.7922
# Epoch 2: val_accuracy improved from 0.91058 to 0.91731, saving model to /content/drive/MyDrive/Capstone_data/crefv2b1mnt_rms3.h5
# 260/260 [==============================] - 112s 429ms/step - loss: 0.5974 - accuracy: 0.7922 - val_loss: 0.2645 - val_accuracy: 0.9173 - lr: 1.0000e-04
# Epoch 3/30
# 260/260 [==============================] - ETA: 0s - loss: 0.5001 - accuracy: 0.8278
# Epoch 3: val_accuracy did not improve from 0.91731
# 260/260 [==============================] - 109s 420ms/step - loss: 0.5001 - accuracy: 0.8278 - val_loss: 0.3949 - val_accuracy: 0.9154 - lr: 7.5000e-05
# Epoch 4/30
# 260/260 [==============================] - ETA: 0s - loss: 0.4588 - accuracy: 0.8465
# Epoch 4: val_accuracy did not improve from 0.91731
# 260/260 [==============================] - 110s 422ms/step - loss: 0.4588 - accuracy: 0.8465 - val_loss: 0.4308 - val_accuracy: 0.8788 - lr: 7.5000e-05
# Epoch 5/30
# 260/260 [==============================] - ETA: 0s - loss: 0.4174 - accuracy: 0.8583
# Epoch 5: val_accuracy did not improve from 0.91731
# 260/260 [==============================] - 109s 420ms/step - loss: 0.4174 - accuracy: 0.8583 - val_loss: 0.4198 - val_accuracy: 0.9115 - lr: 5.6250e-05
# Epoch 6/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3738 - accuracy: 0.8785
# Epoch 6: val_accuracy improved from 0.91731 to 0.93365, saving model to /content/drive/MyDrive/Capstone_data/crefv2b1mnt_rms3.h5
# 260/260 [==============================] - 112s 429ms/step - loss: 0.3738 - accuracy: 0.8785 - val_loss: 0.2613 - val_accuracy: 0.9337 - lr: 5.6250e-05
# Epoch 7/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3827 - accuracy: 0.8759
# Epoch 7: val_accuracy improved from 0.93365 to 0.93462, saving model to /content/drive/MyDrive/Capstone_data/crefv2b1mnt_rms3.h5
# 260/260 [==============================] - 111s 428ms/step - loss: 0.3827 - accuracy: 0.8759 - val_loss: 0.2539 - val_accuracy: 0.9346 - lr: 4.2188e-05
# Epoch 8/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3688 - accuracy: 0.8756
# Epoch 8: val_accuracy did not improve from 0.93462
# 260/260 [==============================] - 109s 420ms/step - loss: 0.3688 - accuracy: 0.8756 - val_loss: 0.2958 - val_accuracy: 0.9327 - lr: 4.2188e-05
# Epoch 9/30
# 260/260 [==============================] - ETA: 0s - loss: 0.
30
# 260/260 [==============================] - ETA: 0s - loss: 0.2797 - accuracy: 0.9047
# Epoch 25: val_accuracy did not improve from 0.95769
# 260/260 [==============================] - 109s 419ms/step - loss: 0.2797 - accuracy: 0.9047 - val_loss: 0.1671 - val_accuracy: 0.9558 - lr: 3.1676e-06
# Epoch 26/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2628 - accuracy: 0.9151
# Epoch 26: val_accuracy did not improve from 0.95769
# 260/260 [==============================] - 109s 420ms/step - loss: 0.2628 - accuracy: 0.9151 - val_loss: 0.1711 - val_accuracy: 0.9577 - lr: 3.1676e-06
# Epoch 27/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2832 - accuracy: 0.8994
# Epoch 27: val_accuracy did not improve from 0.95769
# 260/260 [==============================] - 109s 420ms/step - loss: 0.2832 - accuracy: 0.8994 - val_loss: 0.1758 - val_accuracy: 0.9567 - lr: 2.3757e-07
# Epoch 28/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2674 - accuracy: 0.9043
# Epoch 28: val_accuracy did not improve from 0.95769
# 260/260 [==============================] - 110s 421ms/step - loss: 0.2674 - accuracy: 0.9043 - val_loss: 0.1756 - val_accuracy: 0.9538 - lr: 2.3757e-06
# Epoch 29/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2411 - accuracy: 0.9163
# Epoch 29: val_accuracy did not improve from 0.95769
# 260/260 [==============================] - 110s 422ms/step - loss: 0.2411 - accuracy: 0.9163 - val_loss: 0.2048 - val_accuracy: 0.9529 - lr: 1.7818e-06
# Epoch 29: early stopping
# 66/66 [==============================] - 15s 192ms/step - loss: 0.1563 - accuracy: 0.9578
# <ipython-input-21-036ed5fc9d65>:58: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   Y_pred = modela.predict_generator(valid_data_generator)
# Classification Report
#               precision    recall  f1-score   support
#
#       Normal       0.90      0.94      0.92       268
#    Pneumonia       0.98      0.96      0.97       775
#
#     accuracy                           0.96      1043
#    macro avg       0.94      0.95      0.95      1043
# weighted avg       0.96      0.96      0.96      1043
# K-Fold4
# Found 4173 validated image filenames belonging to 2 classes.
# Found 1043 validated image filenames belonging to 2 classes.
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.RMSprop.
# Epoch 1/30
# 260/260 [==============================] - ETA: 0s - loss: 0.7734 - accuracy: 0.6832
# Epoch 1: val_accuracy improved from -inf to 0.91827, saving model to /content/drive/MyDrive/Capstone_data/crefv2b1mnt_rms4.h5
# 260/260 [==============================] - 149s 444ms/step - loss: 0.7734 - accuracy: 0.6832 - val_loss: 0.3597 - val_accuracy: 0.9183 - lr: 1.0000e-04
# Epoch 2/30
# 260/260 [==============================] - ETA: 0s - loss: 0.6082 - accuracy: 0.7811
# Epoch 2: val_accuracy improved from 0.91827 to 0.93077, saving model to /content/drive/MyDrive/Capstone_data/crefv2b1mnt_rms4.h5
# 260/260 [==============================] - 112s 429ms/step - loss: 0.6082 - accuracy: 0.7811 - val_loss: 0.2149 - val_accuracy: 0.9308 - lr: 1.0000e-04
# Epoch 3/30
# 260/260 [==============================] - ETA: 0s - loss: 0.4943 - accuracy: 0.8347
# Epoch 3: val_accuracy did not improve from 0.93077
# 260/260 [==============================] - 109s 419ms/step - loss: 0.4943 - accuracy: 0.8347 - val_loss: 0.2427 - val_accuracy: 0.9269 - lr: 7.5000e-05
# Epoch 4/30
# 260/260 [==============================] - ETA: 0s - loss: 0.4644 - accuracy: 0.8465
# Epoch 4: val_accuracy improved from 0.93077 to 0.93846, saving model to /content/drive/MyDrive/Capstone_data/crefv2b1mnt_rms4.h5
# 260/260 [==============================] - 111s 428ms/step - loss: 0.4644 - accuracy: 0.8465 - val_loss: 0.2698 - val_accuracy: 0.9385 - lr: 7.5000e-05
# Epoch 5/30
# 260/260 [==============================] - ETA: 0s - loss: 0.4067 - accuracy: 0.8670
# Epoch 5: val_accuracy improved from 0.93846 to 0.94519, saving model to /content/drive/MyDrive/Capstone_data/crefv2b1mnt_rms4.h5
# 260/260 [==============================] - 112s 430ms/step - loss: 0.4067 - accuracy: 0.8670 - val_loss: 0.2275 - val_accuracy: 0.9452 - lr: 5.6250e-05
# Epoch 6/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3971 - accuracy: 0.8675
# Epoch 6: val_accuracy did not improve from 0.94519
# 260/260 [==============================] - 110s 423ms/step - loss: 0.3971 - accuracy: 0.8675 - val_loss: 0.2065 - val_accuracy: 0.9433 - lr: 5.6250e-05
# Epoch 7/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3739 - accuracy: 0.8768
# Epoch 7: val_accuracy did not improve from 0.94519
# 260/260 [==============================] - 110s 421ms/step - loss: 0.3739 - accuracy: 0.8768 - val_loss: 0.2379 - val_accuracy: 0.9365 - lr: 4.2188e-05
# Epoch 8/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3665 - accuracy: 0.8739
# Epoch 8: val_accuracy did not improve from 0.94519
# 260/260 [==============================] - 110s 421ms/step - loss: 0.3665 - accuracy: 0.8739 - val_loss: 0.2138 - val_accuracy: 0.9385 - lr: 4.2188e-05
# Epoch 9/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3405 - accuracy: 0.8889
# Epoch 9: val_accuracy improved from 0.94519 to 0.95000, saving model to /content/drive/MyDrive/Capstone_data/crefv2b1mnt_r
val_accuracy did not improve from 0.95865
# 260/260 [==============================] - 109s 420ms/step - loss: 0.2828 - accuracy: 0.9050 - val_loss: 0.1841 - val_accuracy: 0.9490 - lr: 3.1676e-06
# Epoch 27/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2858 - accuracy: 0.9021
# Epoch 27: val_accuracy did not improve from 0.95865
# 260/260 [==============================] - 110s 422ms/step - loss: 0.2858 - accuracy: 0.9021 - val_loss: 0.2033 - val_accuracy: 0.9490 - lr: 2.3757e-06
# Epoch 27: early stopping
# 66/66 [==============================] - 15s 198ms/step - loss: 0.1434 - accuracy: 0.9588
# <ipython-input-21-036ed5fc9d65>:58: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   Y_pred = modela.predict_generator(valid_data_generator)
# Classification Report
#               precision    recall  f1-score   support
#
#       Normal       0.92      0.93      0.92       268
#    Pneumonia       0.97      0.97      0.97       775
#
#     accuracy                           0.96      1043
#    macro avg       0.94      0.95      0.95      1043
# weighted avg       0.96      0.96      0.96      1043
# K-Fold5
# Found 4173 validated image filenames belonging to 2 classes.
# Found 1043 validated image filenames belonging to 2 classes.
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.RMSprop.
# Epoch 1/30
# 260/260 [==============================] - ETA: 0s - loss: 0.7630 - accuracy: 0.6724
# Epoch 1: val_accuracy improved from -inf to 0.80192, saving model to /content/drive/MyDrive/Capstone_data/crefv2b1mnt_rms5.h5
# 260/260 [==============================] - 148s 438ms/step - loss: 0.7630 - accuracy: 0.6724 - val_loss: 0.4874 - val_accuracy: 0.8019 - lr: 1.0000e-04
# Epoch 2/30
# 260/260 [==============================] - ETA: 0s - loss: 0.6024 - accuracy: 0.7626
# Epoch 2: val_accuracy improved from 0.80192 to 0.85577, saving model to /content/drive/MyDrive/Capstone_data/crefv2b1mnt_rms5.h5
# 260/260 [==============================] - 111s 426ms/step - loss: 0.6024 - accuracy: 0.7626 - val_loss: 0.4078 - val_accuracy: 0.8558 - lr: 1.0000e-04
# Epoch 3/30
# 260/260 [==============================] - ETA: 0s - loss: 0.5064 - accuracy: 0.8143
# Epoch 3: val_accuracy improved from 0.85577 to 0.90192, saving model to /content/drive/MyDrive/Capstone_data/crefv2b1mnt_rms5.h5
# 260/260 [==============================] - 112s 430ms/step - loss: 0.5064 - accuracy: 0.8143 - val_loss: 0.3406 - val_accuracy: 0.9019 - lr: 7.5000e-05
# Epoch 4/30
# 260/260 [==============================] - ETA: 0s - loss: 0.4582 - accuracy: 0.8371
# Epoch 4: val_accuracy improved from 0.90192 to 0.92404, saving model to /content/drive/MyDrive/Capstone_data/crefv2b1mnt_rms5.h5
# 260/260 [==============================] - 111s 427ms/step - loss: 0.4582 - accuracy: 0.8371 - val_loss: 0.2511 - val_accuracy: 0.9240 - lr: 7.5000e-05
# Epoch 5/30
# 260/260 [==============================] - ETA: 0s - loss: 0.4147 - accuracy: 0.8573
# Epoch 5: val_accuracy improved from 0.92404 to 0.94135, saving model to /content/drive/MyDrive/Capstone_data/crefv2b1mnt_rms5.h5
# 260/260 [==============================] - 112s 432ms/step - loss: 0.4147 - accuracy: 0.8573 - val_loss: 0.1987 - val_accuracy: 0.9413 - lr: 5.6250e-05
# Epoch 6/30
# 260/260 [==============================] - ETA: 0s - loss: 0.4014 - accuracy: 0.8593
# Epoch 6: val_accuracy did not improve from 0.94135
# 260/260 [==============================] - 109s 420ms/step - loss: 0.4014 - accuracy: 0.8593 - val_loss: 0.3174 - val_accuracy: 0.9077 - lr: 5.6250e-05
# Epoch 7/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3638 - accuracy: 0.8694
# Epoch 7: val_accuracy did not improve from 0.94135
# 260/260 [==============================] - 109s 419ms/step - loss: 0.3638 - accuracy: 0.8694 - val_loss: 0.2021 - val_accuracy: 0.9413 - lr: 4.2188e-05
# Epoch 8/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3388 - accuracy: 0.8790
# Epoch 8: val_accuracy did not improve from 0.94135
# 260/260 [==============================] - 110s 422ms/step - loss: 0.3388 - accuracy: 0.8790 - val_loss: 0.3540 - val_accuracy: 0.9154 - lr: 4.2188e-05
# Epoch 9/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3347 - accuracy: 0.8841
# Epoch 9: val_accuracy improved from 0.94135 to 0.94615, saving model to /content/drive/MyDrive/Capstone_data/crefv2b1mnt_rms5.h5
# 260/260 [==============================] - 111s 428ms/step - loss: 0.3347 - accuracy: 0.8841 - val_loss: 0.1927 - val_accuracy: 0.9462 - lr: 3.1641e-05
# Epoch 10/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3124 - accuracy: 0.8927
# Epoch 10: val_accuracy did not improve from 0.94615
# 260/260 [==============================] - 109s 421ms/step - loss: 0.3124 - accuracy: 0.8927 - val_loss: 0.3757 - val_accuracy: 0.9029 - lr: 3.1641e-05
# Epoch 11/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3179 - accuracy: 0.8954
# Epoch 11: val_accuracy did not improve from 0.94615
# 260/260 [==============================] - 109s 420ms/step - loss: 0.3179 - accuracy: 0.8954 - val_loss: 0.3059 - val_accuracy: 0.9192 - lr: 2.3730e-05
# Epoch 12/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3071 - accuracy: 0.8973
# Epoch 12: val_accuracy did not improve from 0.94615
# 260/260 [==============================] - 109s 419ms/step - loss: 0.3071 - accuracy: 0.8973 - val_loss: 0.3159 - val_accuracy: 0.9221 - lr: 2.3730e-05
# Epoch 13/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3112 - accuracy: 0.8942
# Epoch 13: val_accuracy did not improve from 0.94615
# 260/260 [==============================] - 109s 418ms/step - loss: 0.3112 - accuracy: 0.8942 - val_loss: 0.2463 - val_accuracy: 0.9356 - lr: 1.7798e-05
# Epoch 14/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2987 - accuracy: 0.8930
# Epoch 14: val_accuracy did not improve from 0.94615
# 260/260 [==============================] - 110s 421ms/step - loss: 0.2987 - accuracy: 0.8930 - val_loss: 0.4306 - val_accuracy: 0.8894 - lr: 1.7798e-05
# Epoch 15/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2870 - accuracy: 0.9019
# Epoch 15: val_accuracy did not improve from 0.94615
# 260/260 [==============================] - 109s 417ms/step - loss: 0.2870 - accuracy: 0.9019 - val_loss: 0.2803 - val_accuracy: 0.9240 - lr: 1.3348e-05
# Epoch 16/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2817 - accuracy: 0.9064
# Epoch 16: val_accuracy did not improve from 0.94615
# 260/260 [==============================] - 109s 419ms/step - loss: 0.2817 - accuracy: 0.9064 - val_loss: 0.2434 - val_accuracy: 0.9346 - lr: 1.3348e-06
# Epoch 17/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2824 - accuracy: 0.9031
# Epoch 17: val_accuracy did not improve from 0.94615
# 260/260 [==============================] - 109s 418ms/step - loss: 0.2824 - accuracy: 0.9031 - val_loss: 0.2429 - val_accuracy: 0.9327 - lr: 1.0011e-05
# Epoch 18/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2826 - accuracy: 0.9052
# Epoch 18: val_accuracy did not improve from 0.94615
# 260/260 [==============================] - 109s 420ms/step - loss: 0.2826 - accuracy: 0.9052 - val_loss: 0.2830 - val_accuracy: 0.9250 - lr: 1.0011e-05
# Epoch 18: early stopping
# 66/66 [==============================] - 15s 206ms/step - loss: 0.1921 - accuracy: 0.9463
# <ipython-input-21-036ed5fc9d65>:58: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   Y_pred = modela.predict_generator(valid_data_generator)
# Classification Report
#               precision    recall  f1-score   support
#
#       Normal       0.85      0.96      0.90       268
#    Pneumonia       0.98      0.94      0.96       775
#
#     accuracy                           0.95      1043
#    macro avg       0.92      0.95      0.93      1043
# weighted avg       0.95      0.95      0.95      1043

# %%
l1=max(VALIDATION_ACCURACY[0])
l2=max(VALIDATION_ACCURACY[1])
l3=max(VALIDATION_ACCURACY[2])
l4=max(VALIDATION_ACCURACY[3])
l5=max(VALIDATION_ACCURACY[4])

avg=(l1+l2+l3+l4+l5)/5
avg
# Out:
# 0.9517307758331299
