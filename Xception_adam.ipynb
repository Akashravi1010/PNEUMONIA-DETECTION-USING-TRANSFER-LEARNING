# %%
import keras
import tensorflow as tf
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten,Conv2D
from keras.models import Model
from keras import backend as K
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np
import cv2
import sklearn
import os
import seaborn as sns
from google.colab.patches import cv2_imshow
import glob
import keras
from keras.models import Sequential
from tensorflow.python.keras.layers import Dense, Flatten, GlobalAveragePooling2D, Activation, Flatten, Dropout
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import callbacks
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam, SGD

# %%
seed = 10

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
 batch_size=16

# %%
train_path="/content/drive/MyDrive/Capstone_data/Clahe_train"
test_path="/content/drive/MyDrive/Capstone_data/Clahe_test"
val_path="/content/drive/MyDrive/Capstone_data/Clahe_val"

# %%
train_normal = glob.glob(train_path+"/normal/*.jpeg")
train_pneumonia = glob.glob(train_path+"/pneumonia/*.jpeg")

test_normal = glob.glob(test_path+"/normal/*.jpeg")
test_pneumonia = glob.glob(test_path+"/pneumonia/*.jpeg")

val_normal = glob.glob(val_path+"/normal/*.jpeg")
val_pneumonia = glob.glob(val_path+"/pneumonia/*.jpeg")

# %%
train_list = [x for x in train_normal]
train_list.extend([x for x in train_pneumonia])

df_train = pd.DataFrame(np.concatenate([['Normal']*len(train_normal) , ['Pneumonia']*len(train_pneumonia)]), columns = ['class'])
df_train['image'] = [x for x in train_list]

test_list = [x for x in test_normal]
test_list.extend([x for x in test_pneumonia])

df_test = pd.DataFrame(np.concatenate([['Normal']*len(test_normal) , ['Pneumonia']*len(test_pneumonia)]), columns = ['class'])
df_test['image'] = [x for x in test_list]

val_list = [x for x in val_normal]
val_list.extend([x for x in val_pneumonia])

df_val = pd.DataFrame(np.concatenate([['Normal']*len(val_normal) , ['Pneumonia']*len(val_pneumonia)]), columns = ['class'])
df_val['image'] = [x for x in val_list]

# %%
df_train.head()
df_test.head()
df_val.head()
# Out:
#     class                                              image
# 0  Normal  /content/drive/MyDrive/Capstone_data/Clahe_val...
# 1  Normal  /content/drive/MyDrive/Capstone_data/Clahe_val...
# 2  Normal  /content/drive/MyDrive/Capstone_data/Clahe_val...
# 3  Normal  /content/drive/MyDrive/Capstone_data/Clahe_val...
# 4  Normal  /content/drive/MyDrive/Capstone_data/Clahe_val...

# %%
df_train=df_train.sample(frac=1)

# %%
df_train.head()
# Out:
#           class                                              image
# 2780  Pneumonia  /content/drive/MyDrive/Capstone_data/Clahe_tra...
# 3262  Pneumonia  /content/drive/MyDrive/Capstone_data/Clahe_tra...
# 2569  Pneumonia  /content/drive/MyDrive/Capstone_data/Clahe_tra...
# 109      Normal  /content/drive/MyDrive/Capstone_data/Clahe_tra...
# 941      Normal  /content/drive/MyDrive/Capstone_data/Clahe_tra...

# %%
from sklearn.model_selection import KFold, StratifiedKFold
Y = df_train[['class']]

kf = KFold(n_splits = 5)
                         
skf = StratifiedKFold(n_splits = 5, random_state = 7, shuffle = True)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator ,load_img,img_to_array

train_datagen = ImageDataGenerator(
        rescale = 1./255,
        shear_range=10,
        zoom_range=0.3,
        horizontal_flip=True,
        vertical_flip=True,
        brightness_range=[0.5,2.0],
        width_shift_range = 0.2,
        rotation_range=20,
        fill_mode = 'nearest',
)
test_datagen = ImageDataGenerator(
        rescale = 1./255)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Input, Flatten, SeparableConv2D
from tensorflow.keras.layers import GlobalMaxPooling2D,GlobalAveragePooling2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from tensorflow.keras.callbacks import ModelCheckpoint, Callback, EarlyStopping
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.applications import ResNet50, InceptionV3, Xception
from tensorflow.keras.layers.experimental.preprocessing import Normalization

# %%
df_train.shape
n=5216

# %%
x=len(train_normal)
y=len(train_pneumonia)
s1=(x+y)//batch_size
a=len(test_normal)
b=len(test_pneumonia)
s2=(a+b)//batch_size

# %%
from keras.callbacks import ReduceLROnPlateau
import numpy as np
from keras.callbacks import LearningRateScheduler
from tensorflow.keras.models import load_model
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix ,classification_report
import numpy as np

# %%
from tensorflow import keras
from keras import optimizers
import matplotlib.pyplot as plt

# %%
def printHistory(history, title, epochs):
    f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
    t = f.suptitle(title, fontsize=12)
    f.subplots_adjust(top=0.85, wspace=0.3)

    epoch_list = list(range(1,epochs+1))
    ax1.plot(epoch_list, history.history['accuracy'], label='Train Accuracy')
    ax1.plot(epoch_list, history.history['val_accuracy'], label='Validation Accuracy')
    ax1.set_xticks(np.arange(0, epochs+1, 5))
    ax1.set_ylabel('Accuracy Value')
    ax1.set_xlabel('Epoch')
    ax1.set_title('Accuracy')
    l1 = ax1.legend(loc="best")

    ax2.plot(epoch_list, history.history['loss'], label='Train Loss')
    ax2.plot(epoch_list, history.history['val_loss'], label='Validation Loss')
    ax2.set_xticks(np.arange(0, epochs+1, 5))
    ax2.set_ylabel('Loss Value')
    ax2.set_xlabel('Epoch')
    ax2.set_title('Loss')
    l2 = ax2.legend(loc="best")

# %%
from sklearn.metrics import roc_curve, roc_auc_score
def plot_roc_curve(predictions, labels,auc):
    fpr, tpr, thresholds = roc_curve(labels, predictions) 
    plt.title('Receiver Operating Characteristic (ROC)  Curve',fontsize=14)
    plt.xlim([0, 1])
    plt.ylim([0, 1])
    plt.plot(fpr, tpr, 'g',label = 'AUC Score = %0.2f' % auc)
    plt.plot([0, 1], [0, 1],'r--')
    plt.ylabel('\nTrue Positive Rate (TPR)', fontsize=12)
    plt.xlabel('\nFalse Positive Rate (FPR)', fontsize=12)
    plt.legend()
    plt.grid()
    plt.show()

# %%
def conf(cm,target_names):
    plt.figure(figsize=(5,3))
    sns.set(font_scale=1.2)
    ax = sns.heatmap(cm, annot=True,xticklabels=['H', 'P'], yticklabels=['H', 'P'], cbar=False, cmap='Blues',linewidths=1, linecolor='black', fmt='.0f')
    plt.yticks(rotation=0)
    plt.xlabel('Predicted labels')
    plt.ylabel('True labels')
    ax.xaxis.set_ticks_position('top') 
    plt.title('Confusion matrix')
    plt.show()

# %%
VALIDATION_ACCURACY = []
VALIDATION_LOSS = []
TRAINING_ACCURACY=[]
TRAINING_LOSS=[]

save_dir = '/content/drive/MyDrive/Capstone_data/Clahe_train'
fold_var=1
fine_tune_at=30
t=df_train[['class']]
for train_index, val_index in skf.split(np.zeros(len(Y)),Y):
	print("K-Fold"+str(fold_var))
	training_data = df_train.iloc[train_index]
	validation_data = df_train.iloc[val_index]
	
	train_data_generator = train_datagen.flow_from_dataframe(dataframe=training_data,x_col="image",y_col="class",target_size=(224,224),
                                               batch_size=16,class_mode='categorical',shuffle=True)
	valid_data_generator  = test_datagen.flow_from_dataframe(dataframe=validation_data,x_col="image",y_col="class",target_size=(224,224),
                                               batch_size=16,class_mode='categorical',shuffle=False)
        
 	# CREATE NEW MODEL
	model = Sequential()
	conv_base =Xception(input_shape=[224,224]+[3], include_top=False, weights='imagenet')
	for layer in conv_base.layers[:fine_tune_at]:
		layer.trainable = False
	x=  conv_base.output
	x = GlobalAveragePooling2D()(x)
	x = BatchNormalization()(x)
	x = Dropout(0.3)(x) 
	x = Dense(512, activation ='relu')(x)
	x = BatchNormalization()(x)
	x = Dropout(0.5)(x)
	x = Dense(2, activation ='sigmoid')(x)
	model = Model(conv_base.input, x)
	reduce_lr = ReduceLROnPlateau(monitor='val_loss',patience=7)
	early_stopping = EarlyStopping(monitor = "val_accuracy",patience = 9,verbose = 1,mode = "max",)
	checkpoint = ModelCheckpoint(monitor = "val_accuracy",filepath = "/content/drive/MyDrive/Capstone_data/crxcepmnt_adam"+str(fold_var)+".h5",verbose = 1,save_best_only = True, )
	opt = keras.optimizers.RMSprop(lr=0.0001)
	model.compile(loss = "binary_crossentropy", optimizer =opt, metrics = "accuracy")
	s1=train_data_generator.n//train_data_generator.batch_size
	s2=valid_data_generator.n//valid_data_generator.batch_size
	lr_sched = LearningRateScheduler(lambda epoch: 1e-4 * (0.75 ** np.floor(epoch / 2)))
	history = model.fit(train_data_generator,
    epochs = 30, 
    batch_size = 16,
    validation_data = valid_data_generator,
    validation_steps = s2,
    steps_per_epoch = s1,
    callbacks = [reduce_lr, early_stopping, checkpoint,lr_sched])
	if early_stopping.stopped_epoch==0:
		x=30
	else:
		x=early_stopping.stopped_epoch+1
	printHistory(history,"Xception_Adam",x)
	modela = load_model("/content/drive/MyDrive/Capstone_data/crxcepmnt_adam"+str(fold_var)+".h5") 
	
	results = modela.evaluate(valid_data_generator)
	results = dict(zip(model.metrics_names,results))
	Y_pred = modela.predict_generator(valid_data_generator)
	y_pred = np.argmax(Y_pred, axis=1)
	target_names = ['Normal','Pneumonia']
	cm = confusion_matrix(valid_data_generator.classes, y_pred)
	plot_confusion_matrix(cm, target_names)
	conf(cm,target_names)
	print('Classification Report')
	print(classification_report(valid_data_generator.classes, y_pred, target_names=target_names))
	auc = roc_auc_score(valid_data_generator.classes, y_pred) 
	plot_roc_curve(valid_data_generator.classes, y_pred,auc)
	TRAINING_ACCURACY.append(history.history['accuracy'])
	TRAINING_LOSS.append(history.history['loss'])
	VALIDATION_ACCURACY.append(history.history['val_accuracy'])
	VALIDATION_LOSS.append(history.history['val_loss'])

	fold_var += 1
# Out:
# K-Fold1
# Found 4172 validated image filenames belonging to 2 classes.
# Found 1044 validated image filenames belonging to 2 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 [==============================] - 3s 0us/step
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/rmsprop.py:135: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(RMSprop, self).__init__(name, **kwargs)
# Epoch 1/30
# 260/260 [==============================] - ETA: 0s - loss: 0.5085 - accuracy: 0.8405
# Epoch 1: val_accuracy improved from -inf to 0.70481, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_adam1.h5
# 260/260 [==============================] - 864s 3s/step - loss: 0.5085 - accuracy: 0.8405 - val_loss: 1.4992 - val_accuracy: 0.7048 - lr: 1.0000e-04
# Epoch 2/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3182 - accuracy: 0.9175
# Epoch 2: val_accuracy improved from 0.70481 to 0.77981, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_adam1.h5
# 260/260 [==============================] - 115s 441ms/step - loss: 0.3182 - accuracy: 0.9175 - val_loss: 2.0249 - val_accuracy: 0.7798 - lr: 1.0000e-04
# Epoch 3/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2581 - accuracy: 0.9360
# Epoch 3: val_accuracy improved from 0.77981 to 0.86827, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_adam1.h5
# 260/260 [==============================] - 115s 443ms/step - loss: 0.2581 - accuracy: 0.9360 - val_loss: 0.6539 - val_accuracy: 0.8683 - lr: 7.5000e-05
# Epoch 4/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2135 - accuracy: 0.9382
# Epoch 4: val_accuracy improved from 0.86827 to 0.90096, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_adam1.h5
# 260/260 [==============================] - 115s 441ms/step - loss: 0.2135 - accuracy: 0.9382 - val_loss: 0.7890 - val_accuracy: 0.9010 - lr: 7.5000e-05
# Epoch 5/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2027 - accuracy: 0.9442
# Epoch 5: val_accuracy improved from 0.90096 to 0.91731, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_adam1.h5
# 260/260 [==============================] - 114s 440ms/step - loss: 0.2027 - accuracy: 0.9442 - val_loss: 0.3228 - val_accuracy: 0.9173 - lr: 5.6250e-05
# Epoch 6/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1585 - accuracy: 0.9538
# Epoch 6: val_accuracy improved from 0.91731 to 0.91827, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_adam1.h5
# 260/260 [==============================] - 116s 446ms/step - loss: 0.1585 - accuracy: 0.9538 - val_loss: 0.4008 - val_accuracy: 0.9183 - lr: 5.6250e-05
# Epoch 7/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1580 - accuracy: 0.9567
# Epoch 7: val_accuracy did not improve from 0.91827
# 260/260 [==============================] - 111s 428ms/step - loss: 0.1580 - accuracy: 0.9567 - val_loss: 0.7223 - val_accuracy: 0.8952 - lr: 4.2188e-05
# Epoch 8/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1499 - accuracy: 0.9613
# Epoch 8: val_accuracy improved from 0.91827 to 0.94615, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_adam1.h5
# 260/260 [==============================] - 115s 443ms/step - loss: 0.1499 - accuracy: 0.9613 - val_loss: 0.2213 - val_accuracy: 0.9462 - lr: 4.2188e-05
# Epoch 9/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1354 - accuracy: 0.9644
# Epoch 9: val_accuracy did not improve from 0.94615
# 260/260 [==============================] - 113s 433ms/step - loss: 0.1354 - accuracy: 0.9644 - val_loss: 0.4755 - val_accuracy: 0.9096 - lr: 3.1641e-05
# Epoch 10/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1207 - accuracy: 0.9666
# Epoch 10: val_accuracy did not improve from 0.94615
# 260/260 [==============================] - 112s 431ms/step - loss: 0.1207 - accuracy: 0.9666 - val_loss: 0.4574 - val_accuracy: 0.9192 - lr: 3.1641e-05
# Epoch 11/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1219 - accuracy: 0.9692
# Epoch 11: val_accuracy did not improve from 0.94615
# 260/260 [==============================] - 112s 430ms/step - loss: 0.1219 - accuracy: 0.9692 - val_loss: 0.5951 - val_accuracy: 0.8990 - lr: 2.3730e-05
# Epoch 12/30
# 260/260 [==============================] - ETA: 0s - loss: 0.0939 - accuracy: 0.9740
# Epoch 12: val_accuracy did not improve from 0.94615
# 260/260 [==============================] - 112s 432ms/step - loss: 0.0939 - accuracy: 0.9740 - val_loss: 0.4887 - val_accuracy: 0.9269 - lr: 2.3730e-05
# Epoch 13/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1054 - accuracy: 0.9728
# Epoch 13: val_accuracy did not improve from 0.94615
# 260/260 [==============================] - 113s 432ms/step - loss: 0.1054 - accuracy: 0.9728 - val_loss: 0.4087 - val_accuracy: 0.9298 - lr: 1.7798e-05
# Epoch 14/30
# 260/260 [==============================] - ETA: 0s - loss: 0.0958 - accuracy: 0.9776
# Epoch 14: val_accuracy did not improve from 0.94615
# 260/260 [==============================] - 112s 429ms/step - loss: 0.0958 - accuracy: 0.9776 - val_loss: 0.5294 - val_accuracy: 0.9125 - lr: 1.7798e-05
# Epoch 15/30
# 260/260 [==============================] - ETA: 0s - loss: 0.0758 - accuracy: 0.9786
# Epoch 15: val_accuracy did not improve from 0.94615
# 260/260 [==============================] - 111s 427ms/step - loss: 0.0758 - accuracy: 0.9786 - val_loss: 0.5421 - val_accuracy: 0.9106 - lr: 1.3348e-06
# Epoch 16/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1095 - accuracy: 0.9735
# Epoch 16: val_accuracy did not improve from 0.94615
# 260/260 [==============================] - 112s 430ms/step - loss: 0.1095 - accuracy: 0.9735 - val_loss: 0.5154 - val_accuracy: 0.9183 - lr: 1.3348e-05
# Epoch 17/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1003 - accuracy: 0.9757
# Epoch 17: val_accuracy did not improve from 0.94615
# 260/260 [==============================] - 111s 426ms/step - loss: 0.1003 - accuracy: 0.9757 - val_loss: 0.4618 - val_accuracy: 0.9240 - lr: 1.0011e-05
# Epoch 17: early stopping
# 66/66 [==============================] - 15s 210ms/step - loss: 0.2250 - accuracy: 0.9444
# <ipython-input-21-9da6ffd124f1>:58: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   Y_pred = modela.predict_generator(valid_data_generator)
# Classification Report
#               precision    recall  f1-score   support
#
#       Normal       0.82      1.00      0.90       269
#    Pneumonia       1.00      0.93      0.96       775
#
#     accuracy                           0.94      1044
#    macro avg       0.91      0.96      0.93      1044
# weighted avg       0.95      0.94      0.95      1044
# K-Fold2
# Found 4173 validated image filenames belonging to 2 classes.
# Found 1043 validated image filenames belonging to 2 classes.
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/rmsprop.py:135: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(RMSprop, self).__init__(name, **kwargs)
# Epoch 1/30
# 260/260 [==============================] - ETA: 0s - loss: 0.4637 - accuracy: 0.8634
# Epoch 1: val_accuracy improved from -inf to 0.57981, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_adam2.h5
# 260/260 [==============================] - 122s 445ms/step - loss: 0.4637 - accuracy: 0.8634 - val_loss: 1.9516 - val_accuracy: 0.5798 - lr: 1.0000e-04
# Epoch 2/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2995 - accuracy: 0.9199
# Epoch 2: val_accuracy improved from 0.57981 to 0.70769, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_adam2.h5
# 260/260 [==============================] - 115s 442ms/step - loss: 0.2995 - accuracy: 0.9199 - val_loss: 2.8335 - val_accuracy: 0.7077 - lr: 1.0000e-04
# Epoch 3/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2302 - accuracy: 0.9391
# Epoch 3: val_accuracy improved from 0.70769 to 0.83750, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_adam2.h5
# 260/260 [==============================] - 115s 442ms/step - loss: 0.2302 - accuracy: 0.9391 - val_loss: 1.5062 - val_accuracy: 0.8375 - lr: 7.5000e-05
# Epoch 4/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2257 - accuracy: 0.9430
# Epoch 4: val_accuracy did not improve from 0.83750
# 260/260 [==============================] - 115s 441ms/step - loss: 0.2257 - accuracy: 0.9430 - val_loss: 1.8812 - val_accuracy: 0.8135 - lr: 7.5000e-05
# Epoch 5/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1823 - accuracy: 0.9466
# Epoch 5: val_accuracy improved from 0.83750 to 0.87788, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_adam2.h5
# 260/260 [==============================] - 116s 445ms/step - loss: 0.1823 - accuracy: 0.9466 - val_loss: 0.7198 - val_accuracy: 0.8779 - lr: 5.6250e-05
# Epoch 6/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1976 - accuracy: 0.9442
# Epoch 6: val_accuracy did not improve from 0.87788
# 260/260 [==============================] - 114s 437ms/step - loss: 0.1976 - accuracy: 0.9442 - val_loss: 0.8138 - val_accuracy: 0.8721 - lr: 5.6250e-05
# Epoch 7/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1604 - accuracy: 0.9569
# Epoch 7: val_accuracy improved from 0.87788 to 0.89615, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_adam2.h5
# 260/260 [==============================] - 114s 438ms/step - loss: 0.1604 - accuracy: 0.9569 - val_loss: 0.6113 - val_accuracy: 0.8962 - lr: 4.2188e-05
# Epoch 8/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1622 - accuracy: 0.9591
# Epoch 8: val_accuracy improved from 0.89615 to 0.92019, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_adam2.h5
# 260/260 [==============================] - 115s 442ms/step - loss: 0.1622 - accuracy: 0.9591 - val_loss: 0.2949 - val_accuracy: 0.9202 - lr: 4.2188e-05
# Epoch 9/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1174 - accuracy: 0.9620
# Epoch 9: val_accuracy did not improve from 0.92019
# 260/260 [==============================] - 114s 437ms/step - loss: 0.1174 - accuracy: 0.9620 - val_loss: 0.5032 - val_accuracy: 0.9202 - lr: 3.1641e-05
# Epoch 10/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1144 - accuracy: 0.9687
# Epoch 10: val_accuracy improved from 0.92019 to 0.93462, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_adam2.h5
# 260/260 [==============================] - 114s 437ms/step - loss: 0.1144 - accuracy: 0.9687 - val_loss: 0.4287 - val_accuracy: 0.9346 - lr: 3.1641e-05
# Epoch 11/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1252 - accuracy: 0.9661
# Epoch 11: val_accuracy did not improve from 0.93462
# 260/260 [==============================] - 112s 432ms/step - loss: 0.1252 - accuracy: 0.9661 - val_loss: 0.4396 - val_accuracy: 0.9125 - lr: 2.3730e-05
# Epoch 12/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1014 - accuracy: 0.9740
# Epoch 12: val_accuracy did not improve from 0.93462
# 260/260 [==============================] - 113s 433ms/step - loss: 0.1014 - accuracy: 0.9740 - val_loss: 0.5653 - val_accuracy: 0.9115 - lr: 2.3730e-05
# Epoch 13/30
# 260/260 [==============================] - ETA: 0s - loss: 0.0862 - accuracy: 0.9774
# Epoch 13: val_accuracy did not improve from 0.93462
# 260/260 [==============================] - 114s 437ms/step - loss: 0.0862 - accuracy: 0.9774 - val_loss: 0.6486 - val_accuracy: 0.9058 - lr: 1.7798e-05
# Epoch 14/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1192 - accuracy: 0.9707
# Epoch 14: val_accuracy did not improve from 0.93462
# 260/260 [==============================] - 113s 436ms/step - loss: 0.1192 - accuracy: 0.9707 - val_loss: 0.5445 - val_accuracy: 0.9048 - lr: 1.7798e-05
# Epoch 15/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1027 - accuracy: 0.9762
# Epoch 15: val_accuracy did not improve from 0.93462
# 260/260 [==============================] - 115s 440ms/step - loss: 0.1027 - accuracy: 0.9762 - val_loss: 0.4381 - val_accuracy: 0.9221 - lr: 1.3348e-06
# Epoch 16/30
# 260/260 [==============================] - ETA: 0s - loss: 0.0955 - accuracy: 0.9745
# Epoch 16: val_accuracy did not improve from 0.93462
# 260/260 [==============================] - 112s 430ms/step - loss: 0.0955 - accuracy: 0.9745 - val_loss: 0.6492 - val_accuracy: 0.9125 - lr: 1.3348e-05
# Epoch 17/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1060 - accuracy: 0.9769
# Epoch 17: val_accuracy did not improve from 0.93462
# 260/260 [==============================] - 113s 433ms/step - loss: 0.1060 - accuracy: 0.9769 - val_loss: 0.5953 - val_accuracy: 0.9087 - lr: 1.0011e-05
# Epoch 18/30
# 260/260 [==============================] - ETA: 0s - loss: 0.0962 - accuracy: 0.9786
# Epoch 18: val_accuracy did not improve from 0.93462
# 260/260 [==============================] - 114s 438ms/step - loss: 0.0962 - accuracy: 0.9786 - val_loss: 0.5727 - val_accuracy: 0.9163 - lr: 1.0011e-05
# Epoch 19/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1036 - accuracy: 0.9738
# Epoch 19: val_accuracy did not improve from 0.93462
# 260/260 [==============================] - 112s 431ms/step - loss: 0.1036 - accuracy: 0.9738 - val_loss: 0.5200 - val_accuracy: 0.9212 - lr: 7.5085e-06
# Epoch 19: early stopping
# 66/66 [==============================] - 16s 219ms/step - loss: 0.4275 - accuracy: 0.9348
# <ipython-input-21-9da6ffd124f1>:58: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   Y_pred = modela.predict_generator(valid_data_generator)
# Classification Report
#               precision    recall  f1-score   support
#
#       Normal       0.80      0.99      0.89       268
#    Pneumonia       0.99      0.92      0.95       775
#
#     accuracy                           0.93      1043
#    macro avg       0.90      0.95      0.92      1043
# weighted avg       0.95      0.93      0.94      1043
# K-Fold3
# Found 4173 validated image filenames belonging to 2 classes.
# Found 1043 validated image filenames belonging to 2 classes.
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/rmsprop.py:135: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(RMSprop, self).__init__(name, **kwargs)
# Epoch 1/30
# 260/260 [==============================] - ETA: 0s - loss: 0.4804 - accuracy: 0.8528
# Epoch 1: val_accuracy improved from -inf to 0.38173, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_adam3.h5
# 260/260 [==============================] - 124s 452ms/step - loss: 0.4804 - accuracy: 0.8528 - val_loss: 2.7248 - val_accuracy: 0.3817 - lr: 1.0000e-04
# Epoch 2/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3113 - accuracy: 0.9160
# Epoch 2: val_accuracy improved from 0.38173 to 0.65096, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_adam3.h5
# 260/260 [==============================] - 114s 436ms/step - loss: 0.3113 - accuracy: 0.9160 - val_loss: 1.8938 - val_accuracy: 0.6510 - lr: 1.0000e-04
# Epoch 3/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2514 - accuracy: 0.9295
# Epoch 3: val_accuracy improved from 0.65096 to 0.88846, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_adam3.h5
# 260/260 [==============================] - 113s 435ms/step - loss: 0.2514 - accuracy: 0.9295 - val_loss: 0.5812 - val_accuracy: 0.8885 - lr: 7.5000e-05
# Epoch 4/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2393 - accuracy: 0.9372
# Epoch 4: val_accuracy did not improve from 0.88846
# 260/260 [==============================] - 112s 430ms/step - loss: 0.2393 - accuracy: 0.9372 - val_loss: 1.1275 - val_accuracy: 0.8144 - lr: 7.5000e-05
# Epoch 5/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2061 - accuracy: 0.9442
# Epoch 5: val_accuracy improved from 0.88846 to 0.89519, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_adam3.h5
# 260/260 [==============================] - 112s 430ms/step - loss: 0.2061 - accuracy: 0.9442 - val_loss: 0.5151 - val_accuracy: 0.8952 - lr: 5.6250e-05
# Epoch 6/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1588 - accuracy: 0.9514
# Epoch 6: val_accuracy did not improve from 0.89519
# 260/260 [==============================] - 113s 432ms/step - loss: 0.1588 - accuracy: 0.9514 - val_loss: 0.8210 - val_accuracy: 0.8875 - lr: 5.6250e-05
# Epoch 7/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1555 - accuracy: 0.9560
# Epoch 7: val_accuracy improved from 0.89519 to 0.96923, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_adam3.h5
# 260/260 [==============================] - 114s 438ms/step - loss: 0.1555 - accuracy: 0.9560 - val_loss: 0.1170 - val_accuracy: 0.9692 - lr: 4.2188e-05
# Epoch 8/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1412 - accuracy: 0.9630
# Epoch 8: val_accuracy did not improve from 0.96923
# 260/260 [==============================] - 111s 427ms/step - loss: 0.1412 - accuracy: 0.9630 - val_loss: 0.4136 - val_accuracy: 0.9279 - lr: 4.2188e-05
# Epoch 9/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1409 - accuracy: 0.9605
# Epoch 9: val_accuracy did not improve from 0.96923
# 260/260 [==============================] - 111s 426ms/step - loss: 0.1409 - accuracy: 0.9605 - val_loss: 0.2270 - val_accuracy: 0.9510 - lr: 3.1641e-05
# Epoch 10/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1149 - accuracy: 0.9699
# Epoch 10: val_accuracy did not improve from 0.96923
# 260/260 [==============================] - 111s 427ms/step - loss: 0.1149 - accuracy: 0.9699 - val_loss: 0.3024 - val_accuracy: 0.9423 - lr: 3.1641e-05
# Epoch 11/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1021 - accuracy: 0.9731
# Epoch 11: val_accuracy did not improve from 0.96923
# 260/260 [==============================] - 111s 426ms/step - loss: 0.1021 - accuracy: 0.9731 - val_loss: 0.1351 - val_accuracy: 0.9587 - lr: 2.3730e-05
# Epoch 12/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1204 - accuracy: 0.9704
# Epoch 12: val_accuracy did not improve from 0.96923
# 260/260 [==============================] - 112s 429ms/step - loss: 0.1204 - accuracy: 0.9704 - val_loss: 0.1815 - val_accuracy: 0.9519 - lr: 2.3730e-05
# Epoch 13/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1270 - accuracy: 0.9711
# Epoch 13: val_accuracy did not improve from 0.96923
# 260/260 [==============================] - 112s 430ms/step - loss: 0.1270 - accuracy: 0.9711 - val_loss: 0.1885 - val_accuracy: 0.9538 - lr: 1.7798e-05
# Epoch 14/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1106 - accuracy: 0.9694
# Epoch 14: val_accuracy did not improve from 0.96923
# 260/260 [==============================] - 111s 427ms/step - loss: 0.1106 - accuracy: 0.9694 - val_loss: 0.1977 - val_accuracy: 0.9500 - lr: 1.7798e-06
# Epoch 15/30
# 260/260 [==============================] - ETA: 0s - loss: 0.0840 - accuracy: 0.9771
# Epoch 15: val_accuracy did not improve from 0.96923
# 260/260 [==============================] - 110s 424ms/step - loss: 0.0840 - accuracy: 0.9771 - val_loss: 0.1931 - val_accuracy: 0.9538 - lr: 1.3348e-05
# Epoch 16/30
# 260/260 [==============================] - ETA: 0s - loss: 0.0902 - accuracy: 0.9796
# Epoch 16: val_accuracy did not improve from 0.96923
# 260/260 [==============================] - 110s 423ms/step - loss: 0.0902 - accuracy: 0.9796 - val_loss: 0.2030 - val_accuracy: 0.9548 - lr: 1.3348e-05
# Epoch 16: early stopping
# 66/66 [==============================] - 14s 198ms/step - loss: 0.1170 - accuracy: 0.9693
# <ipython-input-21-9da6ffd124f1>:58: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   Y_pred = modela.predict_generator(valid_data_generator)
# Classification Report
#               precision    recall  f1-score   support
#
#       Normal       0.90      0.99      0.94       268
#    Pneumonia       1.00      0.96      0.98       775
#
#     accuracy                           0.97      1043
#    macro avg       0.95      0.98      0.96      1043
# weighted avg       0.97      0.97      0.97      1043
# K-Fold4
# Found 4173 validated image filenames belonging to 2 classes.
# Found 1043 validated image filenames belonging to 2 classes.
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/rmsprop.py:135: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(RMSprop, self).__init__(name, **kwargs)
# Epoch 1/30
# 260/260 [==============================] - ETA: 0s - loss: 0.5015 - accuracy: 0.8573
# Epoch 1: val_accuracy improved from -inf to 0.55385, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_adam4.h5
# 260/260 [==============================] - 125s 456ms/step - loss: 0.5015 - accuracy: 0.8573 - val_loss: 2.9216 - val_accuracy: 0.5538 - lr: 1.0000e-04
# Epoch 2/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3050 - accuracy: 0.9194
# Epoch 2: val_accuracy improved from 0.55385 to 0.64808, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_adam4.h5
# 260/260 [==============================] - 114s 439ms/step - loss: 0.3050 - accuracy: 0.9194 - val_loss: 2.6228 - val_accuracy: 0.6481 - lr: 1.0000e-04
# Epoch 3/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2508 - accuracy: 0.9355
# Epoch 3: val_accuracy improved from 0.64808 to 0.88750, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_adam4.h5
# 260/260 [==============================] - 115s 440ms/step - loss: 0.2508 - accuracy: 0.9355 - val_loss: 0.9340 - val_accuracy: 0.8875 - lr: 7.5000e-05
# Epoch 4/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2304 - accuracy: 0.9389
# Epoch 4: val_accuracy did not improve from 0.88750
# 260/260 [==============================] - 111s 424ms/step - loss: 0.2304 - accuracy: 0.9389 - val_loss: 1.1467 - val_accuracy: 0.8779 - lr: 7.5000e-05
# Epoch 5/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2019 - accuracy: 0.9423
# Epoch 5: val_accuracy improved from 0.88750 to 0.90962, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_adam4.h5
# 260/260 [==============================] - 112s 429ms/step - loss: 0.2019 - accuracy: 0.9423 - val_loss: 0.4838 - val_accuracy: 0.9096 - lr: 5.6250e-05
# Epoch 6/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1753 - accuracy: 0.9533
# Epoch 6: val_accuracy improved from 0.90962 to 0.91442, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_adam4.h5
# 260/260 [==============================] - 112s 430ms/step - loss: 0.1753 - accuracy: 0.9533 - val_loss: 0.3957 - val_accuracy: 0.9144 - lr: 5.6250e-05
# Epoch 7/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1694 - accuracy: 0.9521
# Epoch 7: val_accuracy improved from 0.91442 to 0.92692, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_adam4.h5
# 260/260 [==============================] - 112s 431ms/step - loss: 0.1694 - accuracy: 0.9521 - val_loss: 0.2820 - val_accuracy: 0.9269 - lr: 4.2188e-05
# Epoch 8/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1418 - accuracy: 0.9615
# Epoch 8: val_accuracy did not improve from 0.92692
# 260/260 [==============================] - 110s 423ms/step - loss: 0.1418 - accuracy: 0.9615 - val_loss: 0.4013 - val_accuracy: 0.9067 - lr: 4.2188e-05
# Epoch 9/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1229 - accuracy: 0.9639
# Epoch 9: val_accuracy improved from 0.92692 to 0.93654, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_adam4.h5
# 260/260 [==============================] - 112s 432ms/step - loss: 0.1229 - accuracy: 0.9639 - val_loss: 0.2070 - val_accuracy: 0.9365 - lr: 3.1641e-05
# Epoch 10/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1285 - accuracy: 0.9680
# Epoch 10: val_accuracy did not improve from 0.93654
# 260/260 [==============================] - 111s 423ms/step - loss: 0.1285 - accuracy: 0.9680 - val_loss: 0.4011 - val_accuracy: 0.9125 - lr: 3.1641e-05
# Epoch 11/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1009 - accuracy: 0.9678
# Epoch 11: val_accuracy did not improve from 0.93654
# 260/260 [==============================] - 110s 422ms/step - loss: 0.1009 - accuracy: 0.9678 - val_loss: 0.2786 - val_accuracy: 0.9221 - lr: 2.3730e-05
# Epoch 12/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1018 - accuracy: 0.9743
# Epoch 12: val_accuracy did not improve from 0.93654
# 260/260 [==============================] - 110s 422ms/step - loss: 0.1018 - accuracy: 0.9743 - val_loss: 0.2475 - val_accuracy: 0.9240 - lr: 2.3730e-05
# Epoch 13/30
# 260/260 [==============================] - ETA: 0s - loss: 0.0937 - accuracy: 0.9745
# Epoch 13: val_accuracy did not improve from 0.93654
# 260/260 [==============================] - 110s 423ms/step - loss: 0.0937 - accuracy: 0.9745 - val_loss: 0.3861 - val_accuracy: 0.9135 - lr: 1.7798e-05
# Epoch 14/30
# 260/260 [==============================] - ETA: 0s - loss: 0.0915 - accuracy: 0.9750
# Epoch 14: val_accuracy did not improve from 0.93654
# 260/260 [==============================] - 110s 424ms/step - loss: 0.0915 - accuracy: 0.9750 - val_loss: 0.3252 - val_accuracy: 0.9327 - lr: 1.7798e-05
# Epoch 15/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1079 - accuracy: 0.9728
# Epoch 15: val_accuracy did not improve from 0.93654
# 260/260 [==============================] - 110s 425ms/step - loss: 0.1079 - accuracy: 0.9728 - val_loss: 0.3889 - val_accuracy: 0.9202 - lr: 1.3348e-05
# Epoch 16/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1117 - accuracy: 0.9767
# Epoch 16: val_accuracy did not improve from 0.93654
# 260/260 [==============================] - 110s 423ms/step - loss: 0.1117 - accuracy: 0.9767 - val_loss: 0.3563 - val_accuracy: 0.9240 - lr: 1.3348e-06
# Epoch 17/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1194 - accuracy: 0.9750
# Epoch 17: val_accuracy did not improve from 0.93654
# 260/260 [==============================] - 110s 424ms/step - loss: 0.1194 - accuracy: 0.9750 - val_loss: 0.3501 - val_accuracy: 0.9260 - lr: 1.0011e-05
# Epoch 18/30
# 260/260 [==============================] - ETA: 0s - loss: 0.0912 - accuracy: 0.9774
# Epoch 18: val_accuracy improved from 0.93654 to 0.94231, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_adam4.h5
# 260/260 [==============================] - 113s 434ms/step - loss: 0.0912 - accuracy: 0.9774 - val_loss: 0.2433 - val_accuracy: 0.9423 - lr: 1.0011e-05
# Epoch 19/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1300 - accuracy: 0.9757
# Epoch 19: val_accuracy did not improve from 0.94231
# 260/260 [==============================] - 111s 425ms/step - loss: 0.1300 - accuracy: 0.9757 - val_loss: 0.2649 - val_accuracy: 0.9413 - lr: 7.5085e-06
# Epoch 20/30
# 260/260 [==============================] - ETA: 0s - loss: 0.0682 - accuracy: 0.9820
# Epoch 20: val_accuracy did not improve from 0.94231
# 260/260 [==============================] - 110s 424ms/step - loss: 0.0682 - accuracy: 0.9820 - val_loss: 0.2834 - val_accuracy: 0.9327 - lr: 7.5085e-06
# Epoch 21/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1016 - accuracy: 0.9791
# Epoch 21: val_accuracy did not improve from 0.94231
# 260/260 [==============================] - 110s 422ms/step - loss: 0.1016 - accuracy: 0.9791 - val_loss: 0.2787 - val_accuracy: 0.9365 - lr: 5.6314e-06
# Epoch 22/30
# 260/260 [==============================] - ETA: 0s - loss: 0.0976 - accuracy: 0.9767
# Epoch 22: val_accuracy did not improve from 0.94231
# 260/260 [==============================] - 110s 424ms/step - loss: 0.0976 - accuracy: 0.9767 - val_loss: 0.2525 - val_accuracy: 0.9375 - lr: 5.6314e-06
# Epoch 23/30
# 260/260 [==============================] - ETA: 0s - loss: 0.0894 - accuracy: 0.9779
# Epoch 23: val_accuracy did not improve from 0.94231
# 260/260 [==============================] - 111s 425ms/step - loss: 0.0894 - accuracy: 0.9779 - val_loss: 0.2565 - val_accuracy: 0.9375 - lr: 4.2235e-07
# Epoch 24/30
# 260/260 [==============================] - ETA: 0s - loss: 0.0918 - accuracy: 0.9791
# Epoch 24: val_accuracy did not improve from 0.94231
# 260/260 [==============================] - 110s 422ms/step - loss: 0.0918 - accuracy: 0.9791 - val_loss: 0.2869 - val_accuracy: 0.9365 - lr: 4.2235e-06
# Epoch 25/30
# 260/260 [==============================] - ETA: 0s - loss: 0.0820 - accuracy: 0.9832
# Epoch 25: val_accuracy did not improve from 0.94231
# 260/260 [==============================] - 111s 428ms/step - loss: 0.0820 - accuracy: 0.9832 - val_loss: 0.3132 - val_accuracy: 0.9317 - lr: 3.1676e-06
# Epoch 26/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1067 - accuracy: 0.9791
# Epoch 26: val_accuracy did not improve from 0.94231
# 260/260 [==============================] - 110s 424ms/step - loss: 0.1067 - accuracy: 0.9791 - val_loss: 0.2943 - val_accuracy: 0.9375 - lr: 3.1676e-06
# Epoch 27/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1002 - accuracy: 0.9793
# Epoch 27: val_accuracy did not improve from 0.94231
# 260/260 [==============================] - 111s 425ms/step - loss: 0.1002 - accuracy: 0.9793 - val_loss: 0.2892 - val_accuracy: 0.9346 - lr: 2.3757e-06
# Epoch 27: early stopping
# 66/66 [==============================] - 14s 195ms/step - loss: 0.2427 - accuracy: 0.9425
# <ipython-input-21-9da6ffd124f1>:58: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   Y_pred = modela.predict_generator(valid_data_generator)
# Classification Report
#               precision    recall  f1-score   support
#
#       Normal       0.83      0.98      0.90       268
#    Pneumonia       0.99      0.93      0.96       775
#
#     accuracy                           0.94      1043
#    macro avg       0.91      0.96      0.93      1043
# weighted avg       0.95      0.94      0.94      1043
# K-Fold5
# Found 4173 validated image filenames belonging to 2 classes.
# Found 1043 validated image filenames belonging to 2 classes.
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/rmsprop.py:135: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(RMSprop, self).__init__(name, **kwargs)
# Epoch 1/30
# 260/260 [==============================] - ETA: 0s - loss: 0.5023 - accuracy: 0.8398
# Epoch 1: val_accuracy improved from -inf to 0.62692, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_adam5.h5
# 260/260 [==============================] - 123s 447ms/step - loss: 0.5023 - accuracy: 0.8398 - val_loss: 1.3454 - val_accuracy: 0.6269 - lr: 1.0000e-04
# Epoch 2/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3165 - accuracy: 0.9170
# Epoch 2: val_accuracy improved from 0.62692 to 0.92212, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_adam5.h5
# 260/260 [==============================] - 112s 430ms/step - loss: 0.3165 - accuracy: 0.9170 - val_loss: 0.4810 - val_accuracy: 0.9221 - lr: 1.0000e-04
# Epoch 3/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2474 - accuracy: 0.9305
# Epoch 3: val_accuracy did not improve from 0.92212
# 260/260 [==============================] - 112s 428ms/step - loss: 0.2474 - accuracy: 0.9305 - val_loss: 0.5917 - val_accuracy: 0.8990 - lr: 7.5000e-05
# Epoch 4/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2064 - accuracy: 0.9423
# Epoch 4: val_accuracy improved from 0.92212 to 0.92308, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_adam5.h5
# 260/260 [==============================] - 112s 431ms/step - loss: 0.2064 - accuracy: 0.9423 - val_loss: 0.3388 - val_accuracy: 0.9231 - lr: 7.5000e-05
# Epoch 5/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1712 - accuracy: 0.9533
# Epoch 5: val_accuracy improved from 0.92308 to 0.94038, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_adam5.h5
# 260/260 [==============================] - 114s 438ms/step - loss: 0.1712 - accuracy: 0.9533 - val_loss: 0.3184 - val_accuracy: 0.9404 - lr: 5.6250e-05
# Epoch 6/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1718 - accuracy: 0.9531
# Epoch 6: val_accuracy did not improve from 0.94038
# 260/260 [==============================] - 110s 424ms/step - loss: 0.1718 - accuracy: 0.9531 - val_loss: 0.4559 - val_accuracy: 0.9144 - lr: 5.6250e-05
# Epoch 7/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1603 - accuracy: 0.9538
# Epoch 7: val_accuracy did not improve from 0.94038
# 260/260 [==============================] - 110s 424ms/step - loss: 0.1603 - accuracy: 0.9538 - val_loss: 0.3702 - val_accuracy: 0.9317 - lr: 4.2188e-05
# Epoch 8/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1603 - accuracy: 0.9567
# Epoch 8: val_accuracy improved from 0.94038 to 0.95673, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_adam5.h5
# 260/260 [==============================] - 113s 432ms/step - loss: 0.1603 - accuracy: 0.9567 - val_loss: 0.2134 - val_accuracy: 0.9567 - lr: 4.2188e-05
# Epoch 9/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1471 - accuracy: 0.9613
# Epoch 9: val_accuracy improved from 0.95673 to 0.95865, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_adam5.h5
# 260/260 [==============================] - 112s 431ms/step - loss: 0.1471 - accuracy: 0.9613 - val_loss: 0.1414 - val_accuracy: 0.9587 - lr: 3.1641e-05
# Epoch 10/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1103 - accuracy: 0.9668
# Epoch 10: val_accuracy did not improve from 0.95865
# 260/260 [==============================] - 111s 425ms/step - loss: 0.1103 - accuracy: 0.9668 - val_loss: 0.4424 - val_accuracy: 0.9163 - lr: 3.1641e-05
# Epoch 11/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1310 - accuracy: 0.9649
# Epoch 11: val_accuracy did not improve from 0.95865
# 260/260 [==============================] - 110s 424ms/step - loss: 0.1310 - accuracy: 0.9649 - val_loss: 0.2083 - val_accuracy: 0.9548 - lr: 2.3730e-05
# Epoch 12/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1225 - accuracy: 0.9687
# Epoch 12: val_accuracy did not improve from 0.95865
# 260/260 [==============================] - 111s 425ms/step - loss: 0.1225 - accuracy: 0.9687 - val_loss: 0.2920 - val_accuracy: 0.9356 - lr: 2.3730e-05
# Epoch 13/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1079 - accuracy: 0.9682
# Epoch 13: val_accuracy did not improve from 0.95865
# 260/260 [==============================] - 114s 436ms/step - loss: 0.1079 - accuracy: 0.9682 - val_loss: 0.1852 - val_accuracy: 0.9538 - lr: 1.7798e-05
# Epoch 14/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1110 - accuracy: 0.9709
# Epoch 14: val_accuracy did not improve from 0.95865
# 260/260 [==============================] - 111s 425ms/step - loss: 0.1110 - accuracy: 0.9709 - val_loss: 0.1688 - val_accuracy: 0.9538 - lr: 1.7798e-05
# Epoch 15/30
# 260/260 [==============================] - ETA: 0s - loss: 0.0951 - accuracy: 0.9723
# Epoch 15: val_accuracy did not improve from 0.95865
# 260/260 [==============================] - 111s 426ms/step - loss: 0.0951 - accuracy: 0.9723 - val_loss: 0.1955 - val_accuracy: 0.9538 - lr: 1.3348e-05
# Epoch 16/30
# 260/260 [==============================] - ETA: 0s - loss: 0.0932 - accuracy: 0.9762
# Epoch 16: val_accuracy did not improve from 0.95865
# 260/260 [==============================] - 111s 427ms/step - loss: 0.0932 - accuracy: 0.9762 - val_loss: 0.1878 - val_accuracy: 0.9538 - lr: 1.3348e-06
# Epoch 17/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1001 - accuracy: 0.9762
# Epoch 17: val_accuracy improved from 0.95865 to 0.96154, saving model to /content/drive/MyDrive/Capstone_data/crxcepmnt_adam5.h5
# 260/260 [==============================] - 112s 431ms/step - loss: 0.1001 - accuracy: 0.9762 - val_loss: 0.1475 - val_accuracy: 0.9615 - lr: 1.0011e-05
# Epoch 18/30
# 260/260 [==============================] - ETA: 0s - loss: 0.0930 - accuracy: 0.9759
# Epoch 18: val_accuracy did not improve from 0.96154
# 260/260 [==============================] - 111s 427ms/step - loss: 0.0930 - accuracy: 0.9759 - val_loss: 0.1885 - val_accuracy: 0.9538 - lr: 1.0011e-05
# Epoch 19/30
# 260/260 [==============================] - ETA: 0s - loss: 0.0974 - accuracy: 0.9752
# Epoch 19: val_accuracy did not improve from 0.96154
# 260/260 [==============================] - 111s 424ms/step - loss: 0.0974 - accuracy: 0.9752 - val_loss: 0.1917 - val_accuracy: 0.9490 - lr: 7.5085e-06
# Epoch 20/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1087 - accuracy: 0.9723
# Epoch 20: val_accuracy did not improve from 0.96154
# 260/260 [==============================] - 112s 429ms/step - loss: 0.1087 - accuracy: 0.9723 - val_loss: 0.1621 - val_accuracy: 0.9529 - lr: 7.5085e-06
# Epoch 21/30
# 260/260 [==============================] - ETA: 0s - loss: 0.0885 - accuracy: 0.9752
# Epoch 21: val_accuracy did not improve from 0.96154
# 260/260 [==============================] - 111s 426ms/step - loss: 0.0885 - accuracy: 0.9752 - val_loss: 0.1846 - val_accuracy: 0.9510 - lr: 5.6314e-06
# Epoch 22/30
# 260/260 [==============================] - ETA: 0s - loss: 0.0734 - accuracy: 0.9793
# Epoch 22: val_accuracy did not improve from 0.96154
# 260/260 [==============================] - 113s 436ms/step - loss: 0.0734 - accuracy: 0.9793 - val_loss: 0.1851 - val_accuracy: 0.9538 - lr: 5.6314e-06
# Epoch 23/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1005 - accuracy: 0.9745
# Epoch 23: val_accuracy did not improve from 0.96154
# 260/260 [==============================] - 110s 422ms/step - loss: 0.1005 - accuracy: 0.9745 - val_loss: 0.1827 - val_accuracy: 0.9548 - lr: 4.2235e-07
# Epoch 24/30
# 260/260 [==============================] - ETA: 0s - loss: 0.0908 - accuracy: 0.9774
# Epoch 24: val_accuracy did not improve from 0.96154
# 260/260 [==============================] - 110s 424ms/step - loss: 0.0908 - accuracy: 0.9774 - val_loss: 0.2154 - val_accuracy: 0.9433 - lr: 4.2235e-06
# Epoch 25/30
# 260/260 [==============================] - ETA: 0s - loss: 0.0890 - accuracy: 0.9779
# Epoch 25: val_accuracy did not improve from 0.96154
# 260/260 [==============================] - 111s 426ms/step - loss: 0.0890 - accuracy: 0.9779 - val_loss: 0.2171 - val_accuracy: 0.9433 - lr: 3.1676e-06
# Epoch 26/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1135 - accuracy: 0.9723
# Epoch 26: val_accuracy did not improve from 0.96154
# 260/260 [==============================] - 110s 424ms/step - loss: 0.1135 - accuracy: 0.9723 - val_loss: 0.2063 - val_accuracy: 0.9500 - lr: 3.1676e-06
# Epoch 26: early stopping
# 66/66 [==============================] - 14s 195ms/step - loss: 0.1471 - accuracy: 0.9616
# <ipython-input-21-9da6ffd124f1>:58: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   Y_pred = modela.predict_generator(valid_data_generator)
# Classification Report
#               precision    recall  f1-score   support
#
#       Normal       0.88      0.99      0.93       268
#    Pneumonia       1.00      0.95      0.97       775
#
#     accuracy                           0.96      1043
#    macro avg       0.94      0.97      0.95      1043
# weighted avg       0.97      0.96      0.96      1043

# %%
l1=max(VALIDATION_ACCURACY[0])
l2=max(VALIDATION_ACCURACY[1])
l3=max(VALIDATION_ACCURACY[2])
l4=max(VALIDATION_ACCURACY[3])
l5=max(VALIDATION_ACCURACY[4])

avg=(l1+l2+l3+l4+l5)/5
avg
# Out:
# 0.9507692217826843
