# %%
import keras
import tensorflow as tf
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten,Conv2D
from keras.models import Model
from keras import backend as K
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np
import cv2
import sklearn
import os
import seaborn as sns
from google.colab.patches import cv2_imshow
import glob
import keras
from keras.models import Sequential
from tensorflow.python.keras.layers import Dense, Flatten, GlobalAveragePooling2D, Activation, Flatten, Dropout
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import callbacks
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam, SGD

# %%
seed = 10

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
 batch_size=16

# %%
train_path="/content/drive/MyDrive/Capstone_data/Clahe_train"
test_path="/content/drive/MyDrive/Capstone_data/Clahe_test"
val_path="/content/drive/MyDrive/Capstone_data/Clahe_val"

# %%
train_normal = glob.glob(train_path+"/normal/*.jpeg")
train_pneumonia = glob.glob(train_path+"/pneumonia/*.jpeg")

test_normal = glob.glob(test_path+"/normal/*.jpeg")
test_pneumonia = glob.glob(test_path+"/pneumonia/*.jpeg")

val_normal = glob.glob(val_path+"/normal/*.jpeg")
val_pneumonia = glob.glob(val_path+"/pneumonia/*.jpeg")

# %%
train_list = [x for x in train_normal]
train_list.extend([x for x in train_pneumonia])

df_train = pd.DataFrame(np.concatenate([['Normal']*len(train_normal) , ['Pneumonia']*len(train_pneumonia)]), columns = ['class'])
df_train['image'] = [x for x in train_list]

test_list = [x for x in test_normal]
test_list.extend([x for x in test_pneumonia])

df_test = pd.DataFrame(np.concatenate([['Normal']*len(test_normal) , ['Pneumonia']*len(test_pneumonia)]), columns = ['class'])
df_test['image'] = [x for x in test_list]

val_list = [x for x in val_normal]
val_list.extend([x for x in val_pneumonia])

df_val = pd.DataFrame(np.concatenate([['Normal']*len(val_normal) , ['Pneumonia']*len(val_pneumonia)]), columns = ['class'])
df_val['image'] = [x for x in val_list]

# %%
df_train.head()
df_test.head()
df_val.head()
# Out:
#     class                                              image
# 0  Normal  /content/drive/MyDrive/Capstone_data/Clahe_val...
# 1  Normal  /content/drive/MyDrive/Capstone_data/Clahe_val...
# 2  Normal  /content/drive/MyDrive/Capstone_data/Clahe_val...
# 3  Normal  /content/drive/MyDrive/Capstone_data/Clahe_val...
# 4  Normal  /content/drive/MyDrive/Capstone_data/Clahe_val...

# %%
df_train=df_train.sample(frac=1)

# %%
df_train.head()
# Out:
#           class                                              image
# 2197  Pneumonia  /content/drive/MyDrive/Capstone_data/Clahe_tra...
# 2258  Pneumonia  /content/drive/MyDrive/Capstone_data/Clahe_tra...
# 2689  Pneumonia  /content/drive/MyDrive/Capstone_data/Clahe_tra...
# 1417  Pneumonia  /content/drive/MyDrive/Capstone_data/Clahe_tra...
# 2913  Pneumonia  /content/drive/MyDrive/Capstone_data/Clahe_tra...

# %%
from sklearn.model_selection import KFold, StratifiedKFold
Y = df_train[['class']]

kf = KFold(n_splits = 5)
                         
skf = StratifiedKFold(n_splits = 5, random_state = 7, shuffle = True)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator ,load_img,img_to_array

train_datagen = ImageDataGenerator(
        rescale = 1./255,
        shear_range=10,
        zoom_range=0.3,
        horizontal_flip=True,
        vertical_flip=True,
        brightness_range=[0.5,2.0],
        width_shift_range = 0.2,
        rotation_range=20,
        fill_mode = 'nearest',
)
test_datagen = ImageDataGenerator(
        rescale = 1./255)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Input, Flatten, SeparableConv2D
from tensorflow.keras.layers import GlobalMaxPooling2D,GlobalAveragePooling2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from tensorflow.keras.callbacks import ModelCheckpoint, Callback, EarlyStopping
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.applications import ResNet50, InceptionV3, EfficientNetV2L
from tensorflow.keras.layers.experimental.preprocessing import Normalization

# %%
df_train.shape
n=5216

# %%
x=len(train_normal)
y=len(train_pneumonia)
s1=(x+y)//batch_size
a=len(test_normal)
b=len(test_pneumonia)
s2=(a+b)//batch_size

# %%
from keras.callbacks import ReduceLROnPlateau
import numpy as np
from keras.callbacks import LearningRateScheduler
from tensorflow.keras.models import load_model
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix ,classification_report
import numpy as np

# %%
from tensorflow import keras
from keras import optimizers
import matplotlib.pyplot as plt

# %%
def printHistory(history, title, epochs):
    f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
    t = f.suptitle(title, fontsize=12)
    f.subplots_adjust(top=0.85, wspace=0.3)

    epoch_list = list(range(1,epochs+1))
    ax1.plot(epoch_list, history.history['accuracy'], label='Train Accuracy')
    ax1.plot(epoch_list, history.history['val_accuracy'], label='Validation Accuracy')
    ax1.set_xticks(np.arange(0, epochs+1, 5))
    ax1.set_ylabel('Accuracy Value')
    ax1.set_xlabel('Epoch')
    ax1.set_title('Accuracy')
    l1 = ax1.legend(loc="best")

    ax2.plot(epoch_list, history.history['loss'], label='Train Loss')
    ax2.plot(epoch_list, history.history['val_loss'], label='Validation Loss')
    ax2.set_xticks(np.arange(0, epochs+1, 5))
    ax2.set_ylabel('Loss Value')
    ax2.set_xlabel('Epoch')
    ax2.set_title('Loss')
    l2 = ax2.legend(loc="best")

# %%
from sklearn.metrics import roc_curve, roc_auc_score
def plot_roc_curve(predictions, labels,auc):
    fpr, tpr, thresholds = roc_curve(labels, predictions) 
    plt.title('Receiver Operating Characteristic (ROC)  Curve',fontsize=14)
    plt.xlim([0, 1])
    plt.ylim([0, 1])
    plt.plot(fpr, tpr, 'g',label = 'AUC Score = %0.2f' % auc)
    plt.plot([0, 1], [0, 1],'r--')
    plt.ylabel('\nTrue Positive Rate (TPR)', fontsize=12)
    plt.xlabel('\nFalse Positive Rate (FPR)', fontsize=12)
    plt.legend()
    plt.grid()
    plt.show()

# %%
def conf(cm,target_names):
    plt.figure(figsize=(5,3))
    sns.set(font_scale=1.2)
    ax = sns.heatmap(cm, annot=True,xticklabels=['H', 'P'], yticklabels=['H', 'P'], cbar=False, cmap='Blues',linewidths=1, linecolor='black', fmt='.0f')
    plt.yticks(rotation=0)
    plt.xlabel('Predicted labels')
    plt.ylabel('True labels')
    ax.xaxis.set_ticks_position('top') 
    plt.title('Confusion matrix')
    plt.show()

# %%
VALIDATION_ACCURACY = []
VALIDATION_LOSS = []
TRAINING_ACCURACY=[]
TRAINING_LOSS=[]

save_dir = '/content/drive/MyDrive/Capstone_data/Clahe_train'
fold_var=1
fine_tune_at=30
t=df_train[['class']]
for train_index, val_index in skf.split(np.zeros(len(Y)),Y):
	print("K-Fold"+str(fold_var))
	training_data = df_train.iloc[train_index]
	validation_data = df_train.iloc[val_index]
	
	train_data_generator = train_datagen.flow_from_dataframe(dataframe=training_data,x_col="image",y_col="class",target_size=(224,224),
                                               batch_size=16,class_mode='categorical',shuffle=True)
	valid_data_generator  = test_datagen.flow_from_dataframe(dataframe=validation_data,x_col="image",y_col="class",target_size=(224,224),
                                               batch_size=16,class_mode='categorical',shuffle=False)
        
 	# CREATE NEW MODEL
	model = Sequential()
	conv_base = EfficientNetV2L(input_shape=[224,224]+[3], include_top=False, weights='imagenet')
	for layer in conv_base.layers[:fine_tune_at]:
		layer.trainable = False
	x=  conv_base.output
	x = GlobalAveragePooling2D()(x)
	x = BatchNormalization()(x)
	x = Dropout(0.3)(x) 
	x = Dense(512, activation ='relu')(x)
	x = BatchNormalization()(x)
	x = Dropout(0.5)(x)
	x = Dense(2, activation ='sigmoid')(x)
	model = Model(conv_base.input, x)
	reduce_lr = ReduceLROnPlateau(monitor='val_loss',patience=7)
	early_stopping = EarlyStopping(monitor = "val_accuracy",patience = 9,verbose = 1,mode = "max",)
	checkpoint = ModelCheckpoint(monitor = "val_accuracy",filepath = "/content/drive/MyDrive/Capstone_data/crefv2lmnt_rms"+str(fold_var)+".h5",verbose = 1,save_best_only = True, )
	opt = keras.optimizers.RMSprop(lr=0.0001)
	model.compile(loss = "binary_crossentropy", optimizer =opt, metrics = "accuracy")
	s1=train_data_generator.n//train_data_generator.batch_size
	s2=valid_data_generator.n//valid_data_generator.batch_size
	lr_sched = LearningRateScheduler(lambda epoch: 1e-4 * (0.75 ** np.floor(epoch / 2)))
	history = model.fit(train_data_generator,
    epochs = 30, 
    batch_size = 16,
    validation_data = valid_data_generator,
    validation_steps = s2,
    steps_per_epoch = s1,
    callbacks = [reduce_lr, early_stopping, checkpoint,lr_sched])
	printHistory(history,"EfficientNetV2L_RMSprop",early_stopping.stopped_epoch+1)
	modela = load_model("/content/drive/MyDrive/Capstone_data/crefv2lmnt_rms"+str(fold_var)+".h5") 
	
	results = modela.evaluate(valid_data_generator)
	results = dict(zip(model.metrics_names,results))
	Y_pred = modela.predict_generator(valid_data_generator)
	y_pred = np.argmax(Y_pred, axis=1)
	target_names = ['Normal','Pneumonia']
	cm = confusion_matrix(valid_data_generator.classes, y_pred)
	conf(cm,target_names)
	print('Classification Report')
	print(classification_report(valid_data_generator.classes, y_pred, target_names=target_names))
	auc = roc_auc_score(valid_data_generator.classes, y_pred) 
	plot_roc_curve(valid_data_generator.classes, y_pred,auc)
	TRAINING_ACCURACY.append(history.history['accuracy'])
	TRAINING_LOSS.append(history.history['loss'])
	VALIDATION_ACCURACY.append(history.history['val_accuracy'])
	VALIDATION_LOSS.append(history.history['val_loss'])

	fold_var += 1
# Out:
# K-Fold1
# Found 4172 validated image filenames belonging to 2 classes.
# Found 1044 validated image filenames belonging to 2 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-l_notop.h5
# 473176280/473176280 [==============================] - 20s 0us/step
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.RMSprop.
# Epoch 1/30
# 260/260 [==============================] - ETA: 0s - loss: 0.6610 - accuracy: 0.7656
# Epoch 1: val_accuracy improved from -inf to 0.93558, saving model to /content/drive/MyDrive/Capstone_data/crefv2lmnt_rms1.h5
# 260/260 [==============================] - 3623s 13s/step - loss: 0.6610 - accuracy: 0.7656 - val_loss: 0.2696 - val_accuracy: 0.9356 - lr: 1.0000e-04
# Epoch 2/30
# 260/260 [==============================] - ETA: 0s - loss: 0.4968 - accuracy: 0.8467
# Epoch 2: val_accuracy did not improve from 0.93558
# 260/260 [==============================] - 207s 793ms/step - loss: 0.4968 - accuracy: 0.8467 - val_loss: 0.5427 - val_accuracy: 0.8635 - lr: 1.0000e-04
# Epoch 3/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3837 - accuracy: 0.8874
# Epoch 3: val_accuracy did not improve from 0.93558
# 260/260 [==============================] - 206s 790ms/step - loss: 0.3837 - accuracy: 0.8874 - val_loss: 1.0589 - val_accuracy: 0.8019 - lr: 7.5000e-05
# Epoch 4/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3296 - accuracy: 0.9052
# Epoch 4: val_accuracy improved from 0.93558 to 0.95192, saving model to /content/drive/MyDrive/Capstone_data/crefv2lmnt_rms1.h5
# 260/260 [==============================] - 220s 844ms/step - loss: 0.3296 - accuracy: 0.9052 - val_loss: 0.2121 - val_accuracy: 0.9519 - lr: 7.5000e-05
# Epoch 5/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2807 - accuracy: 0.9184
# Epoch 5: val_accuracy did not improve from 0.95192
# 260/260 [==============================] - 206s 790ms/step - loss: 0.2807 - accuracy: 0.9184 - val_loss: 0.1567 - val_accuracy: 0.9471 - lr: 5.6250e-05
# Epoch 6/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2404 - accuracy: 0.9232
# Epoch 6: val_accuracy improved from 0.95192 to 0.96731, saving model to /content/drive/MyDrive/Capstone_data/crefv2lmnt_rms1.h5
# 260/260 [==============================] - 218s 836ms/step - loss: 0.2404 - accuracy: 0.9232 - val_loss: 0.0909 - val_accuracy: 0.9673 - lr: 5.6250e-05
# Epoch 7/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2255 - accuracy: 0.9384
# Epoch 7: val_accuracy did not improve from 0.96731
# 260/260 [==============================] - 206s 790ms/step - loss: 0.2255 - accuracy: 0.9384 - val_loss: 0.3565 - val_accuracy: 0.9327 - lr: 4.2188e-05
# Epoch 8/30
# 260/260 [==============================] - ETA: 0s - loss: 0.
saving model to /content/drive/MyDrive/Capstone_data/crefv2lmnt_rms4.h5
# 260/260 [==============================] - 343s 870ms/step - loss: 0.6597 - accuracy: 0.7688 - val_loss: 0.5897 - val_accuracy: 0.8471 - lr: 1.0000e-04
# Epoch 2/30
# 260/260 [==============================] - ETA: 0s - loss: 0.4638 - accuracy: 0.8631
# Epoch 2: val_accuracy improved from 0.84712 to 0.94519, saving model to /content/drive/MyDrive/Capstone_data/crefv2lmnt_rms4.h5
# 260/260 [==============================] - 218s 836ms/step - loss: 0.4638 - accuracy: 0.8631 - val_loss: 0.1648 - val_accuracy: 0.9452 - lr: 1.0000e-04
# Epoch 3/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3575 - accuracy: 0.8939
# Epoch 3: val_accuracy did not improve from 0.94519
# 260/260 [==============================] - 206s 793ms/step - loss: 0.3575 - accuracy: 0.8939 - val_loss: 0.5213 - val_accuracy: 0.8779 - lr: 7.5000e-05
# Epoch 4/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3126 - accuracy: 0.9009
# Epoch 4: val_accuracy did not improve from 0.94519
# 260/260 [==============================] - 206s 791ms/step - loss: 0.3126 - accuracy: 0.9009 - val_loss: 0.2914 - val_accuracy: 0.9337 - lr: 7.5000e-05
# Epoch 5/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2707 - accuracy: 0.9122
# Epoch 5: val_accuracy improved from 0.94519 to 0.96058, saving model to /content/drive/MyDrive/Capstone_data/crefv2lmnt_rms4.h5
# 260/260 [==============================] - 221s 848ms/step - loss: 0.2707 - accuracy: 0.9122 - val_loss: 0.1377 - val_accuracy: 0.9606 - lr: 5.6250e-05
# Epoch 6/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2717 - accuracy: 0.9230
# Epoch 6: val_accuracy did not improve from 0.96058
# 260/260 [==============================] - 207s 794ms/step - loss: 0.2717 - accuracy: 0.9230 - val_loss: 0.6941 - val_accuracy: 0.8721 - lr: 5.6250e-05
# Epoch 7/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2372 - accuracy: 0.9338
# Epoch 7: val_accuracy did not improve from 0.96058
# 260/260 [==============================] - 206s 792ms/step - loss: 0.2372 - accuracy: 0.9338 - val_loss: 0.5238 - val_accuracy: 0.9308 - lr: 4.2188e-05
# Epoch 8/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2424 - accuracy: 0.9305
# Epoch 8: val_accuracy did not improve from 0.96058
# 260/260 [==============================] - 206s 793ms/step - loss: 0.2424 - accuracy: 0.9305 - val_loss: 0.5793 - val_accuracy: 0.9163 - lr: 4.2188e-05
# Epoch 9/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2138 - accuracy: 0.9411
# Epoch 9: val_accuracy did not improve from 0.96058
# 260/260 [==============================] - 206s 792ms/step - loss: 0.2138 - accuracy: 0.9411 - val_loss: 0.2962 - val_accuracy: 0.9298 - lr: 3.1641e-05
# Epoch 10/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2011 - accuracy: 0.9418
# Epoch 10: val_accuracy did not improve from 0.96058
# 260/260 [==============================] - 206s 791ms/step - loss: 0.2011 - accuracy: 0.9418 - val_loss: 0.6285 - val_accuracy: 0.9481 - lr: 3.1641e-05
# Epoch 11/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1778 - accuracy: 0.9452
# Epoch 11: val_accuracy did not improve from 0.96058
# 260/260 [==============================] - 206s 793ms/step - loss: 0.1778 - accuracy: 0.9452 - val_loss: 0.1924 - val_accuracy: 0.9481 - lr: 2.3730e-05
# Epoch 12/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1809 - accuracy: 0.9490
# Epoch 12: val_accuracy did not improve from 0.96058
# 260/260 [==============================] - 206s 793ms/step - loss: 0.1809 - accuracy: 0.9490 - val_loss: 0.2661 - val_accuracy: 0.9452 - lr: 2.3730e-06
# Epoch 13/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1458 - accuracy: 0.9584
# Epoch 13: val_accuracy did not improve from 0.96058
# 260/260 [==============================] - 206s 792ms/step - loss: 0.1458 - accuracy: 0.9584 - val_loss: 0.1825 - val_accuracy: 0.9587 - lr: 1.7798e-05
# Epoch 14/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1435 - accuracy: 0.9586
# Epoch 14: val_accuracy did not improve from 0.96058
# 260/260 [==============================] - 206s 792ms/step - loss: 0.1435 - accuracy: 0.9586 - val_loss: 0.2656 - val_accuracy: 0.9596 - lr: 1.7798e-05
# Epoch 14: early stopping
# 66/66 [==============================] - 23s 230ms/step - loss: 0.1373 - accuracy: 0.9607
# <ipython-input-23-469c5067e6c4>:54: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   Y_pred = modela.predict_generator(valid_data_generator)
# Classification Report
#               precision    recall  f1-score   support
#
#       Normal       0.88      0.99      0.93       268
#    Pneumonia       0.99      0.95      0.97       775
#
#     accuracy                           0.96      1043
#    macro avg       0.94      0.97      0.95      1043
# weighted avg       0.96      0.96      0.96      1043
# K-Fold5
# Found 4173 validated image filenames belonging to 2 classes.
# Found 1043 validated image filenames belonging to 2 classes.
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.RMSprop.
# Epoch 1/30
# 260/260 [==============================] - ETA: 0s - loss: 0.6864 - accuracy: 0.7558
# Epoch 1: val_accuracy improved from -inf to 0.89904, saving model to /content/drive/MyDrive/Capstone_data/crefv2lmnt_rms5.h5
# 260/260 [==============================] - 355s 924ms/step - loss: 0.6864 - accuracy: 0.7558 - val_loss: 0.4219 - val_accuracy: 0.8990 - lr: 1.0000e-04
# Epoch 2/30
# 260/260 [==============================] - ETA: 0s - loss: 0.4985 - accuracy: 0.8463
# Epoch 2: val_accuracy did not improve from 0.89904
# 260/260 [==============================] - 212s 816ms/step - loss: 0.4985 - accuracy: 0.8463 - val_loss: 1.1906 - val_accuracy: 0.7615 - lr: 1.0000e-04
# Epoch 3/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3975 - accuracy: 0.8776
# Epoch 3: val_accuracy did not improve from 0.89904
# 260/260 [==============================] - 207s 794ms/step - loss: 0.3975 - accuracy: 0.8776 - val_loss: 0.4627 - val_accuracy: 0.8337 - lr: 7.5000e-05
# Epoch 4/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3565 - accuracy: 0.8898
# Epoch 4: val_accuracy did not improve from 0.89904
# 260/260 [==============================] - 207s 794ms/step - loss: 0.3565 - accuracy: 0.8898 - val_loss: 0.5738 - val_accuracy: 0.8846 - lr: 7.5000e-05
# Epoch 5/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3073 - accuracy: 0.9105
# Epoch 5: val_accuracy improved from 0.89904 to 0.95865, saving model to /content/drive/MyDrive/Capstone_data/crefv2lmnt_rms5.h5
# 260/260 [==============================] - 220s 844ms/step - loss: 0.3073 - accuracy: 0.9105 - val_loss: 0.1405 - val_accuracy: 0.9587 - lr: 5.6250e-05
# Epoch 6/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2281 - accuracy: 0.9249
# Epoch 6: val_accuracy did not improve from 0.95865
# 260/260 [==============================] - 207s 794ms/step - loss: 0.2281 - accuracy: 0.9249 - val_loss: 0.1940 - val_accuracy: 0.9462 - lr: 5.6250e-05
# Epoch 7/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2281 - accuracy: 0.9358
# Epoch 7: val_accuracy did not improve from 0.95865
# 260/260 [==============================] - 206s 792ms/step - loss: 0.2281 - accuracy: 0.9358 - val_loss: 0.1486 - val_accuracy: 0.9538 - lr: 4.2188e-05
# Epoch 8/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2254 - accuracy: 0.9384
# Epoch 8: val_accuracy did not improve from 0.95865
# 260/260 [==============================] - 206s 793ms/step - loss: 0.2254 - accuracy: 0.9384 - val_loss: 0.2342 - val_accuracy: 0.9490 - lr: 4.2188e-05
# Epoch 9/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2055 - accuracy: 0.9377
# Epoch 9: val_accuracy did not improve from 0.95865
# 260/260 [==============================] - 206s 792ms/step - loss: 0.2055 - accuracy: 0.9377 - val_loss: 0.1883 - val_accuracy: 0.9471 - lr: 3.1641e-05
# Epoch 10/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1784 - accuracy: 0.9490
# Epoch 10: val_accuracy did not improve from 0.95865
# 260/260 [==============================] - 206s 791ms/step - loss: 0.1784 - accuracy: 0.9490 - val_loss: 0.2571 - val_accuracy: 0.9375 - lr: 3.1641e-05
# Epoch 11/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1712 - accuracy: 0.9512
# Epoch 11: val_accuracy did not improve from 0.95865
# 260/260 [==============================] - 206s 793ms/step - loss: 0.1712 - accuracy: 0.9512 - val_loss: 0.2792 - val_accuracy: 0.9115 - lr: 2.3730e-05
# Epoch 12/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1625 - accuracy: 0.9507
# Epoch 12: val_accuracy did not improve from 0.95865
# 260/260 [==============================] - 206s 792ms/step - loss: 0.1625 - accuracy: 0.9507 - val_loss: 0.4329 - val_accuracy: 0.9135 - lr: 2.3730e-06
# Epoch 13/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1777 - accuracy: 0.9490
# Epoch 13: val_accuracy did not improve from 0.95865
# 260/260 [==============================] - 206s 792ms/step - loss: 0.1777 - accuracy: 0.9490 - val_loss: 0.3532 - val_accuracy: 0.9298 - lr: 1.7798e-05
# Epoch 14/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1423 - accuracy: 0.9565
# Epoch 14: val_accuracy did not improve from 0.95865
# 260/260 [==============================] - 206s 793ms/step - loss: 0.1423 - accuracy: 0.9565 - val_loss: 0.2446 - val_accuracy: 0.9433 - lr: 1.7798e-05
# Epoch 14: early stopping
# 66/66 [==============================] - 21s 230ms/step - loss: 0.1402 - accuracy: 0.9588
# <ipython-input-23-469c5067e6c4>:54: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   Y_pred = modela.predict_generator(valid_data_generator)
# Classification Report
#               precision    recall  f1-score   support
#
#       Normal       0.87      0.99      0.92       268
#    Pneumonia       1.00      0.95      0.97       775
#
#     accuracy                           0.96      1043
#    macro avg       0.93      0.97      0.95      1043
# weighted avg       0.96      0.96      0.96      1043

# %%
l1=max(VALIDATION_ACCURACY[0])
l2=max(VALIDATION_ACCURACY[1])
l3=max(VALIDATION_ACCURACY[2])
l4=max(VALIDATION_ACCURACY[3])
l5=max(VALIDATION_ACCURACY[4])

avg=(l1+l2+l3+l4+l5)/5
avg
# Out:
# 0.9615384697914123
