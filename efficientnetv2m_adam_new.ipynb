# %%
import keras
import tensorflow as tf
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten,Conv2D
from keras.models import Model
from keras import backend as K
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np
import cv2
import sklearn
import os
import seaborn as sns
from google.colab.patches import cv2_imshow
import glob
import keras
from keras.models import Sequential
from tensorflow.python.keras.layers import Dense, Flatten, GlobalAveragePooling2D, Activation, Flatten, Dropout
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import callbacks
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam, SGD

# %%
seed = 10

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
 batch_size=16

# %%
train_path="/content/drive/MyDrive/Capstone_data/Clahe_train"
test_path="/content/drive/MyDrive/Capstone_data/Clahe_test"
val_path="/content/drive/MyDrive/Capstone_data/Clahe_val"

# %%
train_normal = glob.glob(train_path+"/normal/*.jpeg")
train_pneumonia = glob.glob(train_path+"/pneumonia/*.jpeg")

test_normal = glob.glob(test_path+"/normal/*.jpeg")
test_pneumonia = glob.glob(test_path+"/pneumonia/*.jpeg")

val_normal = glob.glob(val_path+"/normal/*.jpeg")
val_pneumonia = glob.glob(val_path+"/pneumonia/*.jpeg")

# %%
train_list = [x for x in train_normal]
train_list.extend([x for x in train_pneumonia])

df_train = pd.DataFrame(np.concatenate([['Normal']*len(train_normal) , ['Pneumonia']*len(train_pneumonia)]), columns = ['class'])
df_train['image'] = [x for x in train_list]

test_list = [x for x in test_normal]
test_list.extend([x for x in test_pneumonia])

df_test = pd.DataFrame(np.concatenate([['Normal']*len(test_normal) , ['Pneumonia']*len(test_pneumonia)]), columns = ['class'])
df_test['image'] = [x for x in test_list]

val_list = [x for x in val_normal]
val_list.extend([x for x in val_pneumonia])

df_val = pd.DataFrame(np.concatenate([['Normal']*len(val_normal) , ['Pneumonia']*len(val_pneumonia)]), columns = ['class'])
df_val['image'] = [x for x in val_list]

# %%
df_train.head()
df_test.head()
df_val.head()
# Out:
#     class                                              image
# 0  Normal  /content/drive/MyDrive/Capstone_data/Clahe_val...
# 1  Normal  /content/drive/MyDrive/Capstone_data/Clahe_val...
# 2  Normal  /content/drive/MyDrive/Capstone_data/Clahe_val...
# 3  Normal  /content/drive/MyDrive/Capstone_data/Clahe_val...
# 4  Normal  /content/drive/MyDrive/Capstone_data/Clahe_val...

# %%
df_train=df_train.sample(frac=1)

# %%
df_train.head()
# Out:
#           class                                              image
# 3518  Pneumonia  /content/drive/MyDrive/Capstone_data/Clahe_tra...
# 495      Normal  /content/drive/MyDrive/Capstone_data/Clahe_tra...
# 1617  Pneumonia  /content/drive/MyDrive/Capstone_data/Clahe_tra...
# 197      Normal  /content/drive/MyDrive/Capstone_data/Clahe_tra...
# 3173  Pneumonia  /content/drive/MyDrive/Capstone_data/Clahe_tra...

# %%
from sklearn.model_selection import KFold, StratifiedKFold
Y = df_train[['class']]

kf = KFold(n_splits = 5)
                         
skf = StratifiedKFold(n_splits = 5, random_state = 7, shuffle = True)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator ,load_img,img_to_array

train_datagen = ImageDataGenerator(
        rescale = 1./255,
        shear_range=10,
        zoom_range=0.3,
        horizontal_flip=True,
        vertical_flip=True,
        brightness_range=[0.5,2.0],
        width_shift_range = 0.2,
        rotation_range=20,
        fill_mode = 'nearest',
)
test_datagen = ImageDataGenerator(
        rescale = 1./255)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Input, Flatten, SeparableConv2D
from tensorflow.keras.layers import GlobalMaxPooling2D,GlobalAveragePooling2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from tensorflow.keras.callbacks import ModelCheckpoint, Callback, EarlyStopping
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.applications import ResNet50, InceptionV3, EfficientNetV2M
from tensorflow.keras.layers.experimental.preprocessing import Normalization

# %%
df_train.shape
n=5216

# %%
x=len(train_normal)
y=len(train_pneumonia)
s1=(x+y)//batch_size
a=len(test_normal)
b=len(test_pneumonia)
s2=(a+b)//batch_size

# %%
from keras.callbacks import ReduceLROnPlateau
import numpy as np
from keras.callbacks import LearningRateScheduler
from tensorflow.keras.models import load_model
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix ,classification_report
import numpy as np

# %%
from tensorflow import keras
from keras import optimizers
import matplotlib.pyplot as plt

# %%
def printHistory(history, title, epochs):
    f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
    t = f.suptitle(title, fontsize=12)
    f.subplots_adjust(top=0.85, wspace=0.3)

    epoch_list = list(range(1,epochs+1))
    ax1.plot(epoch_list, history.history['accuracy'], label='Train Accuracy')
    ax1.plot(epoch_list, history.history['val_accuracy'], label='Validation Accuracy')
    ax1.set_xticks(np.arange(0, epochs+1, 5))
    ax1.set_ylabel('Accuracy Value')
    ax1.set_xlabel('Epoch')
    ax1.set_title('Accuracy')
    l1 = ax1.legend(loc="best")

    ax2.plot(epoch_list, history.history['loss'], label='Train Loss')
    ax2.plot(epoch_list, history.history['val_loss'], label='Validation Loss')
    ax2.set_xticks(np.arange(0, epochs+1, 5))
    ax2.set_ylabel('Loss Value')
    ax2.set_xlabel('Epoch')
    ax2.set_title('Loss')
    l2 = ax2.legend(loc="best")

# %%
from sklearn.metrics import roc_curve, roc_auc_score
def plot_roc_curve(predictions, labels,auc):
    fpr, tpr, thresholds = roc_curve(labels, predictions) 
    plt.title('Receiver Operating Characteristic (ROC)  Curve',fontsize=14)
    plt.xlim([0, 1])
    plt.ylim([0, 1])
    plt.plot(fpr, tpr, 'g',label = 'AUC Score = %0.2f' % auc)
    plt.plot([0, 1], [0, 1],'r--')
    plt.ylabel('\nTrue Positive Rate (TPR)', fontsize=12)
    plt.xlabel('\nFalse Positive Rate (FPR)', fontsize=12)
    plt.legend()
    plt.grid()
    plt.show()

# %%
def conf(cm,target_names):
    plt.figure(figsize=(5,3))
    sns.set(font_scale=1.2)
    ax = sns.heatmap(cm, annot=True,xticklabels=['H', 'P'], yticklabels=['H', 'P'], cbar=False, cmap='Blues',linewidths=1, linecolor='black', fmt='.0f')
    plt.yticks(rotation=0)
    plt.xlabel('Predicted labels')
    plt.ylabel('True labels')
    ax.xaxis.set_ticks_position('top') 
    plt.title('Confusion matrix')
    plt.show()

# %%
VALIDATION_ACCURACY = []
VALIDATION_LOSS = []
TRAINING_ACCURACY=[]
TRAINING_LOSS=[]

save_dir = '/content/drive/MyDrive/Capstone_data/Clahe_train'
fold_var=1
fine_tune_at=30
t=df_train[['class']]
for train_index, val_index in skf.split(np.zeros(len(Y)),Y):
	print("K-Fold"+str(fold_var))
	training_data = df_train.iloc[train_index]
	validation_data = df_train.iloc[val_index]
	
	train_data_generator = train_datagen.flow_from_dataframe(dataframe=training_data,x_col="image",y_col="class",target_size=(224,224),
                                               batch_size=16,class_mode='categorical',shuffle=True)
	valid_data_generator  = test_datagen.flow_from_dataframe(dataframe=validation_data,x_col="image",y_col="class",target_size=(224,224),
                                               batch_size=16,class_mode='categorical',shuffle=False)
        
 	# CREATE NEW MODEL
	model = Sequential()
	conv_base = EfficientNetV2M(input_shape=[224,224]+[3], include_top=False, weights='imagenet')
	for layer in conv_base.layers[:fine_tune_at]:
		layer.trainable = False
	x=  conv_base.output
	x = GlobalAveragePooling2D()(x)
	x = BatchNormalization()(x)
	x = Dropout(0.3)(x) 
	x = Dense(512, activation ='relu')(x)
	x = BatchNormalization()(x)
	x = Dropout(0.5)(x)
	x = Dense(2, activation ='sigmoid')(x)
	model = Model(conv_base.input, x)
	reduce_lr = ReduceLROnPlateau(monitor='val_loss',patience=8)
	early_stopping = EarlyStopping(monitor = "val_accuracy",patience = 9,verbose = 1,mode = "max",)
	checkpoint = ModelCheckpoint(monitor = "val_accuracy",filepath = "/content/drive/MyDrive/Capstone_data/crefv2Mmnt_adam"+str(fold_var)+".h5",verbose = 1,save_best_only = True, )
	opt = keras.optimizers.Adam(lr=0.0001)
	model.compile(loss = "binary_crossentropy", optimizer =opt, metrics = "accuracy")
	s1=train_data_generator.n//train_data_generator.batch_size
	s2=valid_data_generator.n//valid_data_generator.batch_size
	lr_sched = LearningRateScheduler(lambda epoch: 1e-4 * (0.75 ** np.floor(epoch / 2)))
	history = model.fit(train_data_generator,
    epochs = 30, 
    batch_size = 16,
    validation_data = valid_data_generator,
    validation_steps = s2,
    steps_per_epoch = s1,
    callbacks = [reduce_lr, early_stopping, checkpoint,lr_sched])
	printHistory(history,"EfficientNetV2M_Adam",early_stopping.stopped_epoch+1)
	modela = load_model("/content/drive/MyDrive/Capstone_data/crefv2Mmnt_adam"+str(fold_var)+".h5") 
	
	results = modela.evaluate(valid_data_generator)
	results = dict(zip(model.metrics_names,results))
	Y_pred = modela.predict_generator(valid_data_generator)
	y_pred = np.argmax(Y_pred, axis=1)
	target_names = ['Normal','Pneumonia']
	cm = confusion_matrix(valid_data_generator.classes, y_pred)
	conf(cm,target_names)
	print('Classification Report')
	print(classification_report(valid_data_generator.classes, y_pred, target_names=target_names))
	auc = roc_auc_score(valid_data_generator.classes, y_pred) 
	plot_roc_curve(valid_data_generator.classes, y_pred,auc)
	TRAINING_ACCURACY.append(history.history['accuracy'])
	TRAINING_LOSS.append(history.history['loss'])
	VALIDATION_ACCURACY.append(history.history['val_accuracy'])
	VALIDATION_LOSS.append(history.history['val_loss'])

	fold_var += 1
# Out:
# K-Fold1
# Found 4172 validated image filenames belonging to 2 classes.
# Found 1044 validated image filenames belonging to 2 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-m_notop.h5
# 214201816/214201816 [==============================] - 11s 0us/step
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/30
# 260/260 [==============================] - ETA: 0s - loss: 0.6925 - accuracy: 0.7358
# Epoch 1: val_accuracy improved from -inf to 0.83750, saving model to /content/drive/MyDrive/Capstone_data/crefv2Mmnt_adam1.h5
# 260/260 [==============================] - 4198s 16s/step - loss: 0.6925 - accuracy: 0.7358 - val_loss: 0.5593 - val_accuracy: 0.8375 - lr: 1.0000e-04
# Epoch 2/30
# 260/260 [==============================] - ETA: 0s - loss: 0.4569 - accuracy: 0.8600
# Epoch 2: val_accuracy improved from 0.83750 to 0.93462, saving model to /content/drive/MyDrive/Capstone_data/crefv2Mmnt_adam1.h5
# 260/260 [==============================] - 143s 548ms/step - loss: 0.4569 - accuracy: 0.8600 - val_loss: 0.2004 - val_accuracy: 0.9346 - lr: 1.0000e-04
# Epoch 3/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3838 - accuracy: 0.8798
# Epoch 3: val_accuracy did not improve from 0.93462
# 260/260 [==============================] - 127s 486ms/step - loss: 0.3838 - accuracy: 0.8798 - val_loss: 0.3145 - val_accuracy: 0.9135 - lr: 7.5000e-05
# Epoch 4/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3465 - accuracy: 0.8869
# Epoch 4: val_accuracy improved from 0.93462 to 0.95865, saving model to /content/drive/MyDrive/Capstone_data/crefv2Mmnt_adam1.h5
# 260/260 [==============================] - 138s 530ms/step - loss: 0.3465 - accuracy: 0.8869 - val_loss: 0.1943 - val_accuracy: 0.9587 - lr: 7.5000e-05
# Epoch 5/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2871 - accuracy: 0.9078
# Epoch 5: val_accuracy did not improve from 0.95865
# 260/260 [==============================] - 127s 486ms/step - loss: 0.2871 - accuracy: 0.9078 - val_loss: 0.1881 - val_accuracy: 0.9452 - lr: 5.6250e-05
# Epoch 6/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2787 - accuracy: 0.9117
# Epoch 6: val_accuracy did not improve from 0.95865
# 260/260 [==============================] - 125s 481ms/step - loss: 0.2787 - accuracy: 0.9117 - val_loss: 0.1949 - val_accuracy: 0.9365 - lr: 5.6250e-05
# Epoch 7/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2609 - accuracy: 0.9182
# Epoch 7: val_accuracy did not improve from 0.95865
# 260/260 [==============================] - 126s 483ms/step - loss: 0.2609 - accuracy: 0.9182 - val_loss: 0.2021 - val_accuracy: 0.9413 - lr: 4.2188e-05
# Epoch 8/30
# 260/260 [==============================] - ETA: 0s - loss: 0.
val_accuracy did not improve from 0.97019
# 260/260 [==============================] - 126s 482ms/step - loss: 0.1299 - accuracy: 0.9620 - val_loss: 0.2354 - val_accuracy: 0.9510 - lr: 4.2235e-06
# Epoch 25/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1561 - accuracy: 0.9584
# Epoch 25: val_accuracy did not improve from 0.97019
# 260/260 [==============================] - 126s 482ms/step - loss: 0.1561 - accuracy: 0.9584 - val_loss: 0.1799 - val_accuracy: 0.9548 - lr: 3.1676e-06
# Epoch 26/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1285 - accuracy: 0.9618
# Epoch 26: val_accuracy did not improve from 0.97019
# 260/260 [==============================] - 126s 482ms/step - loss: 0.1285 - accuracy: 0.9618 - val_loss: 0.1395 - val_accuracy: 0.9635 - lr: 3.1676e-06
# Epoch 27/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1558 - accuracy: 0.9529
# Epoch 27: val_accuracy did not improve from 0.97019
# 260/260 [==============================] - 125s 481ms/step - loss: 0.1558 - accuracy: 0.9529 - val_loss: 0.1595 - val_accuracy: 0.9519 - lr: 2.3757e-06
# Epoch 28/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1271 - accuracy: 0.9608
# Epoch 28: val_accuracy did not improve from 0.97019
# 260/260 [==============================] - 126s 483ms/step - loss: 0.1271 - accuracy: 0.9608 - val_loss: 0.1916 - val_accuracy: 0.9519 - lr: 2.3757e-07
# Epoch 29/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1174 - accuracy: 0.9615
# Epoch 29: val_accuracy did not improve from 0.97019
# 260/260 [==============================] - 127s 486ms/step - loss: 0.1174 - accuracy: 0.9615 - val_loss: 0.1776 - val_accuracy: 0.9510 - lr: 1.7818e-06
# Epoch 29: early stopping
# 66/66 [==============================] - 18s 212ms/step - loss: 0.1207 - accuracy: 0.9703
# <ipython-input-21-6a64457e4d8c>:54: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   Y_pred = modela.predict_generator(valid_data_generator)
# Classification Report
#               precision    recall  f1-score   support
#
#       Normal       0.92      0.97      0.94       268
#    Pneumonia       0.99      0.97      0.98       775
#
#     accuracy                           0.97      1043
#    macro avg       0.95      0.97      0.96      1043
# weighted avg       0.97      0.97      0.97      1043
# K-Fold4
# Found 4173 validated image filenames belonging to 2 classes.
# Found 1043 validated image filenames belonging to 2 classes.
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/30
# 260/260 [==============================] - ETA: 0s - loss: 0.6865 - accuracy: 0.7484
# Epoch 1: val_accuracy improved from -inf to 0.87981, saving model to /content/drive/MyDrive/Capstone_data/crefv2Mmnt_adam4.h5
# 260/260 [==============================] - 262s 597ms/step - loss: 0.6865 - accuracy: 0.7484 - val_loss: 0.5265 - val_accuracy: 0.8798 - lr: 1.0000e-04
# Epoch 2/30
# 260/260 [==============================] - ETA: 0s - loss: 0.4443 - accuracy: 0.8670
# Epoch 2: val_accuracy improved from 0.87981 to 0.92404, saving model to /content/drive/MyDrive/Capstone_data/crefv2Mmnt_adam4.h5
# 260/260 [==============================] - 140s 538ms/step - loss: 0.4443 - accuracy: 0.8670 - val_loss: 0.5274 - val_accuracy: 0.9240 - lr: 1.0000e-04
# Epoch 3/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3930 - accuracy: 0.8747
# Epoch 3: val_accuracy did not improve from 0.92404
# 260/260 [==============================] - 128s 489ms/step - loss: 0.3930 - accuracy: 0.8747 - val_loss: 0.3638 - val_accuracy: 0.9048 - lr: 7.5000e-05
# Epoch 4/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3483 - accuracy: 0.8932
# Epoch 4: val_accuracy improved from 0.92404 to 0.92692, saving model to /content/drive/MyDrive/Capstone_data/crefv2Mmnt_adam4.h5
# 260/260 [==============================] - 139s 534ms/step - loss: 0.3483 - accuracy: 0.8932 - val_loss: 0.1942 - val_accuracy: 0.9269 - lr: 7.5000e-05
# Epoch 5/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2951 - accuracy: 0.9081
# Epoch 5: val_accuracy improved from 0.92692 to 0.94231, saving model to /content/drive/MyDrive/Capstone_data/crefv2Mmnt_adam4.h5
# 260/260 [==============================] - 139s 533ms/step - loss: 0.2951 - accuracy: 0.9081 - val_loss: 0.2137 - val_accuracy: 0.9423 - lr: 5.6250e-05
# Epoch 6/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2682 - accuracy: 0.9127
# Epoch 6: val_accuracy improved from 0.94231 to 0.95962, saving model to /content/drive/MyDrive/Capstone_data/crefv2Mmnt_adam4.h5
# 260/260 [==============================] - 139s 535ms/step - loss: 0.2682 - accuracy: 0.9127 - val_loss: 0.1418 - val_accuracy: 0.9596 - lr: 5.6250e-05
# Epoch 7/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2470 - accuracy: 0.9233
# Epoch 7: val_accuracy did not improve from 0.95962
# 260/260 [==============================] - 128s 491ms/step - loss: 0.2470 - accuracy: 0.9233 - val_loss: 0.2279 - val_accuracy: 0.9462 - lr: 4.2188e-05
# Epoch 8/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2528 - accuracy: 0.9206
# Epoch 8: val_accuracy did not improve from 0.95962
# 260/260 [==============================] - 126s 485ms/step - loss: 0.2528 - accuracy: 0.9206 - val_loss: 1.6190 - val_accuracy: 0.7981 - lr: 4.2188e-05
# Epoch 9/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2403 - accuracy: 0.9192
# Epoch 9: val_accuracy did not improve from 0.95962
# 260/260 [==============================] - 126s 485ms/step - loss: 0.2403 - accuracy: 0.9192 - val_loss: 0.2990 - val_accuracy: 0.9529 - lr: 3.1641e-05
# Epoch 10/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2416 - accuracy: 0.9247
# Epoch 10: val_accuracy did not improve from 0.95962
# 260/260 [==============================] - 126s 482ms/step - loss: 0.2416 - accuracy: 0.9247 - val_loss: 0.2179 - val_accuracy: 0.9385 - lr: 3.1641e-05
# Epoch 11/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2304 - accuracy: 0.9274
# Epoch 11: val_accuracy did not improve from 0.95962
# 260/260 [==============================] - 127s 486ms/step - loss: 0.2304 - accuracy: 0.9274 - val_loss: 0.1551 - val_accuracy: 0.9596 - lr: 2.3730e-05
# Epoch 12/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1929 - accuracy: 0.9437
# Epoch 12: val_accuracy did not improve from 0.95962
# 260/260 [==============================] - 127s 486ms/step - loss: 0.1929 - accuracy: 0.9437 - val_loss: 0.2343 - val_accuracy: 0.9385 - lr: 2.3730e-05
# Epoch 13/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2078 - accuracy: 0.9314
# Epoch 13: val_accuracy did not improve from 0.95962
# 260/260 [==============================] - 127s 488ms/step - loss: 0.2078 - accuracy: 0.9314 - val_loss: 0.5358 - val_accuracy: 0.9192 - lr: 1.7798e-05
# Epoch 14/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1816 - accuracy: 0.9425
# Epoch 14: val_accuracy did not improve from 0.95962
# 260/260 [==============================] - 126s 485ms/step - loss: 0.1816 - accuracy: 0.9425 - val_loss: 0.3878 - val_accuracy: 0.9394 - lr: 1.7798e-06
# Epoch 15/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1934 - accuracy: 0.9468
# Epoch 15: val_accuracy did not improve from 0.95962
# 260/260 [==============================] - 126s 485ms/step - loss: 0.1934 - accuracy: 0.9468 - val_loss: 0.3627 - val_accuracy: 0.9327 - lr: 1.3348e-05
# Epoch 15: early stopping
# 66/66 [==============================] - 18s 212ms/step - loss: 0.1431 - accuracy: 0.9588
# <ipython-input-21-6a64457e4d8c>:54: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   Y_pred = modela.predict_generator(valid_data_generator)
# Classification Report
#               precision    recall  f1-score   support
#
#       Normal       0.89      0.96      0.92       268
#    Pneumonia       0.98      0.96      0.97       775
#
#     accuracy                           0.96      1043
#    macro avg       0.94      0.96      0.95      1043
# weighted avg       0.96      0.96      0.96      1043
# K-Fold5
# Found 4173 validated image filenames belonging to 2 classes.
# Found 1043 validated image filenames belonging to 2 classes.
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/30
# 260/260 [==============================] - ETA: 0s - loss: 0.7251 - accuracy: 0.7253
# Epoch 1: val_accuracy improved from -inf to 0.82596, saving model to /content/drive/MyDrive/Capstone_data/crefv2Mmnt_adam5.h5
# 260/260 [==============================] - 269s 625ms/step - loss: 0.7251 - accuracy: 0.7253 - val_loss: 0.6788 - val_accuracy: 0.8260 - lr: 1.0000e-04
# Epoch 2/30
# 260/260 [==============================] - ETA: 0s - loss: 0.4759 - accuracy: 0.8494
# Epoch 2: val_accuracy improved from 0.82596 to 0.85962, saving model to /content/drive/MyDrive/Capstone_data/crefv2Mmnt_adam5.h5
# 260/260 [==============================] - 140s 537ms/step - loss: 0.4759 - accuracy: 0.8494 - val_loss: 0.6038 - val_accuracy: 0.8596 - lr: 1.0000e-04
# Epoch 3/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3992 - accuracy: 0.8824
# Epoch 3: val_accuracy improved from 0.85962 to 0.91635, saving model to /content/drive/MyDrive/Capstone_data/crefv2Mmnt_adam5.h5
# 260/260 [==============================] - 138s 532ms/step - loss: 0.3992 - accuracy: 0.8824 - val_loss: 0.2423 - val_accuracy: 0.9163 - lr: 7.5000e-05
# Epoch 4/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3416 - accuracy: 0.8961
# Epoch 4: val_accuracy did not improve from 0.91635
# 260/260 [==============================] - 127s 488ms/step - loss: 0.3416 - accuracy: 0.8961 - val_loss: 0.2719 - val_accuracy: 0.9135 - lr: 7.5000e-05
# Epoch 5/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2989 - accuracy: 0.9047
# Epoch 5: val_accuracy improved from 0.91635 to 0.95481, saving model to /content/drive/MyDrive/Capstone_data/crefv2Mmnt_adam5.h5
# 260/260 [==============================] - 144s 555ms/step - loss: 0.2989 - accuracy: 0.9047 - val_loss: 0.1555 - val_accuracy: 0.9548 - lr: 5.6250e-05
# Epoch 6/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3104 - accuracy: 0.9028
# Epoch 6: val_accuracy did not improve from 0.95481
# 260/260 [==============================] - 128s 490ms/step - loss: 0.3104 - accuracy: 0.9028 - val_loss: 0.2751 - val_accuracy: 0.9058 - lr: 5.6250e-05
# Epoch 7/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2997 - accuracy: 0.9062
# Epoch 7: val_accuracy did not improve from 0.95481
# 260/260 [==============================] - 127s 488ms/step - loss: 0.2997 - accuracy: 0.9062 - val_loss: 0.1915 - val_accuracy: 0.9260 - lr: 4.2188e-05
# Epoch 8/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2576 - accuracy: 0.9235
# Epoch 8: val_accuracy did not improve from 0.95481
# 260/260 [==============================] - 127s 487ms/step - loss: 0.2576 - accuracy: 0.9235 - val_loss: 0.1866 - val_accuracy: 0.9317 - lr: 4.2188e-05
# Epoch 9/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2423 - accuracy: 0.9274
# Epoch 9: val_accuracy did not improve from 0.95481
# 260/260 [==============================] - 126s 484ms/step - loss: 0.2423 - accuracy: 0.9274 - val_loss: 0.2118 - val_accuracy: 0.9250 - lr: 3.1641e-05
# Epoch 10/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2058 - accuracy: 0.9341
# Epoch 10: val_accuracy did not improve from 0.95481
# 260/260 [==============================] - 127s 489ms/step - loss: 0.2058 - accuracy: 0.9341 - val_loss: 0.2575 - val_accuracy: 0.9058 - lr: 3.1641e-05
# Epoch 11/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2293 - accuracy: 0.9300
# Epoch 11: val_accuracy did not improve from 0.95481
# 260/260 [==============================] - 127s 489ms/step - loss: 0.2293 - accuracy: 0.9300 - val_loss: 0.3727 - val_accuracy: 0.9010 - lr: 2.3730e-05
# Epoch 12/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2165 - accuracy: 0.9343
# Epoch 12: val_accuracy did not improve from 0.95481
# 260/260 [==============================] - 127s 487ms/step - loss: 0.2165 - accuracy: 0.9343 - val_loss: 0.2555 - val_accuracy: 0.9212 - lr: 2.3730e-05
# Epoch 13/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2236 - accuracy: 0.9310
# Epoch 13: val_accuracy did not improve from 0.95481
# 260/260 [==============================] - 127s 487ms/step - loss: 0.2236 - accuracy: 0.9310 - val_loss: 0.2153 - val_accuracy: 0.9394 - lr: 1.7798e-06
# Epoch 14/30
# 260/260 [==============================] - ETA: 0s - loss: 0.1873 - accuracy: 0.9423
# Epoch 14: val_accuracy did not improve from 0.95481
# 260/260 [==============================] - 127s 487ms/step - loss: 0.1873 - accuracy: 0.9423 - val_loss: 0.1809 - val_accuracy: 0.9365 - lr: 1.7798e-05
# Epoch 14: early stopping
# 66/66 [==============================] - 18s 218ms/step - loss: 0.1562 - accuracy: 0.9540
# <ipython-input-21-6a64457e4d8c>:54: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   Y_pred = modela.predict_generator(valid_data_generator)
# Classification Report
#               precision    recall  f1-score   support
#
#       Normal       0.88      0.95      0.91       268
#    Pneumonia       0.98      0.95      0.97       775
#
#     accuracy                           0.95      1043
#    macro avg       0.93      0.95      0.94      1043
# weighted avg       0.96      0.95      0.95      1043

# %%
l1=max(VALIDATION_ACCURACY[0])
l2=max(VALIDATION_ACCURACY[1])
l3=max(VALIDATION_ACCURACY[2])
l4=max(VALIDATION_ACCURACY[3])
l5=max(VALIDATION_ACCURACY[4])

avg=(l1+l2+l3+l4+l5)/5
avg
# Out:
# 0.9638461589813232
