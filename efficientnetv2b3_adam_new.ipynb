# %%
import keras
import tensorflow as tf
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten,Conv2D
from keras.models import Model
from keras import backend as K
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np
import cv2
import sklearn
import os
import seaborn as sns
from google.colab.patches import cv2_imshow
import glob
import keras
from keras.models import Sequential
from tensorflow.python.keras.layers import Dense, Flatten, GlobalAveragePooling2D, Activation, Flatten, Dropout
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import callbacks
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam, SGD

# %%
seed = 10

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
 batch_size=16

# %%
train_path="/content/drive/MyDrive/Capstone_data/Clahe_train"
test_path="/content/drive/MyDrive/Capstone_data/Clahe_test"
val_path="/content/drive/MyDrive/Capstone_data/Clahe_val"

# %%
train_normal = glob.glob(train_path+"/normal/*.jpeg")
train_pneumonia = glob.glob(train_path+"/pneumonia/*.jpeg")

test_normal = glob.glob(test_path+"/normal/*.jpeg")
test_pneumonia = glob.glob(test_path+"/pneumonia/*.jpeg")

val_normal = glob.glob(val_path+"/normal/*.jpeg")
val_pneumonia = glob.glob(val_path+"/pneumonia/*.jpeg")

# %%
train_list = [x for x in train_normal]
train_list.extend([x for x in train_pneumonia])

df_train = pd.DataFrame(np.concatenate([['Normal']*len(train_normal) , ['Pneumonia']*len(train_pneumonia)]), columns = ['class'])
df_train['image'] = [x for x in train_list]

test_list = [x for x in test_normal]
test_list.extend([x for x in test_pneumonia])

df_test = pd.DataFrame(np.concatenate([['Normal']*len(test_normal) , ['Pneumonia']*len(test_pneumonia)]), columns = ['class'])
df_test['image'] = [x for x in test_list]

val_list = [x for x in val_normal]
val_list.extend([x for x in val_pneumonia])

df_val = pd.DataFrame(np.concatenate([['Normal']*len(val_normal) , ['Pneumonia']*len(val_pneumonia)]), columns = ['class'])
df_val['image'] = [x for x in val_list]

# %%
df_train.head()
df_test.head()
df_val.head()
# Out:
#     class                                              image
# 0  Normal  /content/drive/MyDrive/Capstone_data/Clahe_val...
# 1  Normal  /content/drive/MyDrive/Capstone_data/Clahe_val...
# 2  Normal  /content/drive/MyDrive/Capstone_data/Clahe_val...
# 3  Normal  /content/drive/MyDrive/Capstone_data/Clahe_val...
# 4  Normal  /content/drive/MyDrive/Capstone_data/Clahe_val...

# %%
df_train=df_train.sample(frac=1)

# %%
df_train.head()
# Out:
#           class                                              image
# 2017  Pneumonia  /content/drive/MyDrive/Capstone_data/Clahe_tra...
# 1713  Pneumonia  /content/drive/MyDrive/Capstone_data/Clahe_tra...
# 563      Normal  /content/drive/MyDrive/Capstone_data/Clahe_tra...
# 1284     Normal  /content/drive/MyDrive/Capstone_data/Clahe_tra...
# 2766  Pneumonia  /content/drive/MyDrive/Capstone_data/Clahe_tra...

# %%
from sklearn.model_selection import KFold, StratifiedKFold
Y = df_train[['class']]

kf = KFold(n_splits = 5)
                         
skf = StratifiedKFold(n_splits = 5, random_state = 7, shuffle = True)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator ,load_img,img_to_array

train_datagen = ImageDataGenerator(
        rescale = 1./255,
        shear_range=10,
        zoom_range=0.3,
        horizontal_flip=True,
        vertical_flip=True,
        brightness_range=[0.5,2.0],
        width_shift_range = 0.2,
        rotation_range=20,
        fill_mode = 'nearest',
)
test_datagen = ImageDataGenerator(
        rescale = 1./255)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Input, Flatten, SeparableConv2D
from tensorflow.keras.layers import GlobalMaxPooling2D,GlobalAveragePooling2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from tensorflow.keras.callbacks import ModelCheckpoint, Callback, EarlyStopping
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.applications import ResNet50, InceptionV3, EfficientNetV2B3
from tensorflow.keras.layers.experimental.preprocessing import Normalization

# %%
df_train.shape
n=5216

# %%
x=len(train_normal)
y=len(train_pneumonia)
s1=(x+y)//batch_size
a=len(test_normal)
b=len(test_pneumonia)
s2=(a+b)//batch_size

# %%
from keras.callbacks import ReduceLROnPlateau
import numpy as np
from keras.callbacks import LearningRateScheduler
from tensorflow.keras.models import load_model
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix ,classification_report
import numpy as np

# %%
from tensorflow import keras
from keras import optimizers
import matplotlib.pyplot as plt

# %%
def printHistory(history, title, epochs):
    f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
    t = f.suptitle(title, fontsize=12)
    f.subplots_adjust(top=0.85, wspace=0.3)

    epoch_list = list(range(1,epochs+1))
    ax1.plot(epoch_list, history.history['accuracy'], label='Train Accuracy')
    ax1.plot(epoch_list, history.history['val_accuracy'], label='Validation Accuracy')
    ax1.set_xticks(np.arange(0, epochs+1, 5))
    ax1.set_ylabel('Accuracy Value')
    ax1.set_xlabel('Epoch')
    ax1.set_title('Accuracy')
    l1 = ax1.legend(loc="best")

    ax2.plot(epoch_list, history.history['loss'], label='Train Loss')
    ax2.plot(epoch_list, history.history['val_loss'], label='Validation Loss')
    ax2.set_xticks(np.arange(0, epochs+1, 5))
    ax2.set_ylabel('Loss Value')
    ax2.set_xlabel('Epoch')
    ax2.set_title('Loss')
    l2 = ax2.legend(loc="best")

# %%
from sklearn.metrics import roc_curve, roc_auc_score
def plot_roc_curve(predictions, labels,auc):
    fpr, tpr, thresholds = roc_curve(labels, predictions) 
    plt.title('Receiver Operating Characteristic (ROC)  Curve',fontsize=14)
    plt.xlim([0, 1])
    plt.ylim([0, 1])
    plt.plot(fpr, tpr, 'g',label = 'AUC Score = %0.2f' % auc)
    plt.plot([0, 1], [0, 1],'r--')
    plt.ylabel('\nTrue Positive Rate (TPR)', fontsize=12)
    plt.xlabel('\nFalse Positive Rate (FPR)', fontsize=12)
    plt.legend()
    plt.grid()
    plt.show()

# %%
def conf(cm,target_names):
    plt.figure(figsize=(5,3))
    sns.set(font_scale=1.2)
    ax = sns.heatmap(cm, annot=True,xticklabels=['H', 'P'], yticklabels=['H', 'P'], cbar=False, cmap='Blues',linewidths=1, linecolor='black', fmt='.0f')
    plt.yticks(rotation=0)
    plt.xlabel('Predicted labels')
    plt.ylabel('True labels')
    ax.xaxis.set_ticks_position('top') 
    plt.title('Confusion matrix')
    plt.show()

# %%
VALIDATION_ACCURACY = []
VALIDATION_LOSS = []
TRAINING_ACCURACY=[]
TRAINING_LOSS=[]

save_dir = '/content/drive/MyDrive/Capstone_data/Clahe_train'
fold_var=1
fine_tune_at=30
t=df_train[['class']]
for train_index, val_index in skf.split(np.zeros(len(Y)),Y):
	print("K-Fold"+str(fold_var))
	training_data = df_train.iloc[train_index]
	validation_data = df_train.iloc[val_index]
	
	train_data_generator = train_datagen.flow_from_dataframe(dataframe=training_data,x_col="image",y_col="class",target_size=(224,224),
                                               batch_size=16,class_mode='categorical',shuffle=True)
	valid_data_generator  = test_datagen.flow_from_dataframe(dataframe=validation_data,x_col="image",y_col="class",target_size=(224,224),
                                               batch_size=16,class_mode='categorical',shuffle=False)
        
 	# CREATE NEW MODEL
	model = Sequential()
	conv_base = EfficientNetV2B3(input_shape=[224,224]+[3], include_top=False, weights='imagenet')
	for layer in conv_base.layers[:fine_tune_at]:
		layer.trainable = False
	x=  conv_base.output
	x = GlobalAveragePooling2D()(x)
	x = BatchNormalization()(x)
	x = Dropout(0.3)(x) 
	x = Dense(512, activation ='relu')(x)
	x = BatchNormalization()(x)
	x = Dropout(0.5)(x)
	x = Dense(2, activation ='sigmoid')(x)
	model = Model(conv_base.input, x)
	reduce_lr = ReduceLROnPlateau(monitor='val_loss',patience=7)
	early_stopping = EarlyStopping(monitor = "val_accuracy",patience = 9,verbose = 1,mode = "max",)
	checkpoint = ModelCheckpoint(monitor = "val_accuracy",filepath = "/content/drive/MyDrive/Capstone_data/crefv2b3mnt_adam"+str(fold_var)+".h5",verbose = 1,save_best_only = True, )
	opt = keras.optimizers.Adam(lr=0.0001)
	model.compile(loss = "binary_crossentropy", optimizer =opt, metrics = "accuracy")
	s1=train_data_generator.n//train_data_generator.batch_size
	s2=valid_data_generator.n//valid_data_generator.batch_size
	lr_sched = LearningRateScheduler(lambda epoch: 1e-4 * (0.75 ** np.floor(epoch / 2)))
	history = model.fit(train_data_generator,
    epochs = 30, 
    batch_size = 16,
    validation_data = valid_data_generator,
    validation_steps = s2,
    steps_per_epoch = s1,
    callbacks = [reduce_lr, early_stopping, checkpoint,lr_sched])
	if early_stopping.stopped_epoch==0:
		x=30
	else:
		x=early_stopping.stopped_epoch+1
	printHistory(history,"EfficientNetV2B3_Adam",x)
	modela = load_model("/content/drive/MyDrive/Capstone_data/crefv2b3mnt_adam"+str(fold_var)+".h5") 
	
	results = modela.evaluate(valid_data_generator)
	results = dict(zip(model.metrics_names,results))
	Y_pred = modela.predict_generator(valid_data_generator)
	y_pred = np.argmax(Y_pred, axis=1)
	target_names = ['Normal','Pneumonia']
	cm = confusion_matrix(valid_data_generator.classes, y_pred)
	conf(cm,target_names)
	print('Classification Report')
	print(classification_report(valid_data_generator.classes, y_pred, target_names=target_names))
	auc = roc_auc_score(valid_data_generator.classes, y_pred) 
	plot_roc_curve(valid_data_generator.classes, y_pred,auc)
	TRAINING_ACCURACY.append(history.history['accuracy'])
	TRAINING_LOSS.append(history.history['loss'])
	VALIDATION_ACCURACY.append(history.history['val_accuracy'])
	VALIDATION_LOSS.append(history.history['val_loss'])

	fold_var += 1
# Out:
# K-Fold1
# Found 4172 validated image filenames belonging to 2 classes.
# Found 1044 validated image filenames belonging to 2 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-b3_notop.h5
# 52606240/52606240 [==============================] - 3s 0us/step
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/30
# 260/260 [==============================] - ETA: 0s - loss: 0.7521 - accuracy: 0.7108
# Epoch 1: val_accuracy improved from -inf to 0.87212, saving model to /content/drive/MyDrive/Capstone_data/crefv2b3mnt_adam1.h5
# 260/260 [==============================] - 2554s 10s/step - loss: 0.7521 - accuracy: 0.7108 - val_loss: 0.3564 - val_accuracy: 0.8721 - lr: 1.0000e-04
# Epoch 2/30
# 260/260 [==============================] - ETA: 0s - loss: 0.5531 - accuracy: 0.8142
# Epoch 2: val_accuracy improved from 0.87212 to 0.92885, saving model to /content/drive/MyDrive/Capstone_data/crefv2b3mnt_adam1.h5
# 260/260 [==============================] - 116s 445ms/step - loss: 0.5531 - accuracy: 0.8142 - val_loss: 0.2332 - val_accuracy: 0.9288 - lr: 1.0000e-04
# Epoch 3/30
# 260/260 [==============================] - ETA: 0s - loss: 0.4665 - accuracy: 0.8441
# Epoch 3: val_accuracy did not improve from 0.92885
# 260/260 [==============================] - 110s 422ms/step - loss: 0.4665 - accuracy: 0.8441 - val_loss: 0.2527 - val_accuracy: 0.9279 - lr: 7.5000e-05
# Epoch 4/30
# 260/260 [==============================] - ETA: 0s - loss: 0.4096 - accuracy: 0.8645
# Epoch 4: val_accuracy did not improve from 0.92885
# 260/260 [==============================] - 109s 420ms/step - loss: 0.4096 - accuracy: 0.8645 - val_loss: 0.5308 - val_accuracy: 0.8817 - lr: 7.5000e-05
# Epoch 5/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3740 - accuracy: 0.8785
# Epoch 5: val_accuracy improved from 0.92885 to 0.95192, saving model to /content/drive/MyDrive/Capstone_data/crefv2b3mnt_adam1.h5
# 260/260 [==============================] - 114s 437ms/step - loss: 0.3740 - accuracy: 0.8785 - val_loss: 0.1879 - val_accuracy: 0.9519 - lr: 5.6250e-05
# Epoch 6/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3440 - accuracy: 0.8872
# Epoch 6: val_accuracy did not improve from 0.95192
# 260/260 [==============================] - 110s 423ms/step - loss: 0.3440 - accuracy: 0.8872 - val_loss: 0.2881 - val_accuracy: 0.9346 - lr: 5.6250e-05
# Epoch 7/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3207 - accuracy: 0.8953
# Epoch 7: val_accuracy did not improve from 0.95192
# 260/260 [==============================] - 110s 422ms/step - loss: 0.3207 - accuracy: 0.8953 - val_loss: 0.1808 - val_accuracy: 0.9481 - lr: 4.2188e-05
# Epoch 8/30
# 260/260 [==============================] - ETA: 0s - loss: 0.
val_accuracy did not improve from 0.96250
# 260/260 [==============================] - 109s 421ms/step - loss: 0.2223 - accuracy: 0.9242 - val_loss: 0.1382 - val_accuracy: 0.9538 - lr: 1.7818e-06
# Epoch 29: early stopping
# 66/66 [==============================] - 15s 194ms/step - loss: 0.1341 - accuracy: 0.9626
# <ipython-input-21-40afd3292491>:58: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   Y_pred = modela.predict_generator(valid_data_generator)
# Classification Report
#               precision    recall  f1-score   support
#
#       Normal       0.90      0.96      0.93       268
#    Pneumonia       0.98      0.97      0.97       775
#
#     accuracy                           0.96      1043
#    macro avg       0.94      0.96      0.95      1043
# weighted avg       0.96      0.96      0.96      1043
# K-Fold5
# Found 4173 validated image filenames belonging to 2 classes.
# Found 1043 validated image filenames belonging to 2 classes.
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/30
# 260/260 [==============================] - ETA: 0s - loss: 0.7990 - accuracy: 0.6714
# Epoch 1: val_accuracy improved from -inf to 0.87115, saving model to /content/drive/MyDrive/Capstone_data/crefv2b3mnt_adam5.h5
# 260/260 [==============================] - 166s 439ms/step - loss: 0.7990 - accuracy: 0.6714 - val_loss: 0.3810 - val_accuracy: 0.8712 - lr: 1.0000e-04
# Epoch 2/30
# 260/260 [==============================] - ETA: 0s - loss: 0.5322 - accuracy: 0.8126
# Epoch 2: val_accuracy improved from 0.87115 to 0.92212, saving model to /content/drive/MyDrive/Capstone_data/crefv2b3mnt_adam5.h5
# 260/260 [==============================] - 112s 429ms/step - loss: 0.5322 - accuracy: 0.8126 - val_loss: 0.3223 - val_accuracy: 0.9221 - lr: 1.0000e-04
# Epoch 3/30
# 260/260 [==============================] - ETA: 0s - loss: 0.4923 - accuracy: 0.8357
# Epoch 3: val_accuracy did not improve from 0.92212
# 260/260 [==============================] - 108s 414ms/step - loss: 0.4923 - accuracy: 0.8357 - val_loss: 0.3008 - val_accuracy: 0.9135 - lr: 7.5000e-05
# Epoch 4/30
# 260/260 [==============================] - ETA: 0s - loss: 0.4152 - accuracy: 0.8569
# Epoch 4: val_accuracy improved from 0.92212 to 0.93654, saving model to /content/drive/MyDrive/Capstone_data/crefv2b3mnt_adam5.h5
# 260/260 [==============================] - 113s 432ms/step - loss: 0.4152 - accuracy: 0.8569 - val_loss: 0.2073 - val_accuracy: 0.9365 - lr: 7.5000e-05
# Epoch 5/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3941 - accuracy: 0.8699
# Epoch 5: val_accuracy did not improve from 0.93654
# 260/260 [==============================] - 108s 414ms/step - loss: 0.3941 - accuracy: 0.8699 - val_loss: 0.2083 - val_accuracy: 0.9346 - lr: 5.6250e-05
# Epoch 6/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3545 - accuracy: 0.8813
# Epoch 6: val_accuracy improved from 0.93654 to 0.93942, saving model to /content/drive/MyDrive/Capstone_data/crefv2b3mnt_adam5.h5
# 260/260 [==============================] - 111s 428ms/step - loss: 0.3545 - accuracy: 0.8813 - val_loss: 0.1969 - val_accuracy: 0.9394 - lr: 5.6250e-05
# Epoch 7/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3501 - accuracy: 0.8831
# Epoch 7: val_accuracy improved from 0.93942 to 0.94808, saving model to /content/drive/MyDrive/Capstone_data/crefv2b3mnt_adam5.h5
# 260/260 [==============================] - 111s 428ms/step - loss: 0.3501 - accuracy: 0.8831 - val_loss: 0.1572 - val_accuracy: 0.9481 - lr: 4.2188e-05
# Epoch 8/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3173 - accuracy: 0.8920
# Epoch 8: val_accuracy did not improve from 0.94808
# 260/260 [==============================] - 108s 415ms/step - loss: 0.3173 - accuracy: 0.8920 - val_loss: 0.2330 - val_accuracy: 0.9423 - lr: 4.2188e-05
# Epoch 9/30
# 260/260 [==============================] - ETA: 0s - loss: 0.3133 - accuracy: 0.8922
# Epoch 9: val_accuracy improved from 0.94808 to 0.95096, saving model to /content/drive/MyDrive/Capstone_data/crefv2b3mnt_adam5.h5
# 260/260 [==============================] - 111s 426ms/step - loss: 0.3133 - accuracy: 0.8922 - val_loss: 0.1621 - val_accuracy: 0.9510 - lr: 3.1641e-05
# Epoch 10/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2918 - accuracy: 0.8997
# Epoch 10: val_accuracy did not improve from 0.95096
# 260/260 [==============================] - 108s 414ms/step - loss: 0.2918 - accuracy: 0.8997 - val_loss: 0.2377 - val_accuracy: 0.9442 - lr: 3.1641e-05
# Epoch 11/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2768 - accuracy: 0.9081
# Epoch 11: val_accuracy improved from 0.95096 to 0.96154, saving model to /content/drive/MyDrive/Capstone_data/crefv2b3mnt_adam5.h5
# 260/260 [==============================] - 110s 424ms/step - loss: 0.2768 - accuracy: 0.9081 - val_loss: 0.1327 - val_accuracy: 0.9615 - lr: 2.3730e-05
# Epoch 12/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2748 - accuracy: 0.9112
# Epoch 12: val_accuracy did not improve from 0.96154
# 260/260 [==============================] - 109s 419ms/step - loss: 0.2748 - accuracy: 0.9112 - val_loss: 0.1381 - val_accuracy: 0.9587 - lr: 2.3730e-05
# Epoch 13/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2617 - accuracy: 0.9083
# Epoch 13: val_accuracy did not improve from 0.96154
# 260/260 [==============================] - 107s 412ms/step - loss: 0.2617 - accuracy: 0.9083 - val_loss: 0.1432 - val_accuracy: 0.9596 - lr: 1.7798e-05
# Epoch 14/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2652 - accuracy: 0.9091
# Epoch 14: val_accuracy did not improve from 0.96154
# 260/260 [==============================] - 108s 416ms/step - loss: 0.2652 - accuracy: 0.9091 - val_loss: 0.1571 - val_accuracy: 0.9548 - lr: 1.7798e-05
# Epoch 15/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2701 - accuracy: 0.9074
# Epoch 15: val_accuracy improved from 0.96154 to 0.96442, saving model to /content/drive/MyDrive/Capstone_data/crefv2b3mnt_adam5.h5
# 260/260 [==============================] - 112s 431ms/step - loss: 0.2701 - accuracy: 0.9074 - val_loss: 0.1201 - val_accuracy: 0.9644 - lr: 1.3348e-05
# Epoch 16/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2604 - accuracy: 0.9079
# Epoch 16: val_accuracy improved from 0.96442 to 0.97019, saving model to /content/drive/MyDrive/Capstone_data/crefv2b3mnt_adam5.h5
# 260/260 [==============================] - 112s 429ms/step - loss: 0.2604 - accuracy: 0.9079 - val_loss: 0.1064 - val_accuracy: 0.9702 - lr: 1.3348e-05
# Epoch 17/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2540 - accuracy: 0.9134
# Epoch 17: val_accuracy did not improve from 0.97019
# 260/260 [==============================] - 108s 415ms/step - loss: 0.2540 - accuracy: 0.9134 - val_loss: 0.1121 - val_accuracy: 0.9644 - lr: 1.0011e-05
# Epoch 18/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2526 - accuracy: 0.9139
# Epoch 18: val_accuracy did not improve from 0.97019
# 260/260 [==============================] - 108s 416ms/step - loss: 0.2526 - accuracy: 0.9139 - val_loss: 0.1221 - val_accuracy: 0.9625 - lr: 1.0011e-05
# Epoch 19/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2449 - accuracy: 0.9211
# Epoch 19: val_accuracy did not improve from 0.97019
# 260/260 [==============================] - 107s 413ms/step - loss: 0.2449 - accuracy: 0.9211 - val_loss: 0.1335 - val_accuracy: 0.9587 - lr: 7.5085e-06
# Epoch 20/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2470 - accuracy: 0.9170
# Epoch 20: val_accuracy did not improve from 0.97019
# 260/260 [==============================] - 108s 414ms/step - loss: 0.2470 - accuracy: 0.9170 - val_loss: 0.0976 - val_accuracy: 0.9692 - lr: 7.5085e-06
# Epoch 21/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2481 - accuracy: 0.9127
# Epoch 21: val_accuracy did not improve from 0.97019
# 260/260 [==============================] - 111s 425ms/step - loss: 0.2481 - accuracy: 0.9127 - val_loss: 0.0992 - val_accuracy: 0.9673 - lr: 5.6314e-06
# Epoch 22/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2552 - accuracy: 0.9139
# Epoch 22: val_accuracy did not improve from 0.97019
# 260/260 [==============================] - 107s 413ms/step - loss: 0.2552 - accuracy: 0.9139 - val_loss: 0.1025 - val_accuracy: 0.9673 - lr: 5.6314e-06
# Epoch 23/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2454 - accuracy: 0.9194
# Epoch 23: val_accuracy did not improve from 0.97019
# 260/260 [==============================] - 108s 415ms/step - loss: 0.2454 - accuracy: 0.9194 - val_loss: 0.1134 - val_accuracy: 0.9663 - lr: 4.2235e-06
# Epoch 24/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2327 - accuracy: 0.9211
# Epoch 24: val_accuracy did not improve from 0.97019
# 260/260 [==============================] - 108s 414ms/step - loss: 0.2327 - accuracy: 0.9211 - val_loss: 0.1030 - val_accuracy: 0.9673 - lr: 4.2235e-06
# Epoch 25/30
# 260/260 [==============================] - ETA: 0s - loss: 0.2237 - accuracy: 0.9197
# Epoch 25: val_accuracy did not improve from 0.97019
# 260/260 [==============================] - 108s 416ms/step - loss: 0.2237 - accuracy: 0.9197 - val_loss: 0.1022 - val_accuracy: 0.9663 - lr: 3.1676e-06
# Epoch 25: early stopping
# 66/66 [==============================] - 15s 190ms/step - loss: 0.1063 - accuracy: 0.9703
# <ipython-input-21-40afd3292491>:58: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   Y_pred = modela.predict_generator(valid_data_generator)
# Classification Report
#               precision    recall  f1-score   support
#
#       Normal       0.95      0.93      0.94       268
#    Pneumonia       0.98      0.98      0.98       775
#
#     accuracy                           0.97      1043
#    macro avg       0.96      0.96      0.96      1043
# weighted avg       0.97      0.97      0.97      1043

# %%
l1=max(VALIDATION_ACCURACY[0])
l2=max(VALIDATION_ACCURACY[1])
l3=max(VALIDATION_ACCURACY[2])
l4=max(VALIDATION_ACCURACY[3])
l5=max(VALIDATION_ACCURACY[4])

avg=(l1+l2+l3+l4+l5)/5
avg
# Out:
# 0.9621153831481933
